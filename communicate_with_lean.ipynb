# %% [markdown]
# # Communicating with Lean

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Communicating-with-Lean" data-toc-modified-id="Communicating-with-Lean-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Communicating with Lean</a></span><ul class="toc-item"><li><span><a href="#Lean-Server" data-toc-modified-id="Lean-Server-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Lean Server</a></span></li><li><span><a href="#Testing-tactics-with-the-Lean-Server" data-toc-modified-id="Testing-tactics-with-the-Lean-Server-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Testing tactics with the Lean Server</a></span><ul class="toc-item"><li><span><a href="#Speed-and-robustness" data-toc-modified-id="Speed-and-robustness-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Speed and robustness</a></span></li><li><span><a href="#Stepping-through-a-full-proof" data-toc-modified-id="Stepping-through-a-full-proof-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Stepping through a full proof</a></span></li></ul></li><li><span><a href="#Creating-a-simple-Lean-solver-(with-breath-first-search)-in-Python" data-toc-modified-id="Creating-a-simple-Lean-solver-(with-breath-first-search)-in-Python-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Creating a simple Lean solver (with breath first search) in Python</a></span></li><li><span><a href="#Custom-printing-of-Lean-expressions" data-toc-modified-id="Custom-printing-of-Lean-expressions-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Custom printing of Lean expressions</a></span></li><li><span><a href="#Current-issues" data-toc-modified-id="Current-issues-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Current issues</a></span><ul class="toc-item"><li><span><a href="#Privately-defined-terms" data-toc-modified-id="Privately-defined-terms-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Privately defined terms</a></span></li><li><span><a href="#Term-blowup" data-toc-modified-id="Term-blowup-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Term blowup</a></span></li><li><span><a href="#Missing-@-symbols" data-toc-modified-id="Missing-@-symbols-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Missing @ symbols</a></span></li><li><span><a href="#Extra-@-sysmbols-(or-maybe-a-missing-case-in-the-Lean-parser)" data-toc-modified-id="Extra-@-sysmbols-(or-maybe-a-missing-case-in-the-Lean-parser)-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Extra <code>@</code> sysmbols (or maybe a missing case in the Lean parser)</a></span></li><li><span><a href="#Implicit-and-type-class-assumptions" data-toc-modified-id="Implicit-and-type-class-assumptions-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>Implicit and type class assumptions</a></span></li><li><span><a href="#Let-expressions" data-toc-modified-id="Let-expressions-1.5.6"><span class="toc-item-num">1.5.6&nbsp;&nbsp;</span>Let expressions</a></span></li><li><span><a href="#Other" data-toc-modified-id="Other-1.5.7"><span class="toc-item-num">1.5.7&nbsp;&nbsp;</span>Other</a></span></li></ul></li><li><span><a href="#TODOs" data-toc-modified-id="TODOs-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>TODOs</a></span></li><li><span><a href="#What-I-want-from-Lean-4" data-toc-modified-id="What-I-want-from-Lean-4-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>What I want from Lean 4</a></span></li></ul></li></ul></div>

# %% [markdown]
# This is a hacky prototype showing how one can use Lean's server for communication between Lean and another program.  We have in mind implementing something like HOList for Lean. The main idea is that theorem proving is like a puzzle similar to the Rubik cube.  One has states and actions one can perform to move to other states.  This states are goals (or lists of goals) and the actions are tactics.
#
# What we build here is an interface where one says to Lean "apply this tactic to this goal" and Lean says whether that tactic succeeds and if so what the new list of goals are.  It is written in a Python notebook, but the ideas transcend languages.

# %%
import subprocess
import tempfile
import json
from pprint import pprint
import time
from datetime import datetime
import collections
from IPython.display import display

# %% [markdown]
# ## Lean Server
# This class starts up a Lean server and communicates with it.  There are a number of requests one can make to the Lean server, but we only need one or two.  To understand the Lean server, it is important to know it is not like a REPL, but more like the LSP.  It is designed to partial compile and comment on files as they are being written.  The use here is more of a hack (and it is unfortunately quite a bit slow we will see).
#
# One communicates to Lean by sending JSON requests and getting back responses.  We only need one or two request types for our purposes.  The first request we need is a "sync" request.  It sends a "file" to Lean to be synced.  (The file doesn't actually need to exist.)  The second request, an "info" request, asks Lean to provide more information about particular places in the code.  Unfortunately, the responses to the requests don't actually provide a lot of direct answers.  Especially for the "sync" request, one has to wait for an "all_messages" request to provide answers.  (And even then, it is difficult to determine that the response you got is up-to-date with the current Lean file.  We've employed a lot of tricks to make sure we are getting the most up-to-date information from Lean.)  Our class will store any "all_messages" responses it sees into a queue for latter processing.
#
# Ultimately, the "info" requests turned out not to be a reliable as we hoped, so we just use the "sync" request and only use the "info" request to prevent blocking of the channel.

# %%
class LeanServer:
    """
    Open up a Lean server and communicate with it.  
    
    Right now it only has support for the "sync" and "info" requests (and their)
    corresponding responses.  It does however, store all "all_messages" response
    into a queue for later processing.
    """
    
    def __init__(self):
        self.cntr = -1
        self.cntr2 = -1
        self.all_messages = []
        self.all_messages_time = -1
        self.current_tasks = []
        self.current_tasks_time = -1
        self.proc = subprocess.Popen(['lean', '--server'], 
                    universal_newlines=True, 
                    stdin=subprocess.PIPE, # pipe STDIN and STDOUT to send and receive messages
                    stdout=subprocess.PIPE, 
                    #stderr=subprocess.PIPE
                )
    
    # make into a context manager so that it closes lean server automatically
    def __enter__(self):
        self.proc.__enter__()
        return self
    
    def __exit__(self, type, value, traceback):
        self.proc.__exit__(type, value, traceback)
    
    def seq_num(self):
        self.cntr += 1
        return self.cntr
    
    def send_request(self, request, expected_response, verbose=False, sleep=0.0):
        seq_num = self.seq_num()
        request1 = request.copy()
        request1['seq_num'] = seq_num
        j = json.dumps(request1)
        
        # TODO: Use logging instead
        if verbose:
            print()
            print("=>:", datetime.now().strftime('%H:%M:%S.%f'))
            pprint(j)
            print()
        
        # send
        print(j, file=self.proc.stdin, flush=True)
        
        # wait for response
        time.sleep(sleep)
        while True:
            self.cntr2 += 1
            raw_output = self.proc.stdout.readline()
            output = json.loads(raw_output)
            if verbose:
                print("<=:", datetime.now().strftime('%H:%M:%S.%f'))
                pprint(output)
                print()
            if 'response' in output:
                if output['response'] == expected_response and output['seq_num'] == seq_num:
                    return output
                # TODO: Handle error differently.  It means the JSON is bad
                elif output['response'] == 'error':
                    return output
                # record messages since they may point to errors in the lean code
                elif output['response'] == 'all_messages':
                    self.all_messages = output['msgs']
                    self.all_messages_time = self.cntr2
                # record tasks to know when Lean has stopped processing file
                elif output['response'] == 'current_tasks':
                    self.current_tasks = output['tasks']
                    self.current_tasks_time = self.cntr2
    
    def send_sync_request(self, file_name, content, verbose=False):
        request = {
            'command':'sync',
            'file_name': file_name,
            "content": content,
        }
        
        return self.send_request(request, expected_response='ok', verbose=verbose, sleep=0.0)
    
    def send_info_request(self, file_name, line, column, verbose=False):
        request = {            
            'command':'info',
            'file_name': file_name,
            'column': column,
            'line': line
        }
        
        return self.send_request(request, expected_response='ok', verbose=verbose, sleep=0.0)

# %%
# sync file (the "file" doesn't need to exist)
with LeanServer() as lean_server:
    response1 = lean_server.send_sync_request(
        file_name='/tmp/fake_lean_file.lean', 
        content='example (p: Prop) : p = p := begin sorry end')
    time.sleep(1)
    response2 = lean_server.send_info_request(
        file_name='/tmp/fake_lean_file.lean', 
        line=1, 
        column=0)
    
    # the responses themselves aren't always useful
    display(response1)
    display(response2)
    
    # the "all_messages" responses are more useful
    display(lean_server.all_messages)
# Out:
# {'message': 'file invalidated', 'response': 'ok', 'seq_num': 0}
# {'response': 'ok', 'seq_num': 1}
# [{'caption': '',
#   'file_name': '/tmp/fake_lean_file.lean',
#   'pos_col': 0,
#   'pos_line': 1,
#   'severity': 'warning',
#   'text': "declaration '[anonymous]' uses sorry"}]

# %% [markdown]
# In much of the code, use the optional parameter `verbose=True` to see the message traffic.

# %%
# sync file (the "file" doesn't need to exist)
with LeanServer() as lean_server:
    lean_server.send_sync_request(
        file_name='/tmp/fake_lean_file.lean', 
        content='example (p: Prop) : p = p := begin sorry end',
        verbose=True)
    lean_server.send_info_request(
        file_name='/tmp/fake_lean_file.lean', 
        line=1,
        column=0,
        verbose=True)
# Out:
# =>: 10:45:37.131428
# ('{"content": "example (p: Prop) : p = p := begin sorry end", "file_name": '
#  '"/tmp/fake_lean_file.lean", "seq_num": 0, "command": "sync"}')
#
# <=: 10:45:37.387175
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 10:45:37.605599
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 10:45:37.808850
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 10:45:37.890468
# {'message': 'file invalidated', 'response': 'ok', 'seq_num': 0}
#
#
# =>: 10:45:37.890757
# ('{"line": 1, "column": 0, "file_name": "/tmp/fake_lean_file.lean", "seq_num": '
#  '1, "command": "info"}')
#
# <=: 10:45:37.891602
# {'response': 'ok', 'seq_num': 1}

# %% [markdown]
# ## Testing tactics with the Lean Server

# %% [markdown]
# Again, tactic-based theorem proving is like a puzzle.  You go from state to state exploring.  What we need is a way to test if we can use a tactic on a goal and what the next goals are.  This is what the LeanTacticTestingInterface does.  (Note, it is much faster to ask the Lean server about multiple goal-tactic pairs instead of just one at a time.)

# %%
# For storing information about a Lean goal
LeanGoal = collections.namedtuple('LeanGoal', ['universes', 'assumptions', 'conclusion'])

# %%
inspection_tools = r"""
namespace inspection_tools

def join (sep : string) : list string → string
| [x]     := x
| []      := ""
| (x::xs) := x ++ sep ++ join xs

meta def expr_to_string (e : expr bool.tt) : tactic string :=
do
  o ← tactic.get_options,
  tactic.set_options (options.mk.set_bool `pp.all tt),
  f ← tactic.pp e,
  tactic.set_options o,  -- set back to before
  return $ to_string f
  
meta def local_cxt_to_string (v : expr bool.tt) : tactic string := 
do 
  tp ← tactic.infer_type v,
  v_str ← expr_to_string v,
  tp_str ← expr_to_string tp,
  return $ v_str ++ "\n\n" ++ tp_str

meta def goal_to_string (g : expr) : tactic string :=
do 
  tactic.set_goals [g],
  goal ← tactic.target,
  local_cxt ← tactic.local_context,
  let local_cxt_len := list.length local_cxt,
  goal_str ← expr_to_string goal,
  local_cxt_strs ← (list.mmap local_cxt_to_string local_cxt),
  let s1 := goal_str ++ "\n\n",
  let s2 := "Local Context Vars: " ++ (to_string local_cxt_len) ++ "\n\n",
  let s3 := join "\n\n" local_cxt_strs,
  return $ s1 ++ s2 ++ s3

meta def state_report : tactic string :=
do 
 gs ← tactic.get_goals,
 -- loop over all goals (has effect of resetting the goal each time)
 let gs_len := list.length gs,
 goal_strings ← gs.mmap goal_to_string,
 tactic.set_goals gs,  -- set goals back
 let s := "Goals: " ++ (to_string gs_len) ++ "\n\n" ++ (join "\n\n" goal_strings),
 return s
 
meta def trace_goal_state : tactic unit :=
do 
 s ← state_report,
 tactic.trace s,
 return ()

end inspection_tools
"""

default_custom_code = r"""
namespace custom
 
meta def trace_custom_state : tactic unit :=
do 
 tactic.trace "",  -- make more interesting
 return ()

end custom
"""

# %%
class LeanTacticTestingInterface:
    """
    Interface to test a tactic on a goal (or multiple tactics on multiple goals)
    """
    def __init__(self):
        self.lean_server = LeanServer()
        
        self.msg_cntr = 0
        self.file_name = 'dummy.lean'   # the name of the "file" being checked (not a real file)
        self.dummy_file = 'dummy.lean'  # a file always kept empty 
        self.eval_line_pos = None       # used for checking that a file is complete
        
        # set up a dummy file for later use
        self.lean_server.send_sync_request(file_name=self.dummy_file, content="")
        
        # one can implement their own custom state trace.  This is the default.
        self.custom_code = default_custom_code
    
     # make into a context manager so that it closes lean server automatically
    def __enter__(self):
        self.lean_server.__enter__()
        return self
    
    def __exit__(self, type, value, traceback):
        self.lean_server.__exit__(type, value, traceback)
        
    def parse_state(self, universes, goal_state):
        """
        Parses the trace string returned by trace_goal_state
        """
        lines = iter(' '.join(l.split()) for l in goal_state.split("\n\n"))
        
        goal_cnt = int(next(lines).split()[-1])
        
        goals = []
        for _ in range(goal_cnt):
            target = next(lines)
            assump_cnt = int(next(lines).split()[-1])
            assumptions = []
            for _ in range(assump_cnt):
                v = next(lines)
                tp = next(lines)
                assumptions.append(v + " : " + tp)
            goal = LeanGoal(universes, assumptions, target)
            goals.append(goal)

        return goals
    
    def check_content(self, content, verbose):
        """
        Have Lean check the contents of a Lean "file". 
        """
        self.msg_cntr += 1
        
        # empty out the previous file for good measure
        self.lean_server.send_sync_request(file_name=self.file_name, content="", verbose=verbose)
        
        # use a few different file names to help avoid old data in the messages
        self.file_name = 'fake_lean_file{}.lean'.format(self.msg_cntr % 10)
        
        # put an eval at the end to make sure the response is not from an old file
        extended_content = content + "\n#eval " + str(self.msg_cntr)
        self.eval_line_pos = extended_content.count("\n") + 1
        
        if verbose:
            print("-- {} --------------".format(self.file_name))
            for i, l in enumerate(extended_content.split('\n')):
                print("{:3}   {}".format(i+1, l))
            print("-------------------------")
            
        # send the file
        self.lean_server.send_sync_request(file_name=self.file_name, content=extended_content, verbose=verbose)
        
    def get_messages(self, verbose):
        """
        Get messages for the current content being checked.
        Return all the messages for that "file"
        
        This is really really hard to make robust.  How do I know Lean has finished
        or worst that Lean isn't still providing information from an old
        version of the file?
        """
        
        # wait for tasks to stop running
        tasks_stopped_time = None
        for _ in range(10000):  # lazy time-out mechanism
            
            # keep sending requests to a dummy file to collect more "all_messages" responses
            self.lean_server.send_info_request(file_name=self.dummy_file, line=1, column=0, verbose=verbose)
            
            # check that tasks are complete for file_name
            task_running = False
            for task in self.lean_server.current_tasks:
                if task['file_name'] == self.file_name:
                    task_running = True
                    break
            if not task_running:
                tasks_stopped_time = self.lean_server.current_tasks_time
                break
        else:
            raise TimeoutError("Tasks still running for {}:\n{}".format('file_name', "\n".join(self.lean_server.current_tasks)))
            
                
        # check that messages are complete by looking at eval at the end
        for _ in range(10000):  # lazy time-out mechanism
            
            # keep sending requests to a dummy file to collect more "all_messages" responses
            self.lean_server.send_info_request(self.dummy_file, line=1, column=0, verbose=verbose)
            
            # wait until messages are after current tasks
            #if self.lean_server.all_messages_time < tasks_stopped_time:
            #    continue
                
            # filter the messages to those for this "file" 
            # and also check for the final the eval statement
            filtered_messages = []
            messages_are_complete = False
            for msg in self.lean_server.all_messages:
                if msg['file_name'] == self.file_name:
                    if msg['pos_line'] < self.eval_line_pos:
                        filtered_messages.append(msg)
                    elif msg['pos_line'] == self.eval_line_pos and msg['caption'] == "eval result":
                        if msg['text'] == str(self.msg_cntr):
                            messages_are_complete = True
                        else:
                            break

            # clear messages
            self.lean_server.all_messages = []

            if messages_are_complete:
                return filtered_messages
            
        raise TimeoutError("Expecting eval result on line {} of file {} to be {}.  Run with verbose=True to check for error messages.".format(
                self.eval_line_pos, self.file_name, self.msg_cntr
        ))
    
    def preamble(self, imports):
        if imports:
            import_line = "import " + " ".join(imports) + "\n"
        else:
            import_line = ""
        
        return import_line + inspection_tools + "\n" + self.custom_code + "\n"
        
    def example_block(self, goal, tactic):
        block = ""
        # line: preamble + 9 * n + 0
        block += "section example_block\n"
        # line: preamble + 9 * n + 1
        if goal.universes:
            block += "universes " + " ".join(goal.universes) + "\n"
        else:
            block += "--no universes\n"
        # line: preamble + 9 * n + 2  
        block += "example "
        block += " ".join("(" + l.replace("\n", " ").replace("…", "_redacted_code_too_long_") + ")" for l in goal.assumptions)
        block += " : "
        block += goal.conclusion.replace("\n", " ").replace("…", "_redacted_code_too_long_") + " :=\n"
        # line: preamble + 9 * n + 3
        block += "begin\n"  
        # line: preamble + 9 * n + 4
        block += tactic + ",\n"
        # line: preamble + 9 * n + 5
        block += 'inspection_tools.trace_goal_state,\n' # goal state
        # line: preamble + 9 * n + 6
        block += 'custom.trace_custom_state,\n'         # custom trace
        # line: preamble + 9 * n + 7
        block += "end\n"
        # line: preamble + 9 * n + 8
        block += "end example_block\n"

        return block
            
    def apply_tactic_multiple(self, lean_goals, tactics, imports=[], verbose=False):
        assert len(lean_goals) == len(tactics)
        
        # build content
        preamble = self.preamble(imports)
        
        # this is the line (indexed from 1) that the first block will be on
        preamble_length = preamble.count("\n") + 1
        
        content = preamble
        for goal, tactic in zip(lean_goals, tactics):
            content += self.example_block(goal, tactic)
        
        # start checking the file
        self.check_content(content, verbose=verbose)
            
        # positions in the block
        theorem_line = 2
        tactic_line = 4
        goals_line = 5
        custom_state_line = 6
        block_length = 9
        
        for _ in range(1000):  # lazy timeout method
            # start checking the file
            msgs = self.get_messages(verbose=verbose)
        
            # extract data from messages
            results = [[None, None, [], []] for _ in lean_goals]
            for msg in msgs:
                block_line_pos = (msg['pos_line'] - preamble_length) % block_length
                block_num = (msg['pos_line'] - preamble_length) // block_length

                if msg['pos_line'] < preamble_length:
                    continue
                elif block_line_pos == goals_line and msg['severity'] == 'information':
                    results[block_num][0] = msg['text']
                elif block_line_pos == custom_state_line and msg['severity'] == 'information':
                    results[block_num][1] = msg['text']
                elif block_line_pos == tactic_line and msg['severity'] == 'error':
                    results[block_num][2].append(msg['text'])
                elif block_line_pos == theorem_line and msg['severity'] == 'error':
                    results[block_num][3].append(msg['text'])

            # parse data and check for completeness
            final_results = []
            complete = True
            for i, ((goal_state, custom_state, tactic_errors, theorem_errors), prev_goal) in enumerate(zip(results, lean_goals)):
                if theorem_errors:
                    result = ('theorem_error', theorem_errors, '')
                elif tactic_errors:
                    result = ('tactic_failure', tactic_errors, '')
                elif goal_state is not None and custom_state is not None:
                    result = ('success', self.parse_state(prev_goal.universes, goal_state), custom_state.strip())
                else:
                    complete = False  # need to get messages again
                    break

                final_results.append(result)

            if complete:
                return final_results
        
        raise TimeoutError("Lean server sessages are not as expected:\n{}".format("\n".join(msgs)))
        
    def apply_tactic(self, lean_goal, tactic, imports=[], verbose=False):
        """
        Apply tactic to a goal and see what you get.
        """
        
        result = self.apply_tactic_multiple([lean_goal], [tactic], imports=imports, verbose=verbose)
        return result[0]

# %% [markdown]
# We see if we apply `refl` to `p = p` we solve all the goals (hence the empty list returned).

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal([], ['p q : Prop'],  'p = p')
    display(lean_interface.apply_tactic(goal, 'refl'))
# Out:
# ('success', [], '')

# %% [markdown]
# One can also add universe levels, e.g. `u`, `v`, as follows:

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u', 'v'], ['a b: Type u'],  'a = a')
    display(lean_interface.apply_tactic(goal, 'refl'))
# Out:
# ('success', [], '')

# %% [markdown]
# Imports can also be added to the `apply_tactic` call:

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u'], ['α : Type u'],  'dlist.to_list (@dlist.empty α) = []')
    display(lean_interface.apply_tactic(goal, 'refl', imports=['data.dlist']))
# Out:
# ('success', [], '')

# %% [markdown]
# To see what is going on, we show the logs with `verbose=True`.  This also prints the file being sent to Lean.
#
# The main idea is that we encode everything we want to check into a Lean file, send that via a "sync" request, and read off the response from the messages.

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u', 'v'], ['a b: Type u'],  'a = a')
    display(lean_interface.apply_tactic(goal, 'refl', verbose=True))
# Out:
# =>: 10:45:45.544907
# '{"content": "", "file_name": "dummy.lean", "seq_num": 1, "command": "sync"}'
#
# <=: 10:45:45.545603
# {'message': 'file unchanged', 'response': 'ok', 'seq_num': 1}
#
# -- fake_lean_file1.lean --------------
#   1
#   2   namespace inspection_tools
#   3
#   4   def join (sep : string) : list string → string
#   5   | [x]     := x
#   6   | []      := ""
#   7   | (x::xs) := x ++ sep ++ join xs
#   8
#   9   meta def expr_to_string (e : expr bool.tt) : tactic string :=
#  10   do
#  11     o ← tactic.get_options,
#  12     tactic.set_options (options.mk.set_bool `pp.all tt),
#  13     f ← tactic.pp e,
#  14     tactic.set_options o,  -- set back to before
#  15     return $ to_string f
#  16
#  17   meta def local_cxt_to_string (v : expr bool.tt) : tactic string :=
#  18   do
#  19     tp ← tactic.infer_type v,
#  20     v_str ← expr_to_string v,
#  21     tp_str ← expr_to_string tp,
#  22     return $ v_str ++ "\n\n" ++ tp_str
#  23
#  24   meta def goal_to_string (g : expr) : tactic string :=
#  25   do
#  26     tactic.set_goals [g],
#  27     goal ← tactic.target,
#  28     local_cxt ← tactic.local_context,
#  29     let local_cxt_len := list.length local_cxt,
#  30     goal_str ← expr_to_string goal,
#  31     local_cxt_strs ← (list.mmap local_cxt_to_string local_cxt),
#  32     let s1 := goal_str ++ "\n\n",
#  33     let s2 := "Local Context Vars: " ++ (to_string local_cxt_len) ++ "\n\n",
#  34     let s3 := join "\n\n" local_cxt_strs,
#  35     return $ s1 ++ s2 ++ s3
#  36
#  37   meta def state_report : tactic string :=
#  38   do
#  39    gs ← tactic.get_goals,
#  40    -- loop over all goals (has effect of resetting the goal each time)
#  41    let gs_len := list.length gs,
#  42    goal_strings ← gs.mmap goal_to_string,
#  43    tactic.set_goals gs,  -- set goals back
#  44    let s := "Goals: " ++ (to_string gs_len) ++ "\n\n" ++ (join "\n\n" goal_strings),
#  45    return s
#  46
#  47   meta def trace_goal_state : tactic unit :=
#  48   do
#  49    s ← state_report,
#  50    tactic.trace s,
#  51    return ()
#  52
#  53   end inspection_tools
#  54
#  55
#  56   namespace custom
#  57
#  58   meta def trace_custom_state : tactic unit :=
#  59   do
#  60    tactic.trace "",  -- make more interesting
#  61    return ()
#  62
#  63   end custom
#  64
#  65   section example_block
#  66   universes u v
#  67   example (a b: Type u) : a = a :=
#  68   begin
#  69   refl,
#  70   inspection_tools.trace_goal_state,
#  71   custom.trace_custom_state,
#  72   end
#  73   end example_block
#  74
#  75   #eval 1
# -------------------------
#
# =>: 10:45:45.546283
# ('{"content": "\\nnamespace inspection_tools\\n\\ndef join (sep : string) : '
#  'list string \\u2192 string\\n| [x]     := x\\n| []      := \\"\\"\\n| '
#  '(x::xs) := x ++ sep ++ join xs\\n\\nmeta def expr_to_string (e : expr '
#  'bool.tt) : tactic string :=\\ndo\\n  o \\u2190 tactic.get_options,\\n  '
#  'tactic.set_options (options.mk.set_bool `pp.all tt),\\n  f \\u2190 tactic.pp '
#  'e,\\n  tactic.set_options o,  -- set back to before\\n  return $ to_string '
#  'f\\n  \\nmeta def local_cxt_to_string (v : expr bool.tt) : tactic string := '
#  '\\ndo \\n  tp \\u2190 tactic.infer_type v,\\n  v_str \\u2190 expr_to_string '
#  'v,\\n  tp_str \\u2190 expr_to_string tp,\\n  return $ v_str ++ '
#  '\\"\\\\n\\\\n\\" ++ tp_str\\n\\nmeta def goal_to_string (g : expr) : tactic '
#  'string :=\\ndo \\n  tactic.set_goals [g],\\n  goal \\u2190 '
#  'tactic.target,\\n  local_cxt \\u2190 tactic.local_context,\\n  let '
#  'local_cxt_len := list.length local_cxt,\\n  goal_str \\u2190 expr_to_string '
#  'goal,\\n  local_cxt_strs \\u2190 (list.mmap local_cxt_to_string '
#  'local_cxt),\\n  let s1 := goal_str ++ \\"\\\\n\\\\n\\",\\n  let s2 := '
#  '\\"Local Context Vars: \\" ++ (to_string local_cxt_len) ++ '
#  '\\"\\\\n\\\\n\\",\\n  let s3 := join \\"\\\\n\\\\n\\" local_cxt_strs,\\n  '
#  'return $ s1 ++ s2 ++ s3\\n\\nmeta def state_report : tactic string :=\\ndo '
#  '\\n gs \\u2190 tactic.get_goals,\\n -- loop over all goals (has effect of '
#  'resetting the goal each time)\\n let gs_len := list.length gs,\\n '
#  'goal_strings \\u2190 gs.mmap goal_to_string,\\n tactic.set_goals gs,  -- set '
#  'goals back\\n let s := \\"Goals: \\" ++ (to_string gs_len) ++ '
#  '\\"\\\\n\\\\n\\" ++ (join \\"\\\\n\\\\n\\" goal_strings),\\n return s\\n '
#  '\\nmeta def trace_goal_state : tactic unit :=\\ndo \\n s \\u2190 '
#  'state_report,\\n tactic.trace s,\\n return ()\\n\\nend '
#  'inspection_tools\\n\\n\\nnamespace custom\\n \\nmeta def trace_custom_state '
#  ': tactic unit :=\\ndo \\n tactic.trace \\"\\",  -- make more interesting\\n '
#  'return ()\\n\\nend custom\\n\\nsection example_block\\nuniverses u '
#  'v\\nexample (a b: Type u) : a = a '
#  ':=\\nbegin\\nrefl,\\ninspection_tools.trace_goal_state,\\ncustom.trace_custom_state,\\nend\\nend '
#  'example_block\\n\\n#eval 1", "file_name": "fake_lean_file1.lean", "seq_num": '
#  '2, "command": "sync"}')
#
# <=: 10:45:45.747776
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 10:45:45.963713
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 10:45:46.087615
# {'message': 'file invalidated', 'response': 'ok', 'seq_num': 2}
#
#
# =>: 10:45:46.087825
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 3, "command": '
#  '"info"}')
#
# <=: 10:45:46.090066
# {'response': 'ok', 'seq_num': 3}
#
#
# =>: 10:45:46.090262
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 4, "command": '
#  '"info"}')
#
# <=: 10:45:46.090626
# {'response': 'ok', 'seq_num': 4}
#
#
# =>: 10:45:46.090753
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 5, "command": '
#  '"info"}')
#
# <=: 10:45:46.091122
# {'response': 'ok', 'seq_num': 5}
#
#
# =>: 10:45:46.091346
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 6, "command": '
#  '"info"}')
#
# <=: 10:45:46.091682
# {'response': 'ok', 'seq_num': 6}
#
#
# =>: 10:45:46.091797
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 7, "command": '
#  '"info"}')
#
# <=: 10:45:46.092102
# {'response': 'ok', 'seq_num': 7}
#
#
# =>: 10:45:46.092212
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 8, "command": '
#  '"info"}')
#
# <=: 10:45:46.092514
# {'response': 'ok', 'seq_num': 8}
#
#
# =>: 10:45:46.092619
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 9, "command": '
#  '"info"}')
#
# <=: 10:45:46.092919
# {'response': 'ok', 'seq_num': 9}
#
#
# =>: 10:45:46.093021
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 10, '
#  '"command": "info"}')
#
# <=: 10:45:46.093321
# {'response': 'ok', 'seq_num': 10}
#
#
# =>: 10:45:46.093426
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 11, '
#  '"command": "info"}')
#
# <=: 10:45:46.093718
# {'response': 'ok', 'seq_num': 11}
#
#
# =>: 10:45:46.093821
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 12, '
#  '"command": "info"}')
#
# <=: 10:45:46.094116
# {'response': 'ok', 'seq_num': 12}
#
#
# =>: 10:45:46.094218
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 13, '
#  '"command": "info"}')
#
# <=: 10:45:46.094515
# {'response': 'ok', 'seq_num': 13}
#
#
# =>: 10:45:46.094616
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 14, '
#  '"command": "info"}')
#
# <=: 10:45:46.094908
# {'response': 'ok', 'seq_num': 14}
#
#
# =>: 10:45:46.095007
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 15, '
#  '"command": "info"}')
#
# <=: 10:45:46.095305
# {'response': 'ok', 'seq_num': 15}
#
#
# =>: 10:45:46.095405
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 16, '
#  '"command": "info"}')
#
# <=: 10:45:46.095695
# {'response': 'ok', 'seq_num': 16}
#
#
# =>: 10:45:46.095794
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 17, '
#  '"command": "info"}')
#
# <=: 10:45:46.096083
# {'response': 'ok', 'seq_num': 17}
#
#
# =>: 10:45:46.096182
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 18, '
#  '"command": "info"}')
#
# <=: 10:45:46.096462
# {'response': 'ok', 'seq_num': 18}
#
#
# =>: 10:45:46.096560
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 19, '
#  '"command": "info"}')
#
# <=: 10:45:46.096852
# {'response': 'ok', 'seq_num': 19}
#
#
# =>: 10:45:46.096951
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 20, '
#  '"command": "info"}')
#
# <=: 10:45:46.097239
# {'response': 'ok', 'seq_num': 20}
#
#
# =>: 10:45:46.097337
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 21, '
#  '"command": "info"}')
#
# <=: 10:45:46.097635
# {'response': 'ok', 'seq_num': 21}
#
#
# =>: 10:45:46.097736
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 22, '
#  '"command": "info"}')
#
# <=: 10:45:46.098032
# {'response': 'ok', 'seq_num': 22}
#
#
# =>: 10:45:46.098131
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 23, '
#  '"command": "info"}')
#
# <=: 10:45:46.098422
# {'response': 'ok', 'seq_num': 23}
#
#
# =>: 10:45:46.098523
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 24, '
#  '"command": "info"}')
#
# <=: 10:45:46.098821
# {'response': 'ok', 'seq_num': 24}
#
#
# =>: 10:45:46.098923
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 25, '
#  '"command": "info"}')
#
# <=: 10:45:46.099215
# {'response': 'ok', 'seq_num': 25}
#
#
# =>: 10:45:46.099316
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 26, '
#  '"command": "info"}')
#
# <=: 10:45:46.099634
# {'response': 'ok', 'seq_num': 26}
#
#
# =>: 10:45:46.099737
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 27, '
#  '"command": "info"}')
#
# <=: 10:45:46.100037
# {'response': 'ok', 'seq_num': 27}
#
#
# =>: 10:45:46.100137
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 28, '
#  '"command": "info"}')
#
# <=: 10:45:46.100429
# {'response': 'ok', 'seq_num': 28}
#
#
# =>: 10:45:46.100528
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 29, '
#  '"command": "info"}')
#
# <=: 10:45:46.100829
# {'response': 'ok', 'seq_num': 29}
#
#
# =>: 10:45:46.100931
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 30, '
#  '"command": "info"}')
#
# <=: 10:45:46.101226
# {'response': 'ok', 'seq_num': 30}
#
#
# =>: 10:45:46.101327
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 31, '
#  '"command": "info"}')
#
# <=: 10:45:46.101624
# {'response': 'ok', 'seq_num': 31}
#
#
# =>: 10:45:46.101723
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 32, '
#  '"command": "info"}')
#
# <=: 10:45:46.102013
# {'response': 'ok', 'seq_num': 32}
#
#
# =>: 10:45:46.102112
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 33, '
#  '"command": "info"}')
#
# <=: 10:45:46.102419
# {'response': 'ok', 'seq_num': 33}
#
#
# =>: 10:45:46.102520
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 34, '
#  '"command": "info"}')
#
# <=: 10:45:46.102812
# {'response': 'ok', 'seq_num': 34}
#
#
# =>: 10:45:46.102912
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 35, '
#  '"command": "info"}')
#
# <=: 10:45:46.103206
# {'response': 'ok', 'seq_num': 35}
#
#
# =>: 10:45:46.103306
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 36, '
#  '"command": "info"}')
#
# <=: 10:45:46.103599
# {'response': 'ok', 'seq_num': 36}
#
#
# =>: 10:45:46.103699
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 37, '
#  '"command": "info"}')
#
# <=: 10:45:46.103986
# {'response': 'ok', 'seq_num': 37}
#
#
# =>: 10:45:46.104086
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 38, '
#  '"command": "info"}')
#
# <=: 10:45:46.104379
# {'response': 'ok', 'seq_num': 38}
#
#
# =>: 10:45:46.104479
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 39, '
#  '"command": "info"}')
#
# <=: 10:45:46.104776
# {'response': 'ok', 'seq_num': 39}
#
#
# =>: 10:45:46.104877
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 40, '
#  '"command": "info"}')
#
# <=: 10:45:46.105175
# {'response': 'ok', 'seq_num': 40}
#
#
# =>: 10:45:46.105287
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 41, '
#  '"command": "info"}')
#
# <=: 10:45:46.105581
# {'response': 'ok', 'seq_num': 41}
#
#
# =>: 10:45:46.105693
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 42, '
#  '"command": "info"}')
#
# <=: 10:45:46.105996
# {'response': 'ok', 'seq_num': 42}
#
#
# =>: 10:45:46.106109
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 43, '
#  '"command": "info"}')
#
# <=: 10:45:46.167035
# {'is_running': True,
#  'response': 'current_tasks',
#  'tasks': [{'desc': 'parsing at line 1',
#             'end_pos_col': 8,
#             'end_pos_line': 75,
#             'file_name': 'fake_lean_file1.lean',
#             'pos_col': 0,
#             'pos_line': 1},
#            {'desc': 'parsing at line 1',
#             'end_pos_col': 1,
#             'end_pos_line': 1,
#             'file_name': 'dummy.lean',
#             'pos_col': 0,
#             'pos_line': 1}]}
#
# <=: 10:45:46.544449
# {'response': 'ok', 'seq_num': 43}
#
#
# =>: 10:45:46.544811
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 44, '
#  '"command": "info"}')
#
# <=: 10:45:46.545289
# {'response': 'ok', 'seq_num': 44}
#
#
# =>: 10:45:46.545466
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 45, '
#  '"command": "info"}')
#
# <=: 10:45:46.545830
# {'response': 'ok', 'seq_num': 45}
#
#
# =>: 10:45:46.545996
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 46, '
#  '"command": "info"}')
#
# <=: 10:45:46.546355
# {'response': 'ok', 'seq_num': 46}
#
#
# =>: 10:45:46.546516
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 47, '
#  '"command": "info"}')
#
# <=: 10:45:46.546866
# {'response': 'ok', 'seq_num': 47}
#
#
# =>: 10:45:46.547023
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 48, '
#  '"command": "info"}')
#
# <=: 10:45:46.547373
# {'response': 'ok', 'seq_num': 48}
#
#
# =>: 10:45:46.547528
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 49, '
#  '"command": "info"}')
#
# <=: 10:45:46.547875
# {'response': 'ok', 'seq_num': 49}
#
#
# =>: 10:45:46.548030
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 50, '
#  '"command": "info"}')
#
# <=: 10:45:46.548381
# {'response': 'ok', 'seq_num': 50}
#
#
# =>: 10:45:46.548540
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 51, '
#  '"command": "info"}')
#
# <=: 10:45:46.548935
# {'response': 'ok', 'seq_num': 51}
#
#
# =>: 10:45:46.549098
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 52, '
#  '"command": "info"}')
#
# <=: 10:45:46.549464
# {'response': 'ok', 'seq_num': 52}
#
#
# =>: 10:45:46.549584
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 53, '
#  '"command": "info"}')
#
# <=: 10:45:46.549863
# {'response': 'ok', 'seq_num': 53}
#
#
# =>: 10:45:46.549972
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 54, '
#  '"command": "info"}')
#
# <=: 10:45:46.550249
# {'response': 'ok', 'seq_num': 54}
#
#
# =>: 10:45:46.550358
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 55, '
#  '"command": "info"}')
#
# <=: 10:45:46.550630
# {'response': 'ok', 'seq_num': 55}
#
#
# =>: 10:45:46.550737
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 56, '
#  '"command": "info"}')
#
# <=: 10:45:46.551008
# {'response': 'ok', 'seq_num': 56}
#
#
# =>: 10:45:46.551114
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 57, '
#  '"command": "info"}')
#
# <=: 10:45:46.551382
# {'response': 'ok', 'seq_num': 57}
#
#
# =>: 10:45:46.551486
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 58, '
#  '"command": "info"}')
#
# <=: 10:45:46.551755
# {'response': 'ok', 'seq_num': 58}
#
#
# =>: 10:45:46.551859
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 59, '
#  '"command": "info"}')
#
# <=: 10:45:46.552125
# {'response': 'ok', 'seq_num': 59}
#
#
# =>: 10:45:46.552257
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 60, '
#  '"command": "info"}')
#
# <=: 10:45:46.552644
# {'response': 'ok', 'seq_num': 60}
#
#
# =>: 10:45:46.552827
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 61, '
#  '"command": "info"}')
#
# <=: 10:45:46.553142
# {'response': 'ok', 'seq_num': 61}
#
#
# =>: 10:45:46.553266
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 62, '
#  '"command": "info"}')
#
# <=: 10:45:46.553560
# {'response': 'ok', 'seq_num': 62}
#
#
# =>: 10:45:46.553668
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 63, '
#  '"command": "info"}')
#
# <=: 10:45:46.553944
# {'response': 'ok', 'seq_num': 63}
#
#
# =>: 10:45:46.554049
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 64, '
#  '"command": "info"}')
#
# <=: 10:45:46.554321
# {'response': 'ok', 'seq_num': 64}
#
#
# =>: 10:45:46.554425
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 65, '
#  '"command": "info"}')
#
# <=: 10:45:46.554692
# {'response': 'ok', 'seq_num': 65}
#
#
# =>: 10:45:46.554796
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 66, '
#  '"command": "info"}')
#
# <=: 10:45:46.555066
# {'response': 'ok', 'seq_num': 66}
#
#
# =>: 10:45:46.555170
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 67, '
#  '"command": "info"}')
#
# <=: 10:45:46.555440
# {'response': 'ok', 'seq_num': 67}
#
#
# =>: 10:45:46.555548
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 68, '
#  '"command": "info"}')
#
# <=: 10:45:46.555817
# {'response': 'ok', 'seq_num': 68}
#
#
# =>: 10:45:46.555919
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 69, '
#  '"command": "info"}')
#
# <=: 10:45:46.556188
# {'response': 'ok', 'seq_num': 69}
#
#
# =>: 10:45:46.556292
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 70, '
#  '"command": "info"}')
#
# <=: 10:45:46.556566
# {'response': 'ok', 'seq_num': 70}
#
#
# =>: 10:45:46.556666
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 71, '
#  '"command": "info"}')
#
# <=: 10:45:46.556983
# {'response': 'ok', 'seq_num': 71}
#
#
# =>: 10:45:46.557089
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 72, '
#  '"command": "info"}')
#
# <=: 10:45:46.557443
# {'response': 'ok', 'seq_num': 72}
#
#
# =>: 10:45:46.557561
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 73, '
#  '"command": "info"}')
#
# <=: 10:45:46.557876
# {'response': 'ok', 'seq_num': 73}
#
#
# =>: 10:45:46.558084
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 74, '
#  '"command": "info"}')
#
# <=: 10:45:46.558433
# {'response': 'ok', 'seq_num': 74}
#
#
# =>: 10:45:46.558549
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 75, '
#  '"command": "info"}')
#
# <=: 10:45:46.558822
# {'response': 'ok', 'seq_num': 75}
#
#
# =>: 10:45:46.558929
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 76, '
#  '"command": "info"}')
#
# <=: 10:45:46.559197
# {'response': 'ok', 'seq_num': 76}
#
#
# =>: 10:45:46.559298
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 77, '
#  '"command": "info"}')
#
# <=: 10:45:46.559645
# {'response': 'ok', 'seq_num': 77}
#
#
# =>: 10:45:46.559756
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 78, '
#  '"command": "info"}')
#
# <=: 10:45:46.560044
# {'response': 'ok', 'seq_num': 78}
#
#
# =>: 10:45:46.560157
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 79, '
#  '"command": "info"}')
#
# <=: 10:45:46.560579
# {'response': 'ok', 'seq_num': 79}
#
#
# =>: 10:45:46.560774
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 80, '
#  '"command": "info"}')
#
# <=: 10:45:46.561237
# {'response': 'ok', 'seq_num': 80}
#
#
# =>: 10:45:46.561375
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 81, '
#  '"command": "info"}')
#
# <=: 10:45:46.561717
# {'response': 'ok', 'seq_num': 81}
#
#
# =>: 10:45:46.561836
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 82, '
#  '"command": "info"}')
#
# <=: 10:45:46.562138
# {'response': 'ok', 'seq_num': 82}
#
#
# =>: 10:45:46.562253
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 83, '
#  '"command": "info"}')
#
# <=: 10:45:46.562571
# {'response': 'ok', 'seq_num': 83}
#
#
# =>: 10:45:46.562687
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 84, '
#  '"command": "info"}')
#
# <=: 10:45:46.563005
# {'response': 'ok', 'seq_num': 84}
#
#
# =>: 10:45:46.563117
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 85, '
#  '"command": "info"}')
#
# <=: 10:45:46.563410
# {'response': 'ok', 'seq_num': 85}
#
#
# =>: 10:45:46.563514
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 86, '
#  '"command": "info"}')
#
# <=: 10:45:46.563824
# {'response': 'ok', 'seq_num': 86}
#
#
# =>: 10:45:46.563929
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 87, '
#  '"command": "info"}')
#
# <=: 10:45:46.564221
# {'response': 'ok', 'seq_num': 87}
#
#
# =>: 10:45:46.564325
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 88, '
#  '"command": "info"}')
#
# <=: 10:45:46.564637
# {'response': 'ok', 'seq_num': 88}
#
#
# =>: 10:45:46.564743
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 89, '
#  '"command": "info"}')
#
# <=: 10:45:46.565034
# {'response': 'ok', 'seq_num': 89}
#
#
# =>: 10:45:46.565139
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 90, '
#  '"command": "info"}')
#
# <=: 10:45:46.565446
# {'response': 'ok', 'seq_num': 90}
#
#
# =>: 10:45:46.565551
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 91, '
#  '"command": "info"}')
#
# <=: 10:45:46.565843
# {'response': 'ok', 'seq_num': 91}
#
#
# =>: 10:45:46.565949
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 92, '
#  '"command": "info"}')
#
# <=: 10:45:46.566240
# {'response': 'ok', 'seq_num': 92}
#
#
# =>: 10:45:46.566346
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 93, '
#  '"command": "info"}')
#
# <=: 10:45:46.566642
# {'response': 'ok', 'seq_num': 93}
#
#
# =>: 10:45:46.566745
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 94, '
#  '"command": "info"}')
#
# <=: 10:45:46.567035
# {'response': 'ok', 'seq_num': 94}
#
#
# =>: 10:45:46.567135
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 95, '
#  '"command": "info"}')
#
# <=: 10:45:46.567507
# {'response': 'ok', 'seq_num': 95}
#
#
# =>: 10:45:46.567705
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 96, '
#  '"command": "info"}')
#
# <=: 10:45:46.568221
# {'response': 'ok', 'seq_num': 96}
#
#
# =>: 10:45:46.568536
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 97, '
#  '"command": "info"}')
#
# <=: 10:45:46.569892
# {'response': 'ok', 'seq_num': 97}
#
#
# =>: 10:45:46.570115
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 98, '
#  '"command": "info"}')
#
# <=: 10:45:46.570610
# {'response': 'ok', 'seq_num': 98}
#
#
# =>: 10:45:46.572098
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 99, '
#  '"command": "info"}')
#
# <=: 10:45:46.573191
# {'response': 'ok', 'seq_num': 99}
#
#
# =>: 10:45:46.573481
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 100, '
#  '"command": "info"}')
#
# <=: 10:45:46.574554
# {'response': 'ok', 'seq_num': 100}
#
#
# =>: 10:45:46.574801
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 101, '
#  '"command": "info"}')
#
# <=: 10:45:46.575271
# {'response': 'ok', 'seq_num': 101}
#
#
# =>: 10:45:46.575423
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 102, '
#  '"command": "info"}')
#
# <=: 10:45:46.575781
# {'response': 'ok', 'seq_num': 102}
#
#
# =>: 10:45:46.576064
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 103, '
#  '"command": "info"}')
#
# <=: 10:45:46.576569
# {'response': 'ok', 'seq_num': 103}
#
#
# =>: 10:45:46.576719
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 104, '
#  '"command": "info"}')
#
# <=: 10:45:46.577702
# {'response': 'ok', 'seq_num': 104}
#
#
# =>: 10:45:46.577969
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 105, '
#  '"command": "info"}')
#
# <=: 10:45:46.578521
# {'response': 'ok', 'seq_num': 105}
#
#
# =>: 10:45:46.578676
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 106, '
#  '"command": "info"}')
#
# <=: 10:45:46.579001
# {'response': 'ok', 'seq_num': 106}
#
#
# =>: 10:45:46.579125
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 107, '
#  '"command": "info"}')
#
# <=: 10:45:46.579445
# {'response': 'ok', 'seq_num': 107}
#
#
# =>: 10:45:46.579561
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 108, '
#  '"command": "info"}')
#
# <=: 10:45:46.579844
# {'response': 'ok', 'seq_num': 108}
#
#
# =>: 10:45:46.579953
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 109, '
#  '"command": "info"}')
#
# <=: 10:45:46.580230
# {'response': 'ok', 'seq_num': 109}
#
#
# =>: 10:45:46.580337
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 110, '
#  '"command": "info"}')
#
# <=: 10:45:46.580626
# {'response': 'ok', 'seq_num': 110}
#
#
# =>: 10:45:46.580844
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 111, '
#  '"command": "info"}')
#
# <=: 10:45:46.581708
# {'response': 'ok', 'seq_num': 111}
#
#
# =>: 10:45:46.581865
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 112, '
#  '"command": "info"}')
#
# <=: 10:45:46.582231
# {'response': 'ok', 'seq_num': 112}
#
#
# =>: 10:45:46.582363
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 113, '
#  '"command": "info"}')
#
# <=: 10:45:46.582918
# {'response': 'ok', 'seq_num': 113}
#
#
# =>: 10:45:46.583174
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 114, '
#  '"command": "info"}')
#
# <=: 10:45:46.583559
# {'response': 'ok', 'seq_num': 114}
#
#
# =>: 10:45:46.583686
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 115, '
#  '"command": "info"}')
#
# <=: 10:45:46.584054
# {'response': 'ok', 'seq_num': 115}
#
#
# =>: 10:45:46.584243
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 116, '
#  '"command": "info"}')
#
# <=: 10:45:46.584715
# {'response': 'ok', 'seq_num': 116}
#
#
# =>: 10:45:46.584921
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 117, '
#  '"command": "info"}')
#
# <=: 10:45:46.586633
# {'response': 'ok', 'seq_num': 117}
#
#
# =>: 10:45:46.586918
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 118, '
#  '"command": "info"}')
#
# <=: 10:45:46.587497
# {'response': 'ok', 'seq_num': 118}
#
#
# =>: 10:45:46.587724
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 119, '
#  '"command": "info"}')
#
# <=: 10:45:46.588308
# {'response': 'ok', 'seq_num': 119}
#
#
# =>: 10:45:46.588547
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 120, '
#  '"command": "info"}')
#
# <=: 10:45:46.589171
# {'response': 'ok', 'seq_num': 120}
#
#
# =>: 10:45:46.589403
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 121, '
#  '"command": "info"}')
#
# <=: 10:45:46.589976
# {'response': 'ok', 'seq_num': 121}
#
#
# =>: 10:45:46.590193
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 122, '
#  '"command": "info"}')
#
# <=: 10:45:46.590748
# {'response': 'ok', 'seq_num': 122}
#
#
# =>: 10:45:46.591613
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 123, '
#  '"command": "info"}')
#
# <=: 10:45:46.592754
# {'response': 'ok', 'seq_num': 123}
#
#
# =>: 10:45:46.593041
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 124, '
#  '"command": "info"}')
#
# <=: 10:45:46.593627
# {'response': 'ok', 'seq_num': 124}
#
#
# =>: 10:45:46.593854
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 125, '
#  '"command": "info"}')
#
# <=: 10:45:46.594407
# {'response': 'ok', 'seq_num': 125}
#
#
# =>: 10:45:46.594628
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 126, '
#  '"command": "info"}')
#
# <=: 10:45:46.595224
# {'response': 'ok', 'seq_num': 126}
#
#
# =>: 10:45:46.595465
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 127, '
#  '"command": "info"}')
#
# <=: 10:45:46.596078
# {'response': 'ok', 'seq_num': 127}
#
#
# =>: 10:45:46.596314
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 128, '
#  '"command": "info"}')
#
# <=: 10:45:46.596894
# {'response': 'ok', 'seq_num': 128}
#
#
# =>: 10:45:46.597128
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 129, '
#  '"command": "info"}')
#
# <=: 10:45:46.597678
# {'response': 'ok', 'seq_num': 129}
#
#
# =>: 10:45:46.597910
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 130, '
#  '"command": "info"}')
#
# <=: 10:45:46.598395
# {'response': 'ok', 'seq_num': 130}
#
#
# =>: 10:45:46.598545
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 131, '
#  '"command": "info"}')
#
# <=: 10:45:46.598911
# {'response': 'ok', 'seq_num': 131}
#
#
# =>: 10:45:46.599039
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 132, '
#  '"command": "info"}')
#
# <=: 10:45:46.599358
# {'response': 'ok', 'seq_num': 132}
#
#
# =>: 10:45:46.599470
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 133, '
#  '"command": "info"}')
#
# <=: 10:45:46.599778
# {'response': 'ok', 'seq_num': 133}
#
#
# =>: 10:45:46.599947
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 134, '
#  '"command": "info"}')
#
# <=: 10:45:46.600588
# {'response': 'ok', 'seq_num': 134}
#
#
# =>: 10:45:46.600807
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 135, '
#  '"command": "info"}')
#
# <=: 10:45:46.601322
# {'response': 'ok', 'seq_num': 135}
#
#
# =>: 10:45:46.601516
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 136, '
#  '"command": "info"}')
#
# <=: 10:45:46.601971
# {'response': 'ok', 'seq_num': 136}
#
#
# =>: 10:45:46.602112
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 137, '
#  '"command": "info"}')
#
# <=: 10:45:46.602433
# {'response': 'ok', 'seq_num': 137}
#
#
# =>: 10:45:46.602550
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 138, '
#  '"command": "info"}')
#
# <=: 10:45:46.602869
# {'response': 'ok', 'seq_num': 138}
#
#
# =>: 10:45:46.602983
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 139, '
#  '"command": "info"}')
#
# <=: 10:45:46.603289
# {'response': 'ok', 'seq_num': 139}
#
#
# =>: 10:45:46.603399
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 140, '
#  '"command": "info"}')
#
# <=: 10:45:46.604359
# {'response': 'ok', 'seq_num': 140}
#
#
# =>: 10:45:46.604583
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 141, '
#  '"command": "info"}')
#
# <=: 10:45:46.605058
# {'response': 'ok', 'seq_num': 141}
#
#
# =>: 10:45:46.605249
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 142, '
#  '"command": "info"}')
#
# <=: 10:45:46.605688
# {'response': 'ok', 'seq_num': 142}
#
#
# =>: 10:45:46.606054
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 143, '
#  '"command": "info"}')
#
# <=: 10:45:46.606539
# {'response': 'ok', 'seq_num': 143}
#
#
# =>: 10:45:46.606737
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 144, '
#  '"command": "info"}')
#
# <=: 10:45:46.607169
# {'response': 'ok', 'seq_num': 144}
#
#
# =>: 10:45:46.607373
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 145, '
#  '"command": "info"}')
#
# <=: 10:45:46.608401
# {'response': 'ok', 'seq_num': 145}
#
#
# =>: 10:45:46.608563
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 146, '
#  '"command": "info"}')
#
# <=: 10:45:46.608910
# {'response': 'ok', 'seq_num': 146}
#
#
# =>: 10:45:46.609062
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 147, '
#  '"command": "info"}')
#
# <=: 10:45:46.609413
# {'response': 'ok', 'seq_num': 147}
#
#
# =>: 10:45:46.609600
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 148, '
#  '"command": "info"}')
#
# <=: 10:45:46.609922
# {'response': 'ok', 'seq_num': 148}
#
#
# =>: 10:45:46.610042
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 149, '
#  '"command": "info"}')
#
# <=: 10:45:46.610334
# {'response': 'ok', 'seq_num': 149}
#
#
# =>: 10:45:46.610444
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 150, '
#  '"command": "info"}')
#
# <=: 10:45:46.610715
# {'response': 'ok', 'seq_num': 150}
#
#
# =>: 10:45:46.610820
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 151, '
#  '"command": "info"}')
#
# <=: 10:45:46.611103
# {'response': 'ok', 'seq_num': 151}
#
#
# =>: 10:45:46.611320
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 152, '
#  '"command": "info"}')
#
# <=: 10:45:46.611790
# {'response': 'ok', 'seq_num': 152}
#
#
# =>: 10:45:46.611985
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 153, '
#  '"command": "info"}')
#
# <=: 10:45:46.612522
# {'response': 'ok', 'seq_num': 153}
#
#
# =>: 10:45:46.612723
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 154, '
#  '"command": "info"}')
#
# <=: 10:45:46.613231
# {'response': 'ok', 'seq_num': 154}
#
#
# =>: 10:45:46.613427
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 155, '
#  '"command": "info"}')
#
# <=: 10:45:46.613938
# {'response': 'ok', 'seq_num': 155}
#
#
# =>: 10:45:46.614129
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 156, '
#  '"command": "info"}')
#
# <=: 10:45:46.614645
# {'response': 'ok', 'seq_num': 156}
#
#
# =>: 10:45:46.614847
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 157, '
#  '"command": "info"}')
#
# <=: 10:45:46.615428
# {'response': 'ok', 'seq_num': 157}
#
#
# =>: 10:45:46.615679
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 158, '
#  '"command": "info"}')
#
# <=: 10:45:46.616289
# {'response': 'ok', 'seq_num': 158}
#
#
# =>: 10:45:46.616524
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 159, '
#  '"command": "info"}')
#
# <=: 10:45:46.616946
# {'response': 'ok', 'seq_num': 159}
#
#
# =>: 10:45:46.617085
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 160, '
#  '"command": "info"}')
#
# <=: 10:45:46.617393
# {'response': 'ok', 'seq_num': 160}
#
#
# =>: 10:45:46.617510
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 161, '
#  '"command": "info"}')
#
# <=: 10:45:46.618016
# {'response': 'ok', 'seq_num': 161}
#
#
# =>: 10:45:46.618252
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 162, '
#  '"command": "info"}')
#
# <=: 10:45:46.620068
# {'response': 'ok', 'seq_num': 162}
#
#
# =>: 10:45:46.620365
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 163, '
#  '"command": "info"}')
#
# <=: 10:45:46.620996
# {'response': 'ok', 'seq_num': 163}
#
#
# =>: 10:45:46.621233
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 164, '
#  '"command": "info"}')
#
# <=: 10:45:46.622157
# {'response': 'ok', 'seq_num': 164}
#
#
# =>: 10:45:46.622456
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 165, '
#  '"command": "info"}')
#
# <=: 10:45:46.623290
# {'response': 'ok', 'seq_num': 165}
#
#
# =>: 10:45:46.623569
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 166, '
#  '"command": "info"}')
#
# <=: 10:45:46.624290
# {'response': 'ok', 'seq_num': 166}
#
#
# =>: 10:45:46.624571
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 167, '
#  '"command": "info"}')
#
# <=: 10:45:46.625121
# {'response': 'ok', 'seq_num': 167}
#
#
# =>: 10:45:46.625347
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 168, '
#  '"command": "info"}')
#
# <=: 10:45:46.625802
# {'response': 'ok', 'seq_num': 168}
#
#
# =>: 10:45:46.625945
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 169, '
#  '"command": "info"}')
#
# <=: 10:45:46.626259
# {'response': 'ok', 'seq_num': 169}
#
#
# =>: 10:45:46.626382
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 170, '
#  '"command": "info"}')
#
# <=: 10:45:46.626671
# {'response': 'ok', 'seq_num': 170}
#
#
# =>: 10:45:46.626785
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 171, '
#  '"command": "info"}')
#
# <=: 10:45:46.627068
# {'response': 'ok', 'seq_num': 171}
#
#
# =>: 10:45:46.627178
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 172, '
#  '"command": "info"}')
#
# <=: 10:45:46.627571
# {'response': 'ok', 'seq_num': 172}
#
#
# =>: 10:45:46.627771
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 173, '
#  '"command": "info"}')
#
# <=: 10:45:46.628305
# {'response': 'ok', 'seq_num': 173}
#
#
# =>: 10:45:46.628448
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 174, '
#  '"command": "info"}')
#
# <=: 10:45:46.628759
# {'response': 'ok', 'seq_num': 174}
#
#
# =>: 10:45:46.628879
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 175, '
#  '"command": "info"}')
#
# <=: 10:45:46.629171
# {'response': 'ok', 'seq_num': 175}
#
#
# =>: 10:45:46.629281
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 176, '
#  '"command": "info"}')
#
# <=: 10:45:46.629553
# {'response': 'ok', 'seq_num': 176}
#
#
# =>: 10:45:46.629658
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 177, '
#  '"command": "info"}')
#
# <=: 10:45:46.629928
# {'response': 'ok', 'seq_num': 177}
#
#
# =>: 10:45:46.630034
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 178, '
#  '"command": "info"}')
#
# <=: 10:45:46.630304
# {'response': 'ok', 'seq_num': 178}
#
#
# =>: 10:45:46.630410
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 179, '
#  '"command": "info"}')
#
# <=: 10:45:46.630684
# {'response': 'ok', 'seq_num': 179}
#
#
# =>: 10:45:46.630788
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 180, '
#  '"command": "info"}')
#
# <=: 10:45:46.631157
# {'response': 'ok', 'seq_num': 180}
#
#
# =>: 10:45:46.631349
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 181, '
#  '"command": "info"}')
#
# <=: 10:45:46.631786
# {'response': 'ok', 'seq_num': 181}
#
#
# =>: 10:45:46.631915
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 182, '
#  '"command": "info"}')
#
# <=: 10:45:46.632216
# {'response': 'ok', 'seq_num': 182}
#
#
# =>: 10:45:46.632332
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 183, '
#  '"command": "info"}')
#
# <=: 10:45:46.632646
# {'response': 'ok', 'seq_num': 183}
#
#
# =>: 10:45:46.632756
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 184, '
#  '"command": "info"}')
#
# <=: 10:45:46.633040
# {'response': 'ok', 'seq_num': 184}
#
#
# =>: 10:45:46.633148
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 185, '
#  '"command": "info"}')
#
# <=: 10:45:46.633421
# {'response': 'ok', 'seq_num': 185}
#
#
# =>: 10:45:46.633525
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 186, '
#  '"command": "info"}')
#
# <=: 10:45:46.633819
# {'response': 'ok', 'seq_num': 186}
#
#
# =>: 10:45:46.633922
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 187, '
#  '"command": "info"}')
#
# <=: 10:45:46.634188
# {'response': 'ok', 'seq_num': 187}
#
#
# =>: 10:45:46.634291
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 188, '
#  '"command": "info"}')
#
# <=: 10:45:46.634564
# {'response': 'ok', 'seq_num': 188}
#
#
# =>: 10:45:46.634740
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 189, '
#  '"command": "info"}')
#
# <=: 10:45:46.635207
# {'response': 'ok', 'seq_num': 189}
#
#
# =>: 10:45:46.635445
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 190, '
#  '"command": "info"}')
#
# <=: 10:45:46.635933
# {'response': 'ok', 'seq_num': 190}
#
#
# =>: 10:45:46.636123
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 191, '
#  '"command": "info"}')
#
# <=: 10:45:46.636558
# {'response': 'ok', 'seq_num': 191}
#
#
# =>: 10:45:46.636691
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 192, '
#  '"command": "info"}')
#
# <=: 10:45:46.637017
# {'response': 'ok', 'seq_num': 192}
#
#
# =>: 10:45:46.637140
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 193, '
#  '"command": "info"}')
#
# <=: 10:45:46.637448
# {'response': 'ok', 'seq_num': 193}
#
#
# =>: 10:45:46.637556
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 194, '
#  '"command": "info"}')
#
# <=: 10:45:46.637856
# {'response': 'ok', 'seq_num': 194}
#
#
# =>: 10:45:46.637963
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 195, '
#  '"command": "info"}')
#
# <=: 10:45:46.638257
# {'response': 'ok', 'seq_num': 195}
#
#
# =>: 10:45:46.638360
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 196, '
#  '"command": "info"}')
#
# <=: 10:45:46.638650
# {'response': 'ok', 'seq_num': 196}
#
#
# =>: 10:45:46.638752
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 197, '
#  '"command": "info"}')
#
# <=: 10:45:46.639056
# {'response': 'ok', 'seq_num': 197}
#
#
# =>: 10:45:46.639266
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 198, '
#  '"command": "info"}')
#
# <=: 10:45:46.639774
# {'response': 'ok', 'seq_num': 198}
#
#
# =>: 10:45:46.639965
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 199, '
#  '"command": "info"}')
#
# <=: 10:45:46.640492
# {'response': 'ok', 'seq_num': 199}
#
#
# =>: 10:45:46.640715
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 200, '
#  '"command": "info"}')
#
# <=: 10:45:46.641252
# {'response': 'ok', 'seq_num': 200}
#
#
# =>: 10:45:46.641497
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 201, '
#  '"command": "info"}')
#
# <=: 10:45:46.641973
# {'response': 'ok', 'seq_num': 201}
#
#
# =>: 10:45:46.642101
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 202, '
#  '"command": "info"}')
#
# <=: 10:45:46.642393
# {'response': 'ok', 'seq_num': 202}
#
#
# =>: 10:45:46.642508
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 203, '
#  '"command": "info"}')
#
# <=: 10:45:46.642843
# {'response': 'ok', 'seq_num': 203}
#
#
# =>: 10:45:46.642954
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 204, '
#  '"command": "info"}')
#
# <=: 10:45:46.643228
# {'response': 'ok', 'seq_num': 204}
#
#
# =>: 10:45:46.643334
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 205, '
#  '"command": "info"}')
#
# <=: 10:45:46.643603
# {'response': 'ok', 'seq_num': 205}
#
#
# =>: 10:45:46.643776
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 206, '
#  '"command": "info"}')
#
# <=: 10:45:46.644278
# {'response': 'ok', 'seq_num': 206}
#
#
# =>: 10:45:46.644460
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 207, '
#  '"command": "info"}')
#
# <=: 10:45:46.644772
# {'response': 'ok', 'seq_num': 207}
#
#
# =>: 10:45:46.644890
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 208, '
#  '"command": "info"}')
#
# <=: 10:45:46.645171
# {'response': 'ok', 'seq_num': 208}
#
#
# =>: 10:45:46.645278
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 209, '
#  '"command": "info"}')
#
# <=: 10:45:46.645554
# {'response': 'ok', 'seq_num': 209}
#
#
# =>: 10:45:46.645658
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 210, '
#  '"command": "info"}')
#
# <=: 10:45:46.645922
# {'response': 'ok', 'seq_num': 210}
#
#
# =>: 10:45:46.646025
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 211, '
#  '"command": "info"}')
#
# <=: 10:45:46.646283
# {'response': 'ok', 'seq_num': 211}
#
#
# =>: 10:45:46.646388
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 212, '
#  '"command": "info"}')
#
# <=: 10:45:46.646649
# {'response': 'ok', 'seq_num': 212}
#
#
# =>: 10:45:46.646751
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 213, '
#  '"command": "info"}')
#
# <=: 10:45:46.647012
# {'response': 'ok', 'seq_num': 213}
#
#
# =>: 10:45:46.647114
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 214, '
#  '"command": "info"}')
#
# <=: 10:45:46.647377
# {'response': 'ok', 'seq_num': 214}
#
#
# =>: 10:45:46.647642
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 215, '
#  '"command": "info"}')
#
# <=: 10:45:46.648300
# {'response': 'ok', 'seq_num': 215}
#
#
# =>: 10:45:46.648546
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 216, '
#  '"command": "info"}')
#
# <=: 10:45:46.649174
# {'response': 'ok', 'seq_num': 216}
#
#
# =>: 10:45:46.649406
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 217, '
#  '"command": "info"}')
#
# <=: 10:45:46.649946
# {'response': 'ok', 'seq_num': 217}
#
#
# =>: 10:45:46.650092
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 218, '
#  '"command": "info"}')
#
# <=: 10:45:46.650405
# {'response': 'ok', 'seq_num': 218}
#
#
# =>: 10:45:46.650523
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 219, '
#  '"command": "info"}')
#
# <=: 10:45:46.650845
# {'response': 'ok', 'seq_num': 219}
#
#
# =>: 10:45:46.650963
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 220, '
#  '"command": "info"}')
#
# <=: 10:45:46.651243
# {'response': 'ok', 'seq_num': 220}
#
#
# =>: 10:45:46.651351
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 221, '
#  '"command": "info"}')
#
# <=: 10:45:46.651670
# {'response': 'ok', 'seq_num': 221}
#
#
# =>: 10:45:46.651845
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 222, '
#  '"command": "info"}')
#
# <=: 10:45:46.652316
# {'response': 'ok', 'seq_num': 222}
#
#
# =>: 10:45:46.652451
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 223, '
#  '"command": "info"}')
#
# <=: 10:45:46.652783
# {'response': 'ok', 'seq_num': 223}
#
#
# =>: 10:45:46.652900
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 224, '
#  '"command": "info"}')
#
# <=: 10:45:46.653213
# {'response': 'ok', 'seq_num': 224}
#
#
# =>: 10:45:46.653324
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 225, '
#  '"command": "info"}')
#
# <=: 10:45:46.653630
# {'response': 'ok', 'seq_num': 225}
#
#
# =>: 10:45:46.653740
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 226, '
#  '"command": "info"}')
#
# <=: 10:45:46.654049
# {'response': 'ok', 'seq_num': 226}
#
#
# =>: 10:45:46.654155
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 227, '
#  '"command": "info"}')
#
# <=: 10:45:46.654463
# {'response': 'ok', 'seq_num': 227}
#
#
# =>: 10:45:46.654568
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 228, '
#  '"command": "info"}')
#
# <=: 10:45:46.654888
# {'response': 'ok', 'seq_num': 228}
#
#
# =>: 10:45:46.654994
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 229, '
#  '"command": "info"}')
#
# <=: 10:45:46.655295
# {'response': 'ok', 'seq_num': 229}
#
#
# =>: 10:45:46.655398
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 230, '
#  '"command": "info"}')
#
# <=: 10:45:46.655885
# {'response': 'ok', 'seq_num': 230}
#
#
# =>: 10:45:46.656109
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 231, '
#  '"command": "info"}')
#
# <=: 10:45:46.656442
# {'response': 'ok', 'seq_num': 231}
#
#
# =>: 10:45:46.656566
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 232, '
#  '"command": "info"}')
#
# <=: 10:45:46.656860
# {'response': 'ok', 'seq_num': 232}
#
#
# =>: 10:45:46.656972
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 233, '
#  '"command": "info"}')
#
# <=: 10:45:46.657287
# {'response': 'ok', 'seq_num': 233}
#
#
# =>: 10:45:46.657398
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 234, '
#  '"command": "info"}')
#
# <=: 10:45:46.657670
# {'response': 'ok', 'seq_num': 234}
#
#
# =>: 10:45:46.657776
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 235, '
#  '"command": "info"}')
#
# <=: 10:45:46.658065
# {'response': 'ok', 'seq_num': 235}
#
#
# =>: 10:45:46.658173
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 236, '
#  '"command": "info"}')
#
# <=: 10:45:46.658439
# {'response': 'ok', 'seq_num': 236}
#
#
# =>: 10:45:46.658544
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 237, '
#  '"command": "info"}')
#
# <=: 10:45:46.658804
# {'response': 'ok', 'seq_num': 237}
#
#
# =>: 10:45:46.658906
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 238, '
#  '"command": "info"}')
#
# <=: 10:45:46.659171
# {'response': 'ok', 'seq_num': 238}
#
#
# =>: 10:45:46.659299
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 239, '
#  '"command": "info"}')
#
# <=: 10:45:46.659747
# {'response': 'ok', 'seq_num': 239}
#
#
# =>: 10:45:46.659984
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 240, '
#  '"command": "info"}')
#
# <=: 10:45:46.660514
# {'response': 'ok', 'seq_num': 240}
#
#
# =>: 10:45:46.660713
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 241, '
#  '"command": "info"}')
#
# <=: 10:45:46.661772
# {'response': 'ok', 'seq_num': 241}
#
#
# =>: 10:45:46.661928
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 242, '
#  '"command": "info"}')
#
# <=: 10:45:46.662287
# {'response': 'ok', 'seq_num': 242}
#
#
# =>: 10:45:46.662424
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 243, '
#  '"command": "info"}')
#
# <=: 10:45:46.662765
# {'response': 'ok', 'seq_num': 243}
#
#
# =>: 10:45:46.662883
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 244, '
#  '"command": "info"}')
#
# <=: 10:45:46.663204
# {'response': 'ok', 'seq_num': 244}
#
#
# =>: 10:45:46.663316
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 245, '
#  '"command": "info"}')
#
# <=: 10:45:46.663621
# {'response': 'ok', 'seq_num': 245}
#
#
# =>: 10:45:46.663769
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 246, '
#  '"command": "info"}')
#
# <=: 10:45:46.664210
# {'response': 'ok', 'seq_num': 246}
#
#
# =>: 10:45:46.664404
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 247, '
#  '"command": "info"}')
#
# <=: 10:45:46.664946
# {'response': 'ok', 'seq_num': 247}
#
#
# =>: 10:45:46.665137
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 248, '
#  '"command": "info"}')
#
# <=: 10:45:46.665786
# {'response': 'ok', 'seq_num': 248}
#
#
# =>: 10:45:46.666002
# ...
#  '"command": "info"}')
#
# <=: 10:45:46.718673
# {'response': 'ok', 'seq_num': 343}
#
#
# =>: 10:45:46.718779
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 344, '
#  '"command": "info"}')
#
# <=: 10:45:46.719087
# {'response': 'ok', 'seq_num': 344}
#
#
# =>: 10:45:46.719191
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 345, '
#  '"command": "info"}')
#
# <=: 10:45:46.719490
# {'response': 'ok', 'seq_num': 345}
#
#
# =>: 10:45:46.719594
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 346, '
#  '"command": "info"}')
#
# <=: 10:45:46.719897
# {'response': 'ok', 'seq_num': 346}
#
#
# =>: 10:45:46.720008
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 347, '
#  '"command": "info"}')
#
# <=: 10:45:46.720307
# {'response': 'ok', 'seq_num': 347}
#
#
# =>: 10:45:46.720413
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 348, '
#  '"command": "info"}')
#
# <=: 10:45:46.720718
# {'response': 'ok', 'seq_num': 348}
#
#
# =>: 10:45:46.720897
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 349, '
#  '"command": "info"}')
#
# <=: 10:45:46.721489
# {'response': 'ok', 'seq_num': 349}
#
#
# =>: 10:45:46.721725
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 350, '
#  '"command": "info"}')
#
# <=: 10:45:46.722080
# {'response': 'ok', 'seq_num': 350}
#
#
# =>: 10:45:46.722229
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 351, '
#  '"command": "info"}')
#
# <=: 10:45:46.722590
# {'response': 'ok', 'seq_num': 351}
#
#
# =>: 10:45:46.722711
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 352, '
#  '"command": "info"}')
#
# <=: 10:45:46.723078
# {'response': 'ok', 'seq_num': 352}
#
#
# =>: 10:45:46.723192
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 353, '
#  '"command": "info"}')
#
# <=: 10:45:46.723532
# {'response': 'ok', 'seq_num': 353}
#
#
# =>: 10:45:46.723644
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 354, '
#  '"command": "info"}')
#
# <=: 10:45:46.723987
# {'response': 'ok', 'seq_num': 354}
#
#
# =>: 10:45:46.724096
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 355, '
#  '"command": "info"}')
#
# <=: 10:45:46.724436
# {'response': 'ok', 'seq_num': 355}
#
#
# =>: 10:45:46.724610
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 356, '
#  '"command": "info"}')
#
# <=: 10:45:46.724923
# {'response': 'ok', 'seq_num': 356}
#
#
# =>: 10:45:46.725035
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 357, '
#  '"command": "info"}')
#
# <=: 10:45:46.725317
# {'response': 'ok', 'seq_num': 357}
#
#
# =>: 10:45:46.725424
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 358, '
#  '"command": "info"}')
#
# <=: 10:45:46.725709
# {'response': 'ok', 'seq_num': 358}
#
#
# =>: 10:45:46.725816
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 359, '
#  '"command": "info"}')
#
# <=: 10:45:46.726093
# {'response': 'ok', 'seq_num': 359}
#
#
# =>: 10:45:46.726209
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 360, '
#  '"command": "info"}')
#
# <=: 10:45:46.726509
# {'response': 'ok', 'seq_num': 360}
#
#
# =>: 10:45:46.726621
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 361, '
#  '"command": "info"}')
#
# <=: 10:45:46.726949
# {'response': 'ok', 'seq_num': 361}
#
#
# =>: 10:45:46.727058
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 362, '
#  '"command": "info"}')
#
# <=: 10:45:46.727450
# {'response': 'ok', 'seq_num': 362}
#
#
# =>: 10:45:46.727562
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 363, '
#  '"command": "info"}')
#
# <=: 10:45:46.727904
# {'response': 'ok', 'seq_num': 363}
#
#
# =>: 10:45:46.728012
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 364, '
#  '"command": "info"}')
#
# <=: 10:45:46.728319
# {'response': 'ok', 'seq_num': 364}
#
#
# =>: 10:45:46.728439
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 365, '
#  '"command": "info"}')
#
# <=: 10:45:46.728736
# {'response': 'ok', 'seq_num': 365}
#
#
# =>: 10:45:46.728843
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 366, '
#  '"command": "info"}')
#
# <=: 10:45:46.729123
# {'response': 'ok', 'seq_num': 366}
#
#
# =>: 10:45:46.729250
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 367, '
#  '"command": "info"}')
#
# <=: 10:45:46.729546
# {'response': 'ok', 'seq_num': 367}
#
#
# =>: 10:45:46.729656
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 368, '
#  '"command": "info"}')
#
# <=: 10:45:46.729937
# {'response': 'ok', 'seq_num': 368}
#
#
# =>: 10:45:46.730048
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 369, '
#  '"command": "info"}')
#
# <=: 10:45:46.730372
# {'response': 'ok', 'seq_num': 369}
#
#
# =>: 10:45:46.730497
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 370, '
#  '"command": "info"}')
#
# <=: 10:45:46.730865
# {'response': 'ok', 'seq_num': 370}
#
#
# =>: 10:45:46.731001
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 371, '
#  '"command": "info"}')
#
# <=: 10:45:46.731463
# {'response': 'ok', 'seq_num': 371}
#
#
# =>: 10:45:46.731613
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 372, '
#  '"command": "info"}')
#
# <=: 10:45:46.732035
# {'response': 'ok', 'seq_num': 372}
#
#
# =>: 10:45:46.732256
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 373, '
#  '"command": "info"}')
#
# <=: 10:45:46.732638
# {'response': 'ok', 'seq_num': 373}
#
#
# =>: 10:45:46.732774
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 374, '
#  '"command": "info"}')
#
# <=: 10:45:46.733114
# {'response': 'ok', 'seq_num': 374}
#
#
# =>: 10:45:46.733249
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 375, '
#  '"command": "info"}')
#
# <=: 10:45:46.733561
# {'response': 'ok', 'seq_num': 375}
#
#
# =>: 10:45:46.733686
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 376, '
#  '"command": "info"}')
#
# <=: 10:45:46.733987
# {'response': 'ok', 'seq_num': 376}
#
#
# =>: 10:45:46.734134
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 377, '
#  '"command": "info"}')
#
# <=: 10:45:46.734462
# {'response': 'ok', 'seq_num': 377}
#
#
# =>: 10:45:46.734593
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 378, '
#  '"command": "info"}')
#
# <=: 10:45:46.734913
# {'response': 'ok', 'seq_num': 378}
#
#
# =>: 10:45:46.735042
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 379, '
#  '"command": "info"}')
#
# <=: 10:45:46.735360
# {'response': 'ok', 'seq_num': 379}
#
#
# =>: 10:45:46.735487
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 380, '
#  '"command": "info"}')
#
# <=: 10:45:46.735791
# {'response': 'ok', 'seq_num': 380}
#
#
# =>: 10:45:46.735909
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 381, '
#  '"command": "info"}')
#
# <=: 10:45:46.736201
# {'response': 'ok', 'seq_num': 381}
#
#
# =>: 10:45:46.736314
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 382, '
#  '"command": "info"}')
#
# <=: 10:45:46.736603
# {'response': 'ok', 'seq_num': 382}
#
#
# =>: 10:45:46.736724
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 383, '
#  '"command": "info"}')
#
# <=: 10:45:46.737013
# {'response': 'ok', 'seq_num': 383}
#
#
# =>: 10:45:46.737122
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 384, '
#  '"command": "info"}')
#
# <=: 10:45:46.737513
# {'response': 'ok', 'seq_num': 384}
#
#
# =>: 10:45:46.737641
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 385, '
#  '"command": "info"}')
#
# <=: 10:45:46.737995
# {'response': 'ok', 'seq_num': 385}
#
#
# =>: 10:45:46.738160
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 386, '
#  '"command": "info"}')
#
# <=: 10:45:46.738518
# {'response': 'ok', 'seq_num': 386}
#
#
# =>: 10:45:46.738646
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 387, '
#  '"command": "info"}')
#
# <=: 10:45:46.738998
# {'response': 'ok', 'seq_num': 387}
#
#
# =>: 10:45:46.739151
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 388, '
#  '"command": "info"}')
#
# <=: 10:45:46.739703
# {'response': 'ok', 'seq_num': 388}
#
#
# =>: 10:45:46.739876
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 389, '
#  '"command": "info"}')
#
# <=: 10:45:46.740218
# {'response': 'ok', 'seq_num': 389}
#
#
# =>: 10:45:46.740348
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 390, '
#  '"command": "info"}')
#
# <=: 10:45:46.740661
# {'response': 'ok', 'seq_num': 390}
#
#
# =>: 10:45:46.740783
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 391, '
#  '"command": "info"}')
#
# <=: 10:45:46.741089
# {'response': 'ok', 'seq_num': 391}
#
#
# =>: 10:45:46.741208
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 392, '
#  '"command": "info"}')
#
# <=: 10:45:46.741691
# {'response': 'ok', 'seq_num': 392}
#
#
# =>: 10:45:46.741848
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 393, '
#  '"command": "info"}')
#
# <=: 10:45:46.742192
# {'response': 'ok', 'seq_num': 393}
#
#
# =>: 10:45:46.742331
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 394, '
#  '"command": "info"}')
#
# <=: 10:45:46.742789
# {'response': 'ok', 'seq_num': 394}
#
#
# =>: 10:45:46.742949
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 395, '
#  '"command": "info"}')
#
# <=: 10:45:46.743304
# {'response': 'ok', 'seq_num': 395}
#
#
# =>: 10:45:46.743427
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 396, '
#  '"command": "info"}')
#
# <=: 10:45:46.743715
# {'response': 'ok', 'seq_num': 396}
#
#
# =>: 10:45:46.743847
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 397, '
#  '"command": "info"}')
#
# <=: 10:45:46.744143
# {'response': 'ok', 'seq_num': 397}
#
#
# =>: 10:45:46.744258
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 398, '
#  '"command": "info"}')
#
# <=: 10:45:46.744832
# {'response': 'ok', 'seq_num': 398}
#
#
# =>: 10:45:46.744969
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 399, '
#  '"command": "info"}')
#
# <=: 10:45:46.746226
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 10:45:46.746389
# {'response': 'ok', 'seq_num': 399}
#
#
# =>: 10:45:46.746507
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 400, '
#  '"command": "info"}')
#
# <=: 10:45:46.747490
# {'response': 'ok', 'seq_num': 400}
#
#
# =>: 10:45:46.756513
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 401, '
#  '"command": "info"}')
#
# <=: 10:45:46.757158
# {'response': 'ok', 'seq_num': 401}
#
#
# =>: 10:45:46.757397
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 402, '
#  '"command": "info"}')
#
# <=: 10:45:46.758074
# {'response': 'ok', 'seq_num': 402}
#
#
# =>: 10:45:46.758224
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 403, '
#  '"command": "info"}')
#
# <=: 10:45:46.760893
# {'response': 'ok', 'seq_num': 403}
#
#
# =>: 10:45:46.761086
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 404, '
#  '"command": "info"}')
#
# <=: 10:45:46.762074
# {'response': 'ok', 'seq_num': 404}
#
#
# =>: 10:45:46.762226
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 405, '
#  '"command": "info"}')
#
# <=: 10:45:46.762698
# {'response': 'ok', 'seq_num': 405}
#
#
# =>: 10:45:46.762886
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 406, '
#  '"command": "info"}')
#
# <=: 10:45:46.763308
# {'response': 'ok', 'seq_num': 406}
#
#
# =>: 10:45:46.763496
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 407, '
#  '"command": "info"}')
#
# <=: 10:45:46.763910
# {'response': 'ok', 'seq_num': 407}
#
#
# =>: 10:45:46.764100
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 408, '
#  '"command": "info"}')
#
# <=: 10:45:46.764505
# {'response': 'ok', 'seq_num': 408}
#
#
# =>: 10:45:46.764685
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 409, '
#  '"command": "info"}')
#
# <=: 10:45:46.765156
# {'response': 'ok', 'seq_num': 409}
#
#
# =>: 10:45:46.765351
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 410, '
#  '"command": "info"}')
#
# <=: 10:45:46.765847
# {'response': 'ok', 'seq_num': 410}
#
#
# =>: 10:45:46.766069
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 411, '
#  '"command": "info"}')
#
# <=: 10:45:46.766517
# {'response': 'ok', 'seq_num': 411}
#
#
# =>: 10:45:46.766694
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 412, '
#  '"command": "info"}')
#
# <=: 10:45:46.767168
# {'response': 'ok', 'seq_num': 412}
#
#
# =>: 10:45:46.767349
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 413, '
#  '"command": "info"}')
#
# <=: 10:45:46.768225
# {'response': 'ok', 'seq_num': 413}
#
#
# =>: 10:45:46.768451
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 414, '
#  '"command": "info"}')
#
# <=: 10:45:46.768935
# {'response': 'ok', 'seq_num': 414}
#
#
# =>: 10:45:46.769129
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 415, '
#  '"command": "info"}')
#
# <=: 10:45:46.769761
# {'response': 'ok', 'seq_num': 415}
#
#
# =>: 10:45:46.770356
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 416, '
#  '"command": "info"}')
#
# <=: 10:45:46.771568
# {'response': 'ok', 'seq_num': 416}
#
#
# =>: 10:45:46.771799
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 417, '
#  '"command": "info"}')
#
# <=: 10:45:46.772510
# {'response': 'ok', 'seq_num': 417}
#
#
# =>: 10:45:46.772694
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 418, '
#  '"command": "info"}')
#
# <=: 10:45:46.773146
# {'response': 'ok', 'seq_num': 418}
#
#
# =>: 10:45:46.773293
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 419, '
#  '"command": "info"}')
#
# <=: 10:45:46.774125
# {'response': 'ok', 'seq_num': 419}
#
#
# =>: 10:45:46.774331
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 420, '
#  '"command": "info"}')
#
# <=: 10:45:46.778524
# {'response': 'ok', 'seq_num': 420}
#
#
# =>: 10:45:46.778759
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 421, '
#  '"command": "info"}')
#
# <=: 10:45:46.779152
# {'response': 'ok', 'seq_num': 421}
#
#
# =>: 10:45:46.779278
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 422, '
#  '"command": "info"}')
#
# <=: 10:45:46.779633
# {'response': 'ok', 'seq_num': 422}
#
#
# =>: 10:45:46.779761
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 423, '
#  '"command": "info"}')
#
# <=: 10:45:46.780939
# {'response': 'ok', 'seq_num': 423}
#
#
# =>: 10:45:46.781177
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 424, '
#  '"command": "info"}')
#
# <=: 10:45:46.781847
# {'response': 'ok', 'seq_num': 424}
#
#
# =>: 10:45:46.782043
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 425, '
#  '"command": "info"}')
#
# <=: 10:45:46.782417
# {'response': 'ok', 'seq_num': 425}
#
#
# =>: 10:45:46.782557
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 426, '
#  '"command": "info"}')
#
# <=: 10:45:46.782870
# {'response': 'ok', 'seq_num': 426}
#
#
# =>: 10:45:46.782988
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 427, '
#  '"command": "info"}')
#
# <=: 10:45:46.790055
# {'response': 'ok', 'seq_num': 427}
#
#
# =>: 10:45:46.790290
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 428, '
#  '"command": "info"}')
#
# <=: 10:45:46.790722
# {'response': 'ok', 'seq_num': 428}
#
#
# =>: 10:45:46.790843
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 429, '
#  '"command": "info"}')
#
# <=: 10:45:46.793254
# {'response': 'ok', 'seq_num': 429}
#
#
# =>: 10:45:46.793475
# ('{"line": 1, "column": 0, "file_name": "dummy.lean", "seq_num": 430, '
#  '"command": "info"}')
#
# <=: 10:45:46.793698
# {'msgs': [{'caption': 'trace output',
#            'file_name': 'fake_lean_file1.lean',
#            'pos_col': 0,
#            'pos_line': 70,
#            'severity': 'information',
#            'text': 'Goals: 0\n\n\n'},
#           {'caption': 'trace output',
#            'file_name': 'fake_lean_file1.lean',
#            'pos_col': 0,
#            'pos_line': 71,
#            'severity': 'information',
#            'text': '\n'},
#           {'caption': 'eval result',
#            'end_pos_col': 7,
#            'end_pos_line': 75,
#            'file_name': 'fake_lean_file1.lean',
#            'pos_col': 0,
#            'pos_line': 75,
#            'severity': 'information',
#            'text': '1'}],
#  'response': 'all_messages'}
#
# <=: 10:45:46.794591
# {'response': 'ok', 'seq_num': 430}
# ('success', [], '')

# %%
# lots of examples
with LeanTacticTestingInterface() as lean_interface:
    goal1 = LeanGoal([], ['p q : Prop'],  'p = p')
    display(lean_interface.apply_tactic(goal1, 'refl'))
    display(lean_interface.apply_tactic(goal1, 'skip'))
    display(lean_interface.apply_tactic(goal1, 'done'))
    display(lean_interface.apply_tactic(goal1, 'abc123'))
    goal2 = LeanGoal([], ['n m : nat'],  'n = n')
    display(lean_interface.apply_tactic(goal2, 'induction n'))
    goal3 = LeanGoal([], [], 'abc = xyz')
    display(lean_interface.apply_tactic(goal3, 'skip'))
    display(lean_interface.apply_tactic(goal3, 'fgh'))
# Out:
# ('success', [], '')
# ('success',
#  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop'], conclusion='@eq.{1} Prop p p')],
#  '')
# ('tactic_failure',
#  ['done tactic failed, there are unsolved goals\nstate:\np q : Prop\n⊢ p = p'],
#  '')
# ('tactic_failure',
#  ["unknown identifier 'abc123'",
#   "don't know how to synthesize placeholder\ncontext:\np q : Prop\n⊢ Type ?"],
#  '')
# ('success',
#  [LeanGoal(universes=[], assumptions=['m : nat'], conclusion='@eq.{1} nat nat.zero nat.zero'),
#   LeanGoal(universes=[], assumptions=['m : nat', 'n_n : nat', 'n_ih : @eq.{1} nat n_n n_n'], conclusion='@eq.{1} nat (nat.succ n_n) (nat.succ n_n)')],
#  '')
# ('theorem_error',
#  ["unknown identifier 'abc'",
#   "unknown identifier 'xyz'",
#   "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#  '')
# ('theorem_error',
#  ["unknown identifier 'abc'",
#   "unknown identifier 'xyz'",
#   "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#  '')

# %%
# examples of executing in batch
with LeanTacticTestingInterface() as lean_interface:
    goal1 = LeanGoal([], ['p q : Prop'],  'p = p')
    goal2 = LeanGoal([], ['n m : nat'],  'n = n')
    goal3 = LeanGoal([], [], 'abc = xyz')
    
    goals = [goal1, goal1, goal1, goal1, goal2, goal3, goal3]
    tactics = ['refl', 'skip', 'done', 'abc123', 'induction n', 'skip', 'fgh']
    
    display(lean_interface.apply_tactic_multiple(goals, tactics))
# Out:
# [('success', [], ''),
#  ('success',
#   [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop'], conclusion='@eq.{1} Prop p p')],
#   ''),
#  ('tactic_failure',
#   ['done tactic failed, there are unsolved goals\nstate:\np q : Prop\n⊢ p = p'],
#   ''),
#  ('tactic_failure',
#   ["unknown identifier 'abc123'",
#    "don't know how to synthesize placeholder\ncontext:\np q : Prop\n⊢ Type ?"],
#   ''),
#  ('success',
#   [LeanGoal(universes=[], assumptions=['m : nat'], conclusion='@eq.{1} nat nat.zero nat.zero'),
#    LeanGoal(universes=[], assumptions=['m : nat', 'n_n : nat', 'n_ih : @eq.{1} nat n_n n_n'], conclusion='@eq.{1} nat (nat.succ n_n) (nat.succ n_n)')],
#   ''),
#  ('theorem_error',
#   ["unknown identifier 'abc'",
#    "unknown identifier 'xyz'",
#    "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#   ''),
#  ('theorem_error',
#   ["unknown identifier 'abc'",
#    "unknown identifier 'xyz'",
#    "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#   '')]

# %% [markdown]
# ### Speed and robustness
# Unfortunately, this is quit slow.

# %%
# time it
total_runs = 50
total_time = 0
goal = LeanGoal([], [],  'true')
with LeanTacticTestingInterface() as lean_interface:
    # give the system a chance to "warm up"
    lean_interface.apply_tactic(goal, 'refl')
    time.sleep(2)
    
    for i in range(total_runs):
        a = time.time()
        response = lean_interface.apply_tactic(goal, 'refl')
        b = time.time()
        total_time += b - a
"Each call to the Lean interface takes on average {} seconds".format(total_time / total_runs)
# Out:
# 'Each call to the Lean interface takes on average 0.31146204471588135 seconds'

# %% [markdown]
# But sending multiple calls to Lean speeds things up.

# %%
# time running multiple goal-tactics at a time 
total_runs = 50
batch_size = 32
total_time = 0
goals = [LeanGoal([], [],  'true')] * batch_size
tactics = ['refl'] * batch_size
with LeanTacticTestingInterface() as lean_interface:
    # give the system a chance to "warm up"
    lean_interface.apply_tactic(LeanGoal([], [],  'true'), 'refl')
    time.sleep(2)
    
    for i in range(total_runs):
        a = time.time()
        response = lean_interface.apply_tactic_multiple(goals, tactics)
        b = time.time()
        total_time += b - a
display("Each call to the Lean interface takes on average {} seconds".format(total_time / total_runs))
display("Each goal/tactic pair (w/ batch size {}) takes on average {} seconds".format(batch_size, total_time / total_runs / batch_size))
# Out:
# 'Each call to the Lean interface takes on average 0.4297070026397705 seconds'
# 'Each goal/tactic pair (w/ batch size 32) takes on average 0.013428343832492829 seconds'

# %% [markdown]
# It is very difficult to make this process robust. If one is not careful, the results returned by `apply_tactic_multiple` could be for a previous call to the method.  There are ways to get around this, but if one is not careful they would significantly increase Lean's memory usage over time.  (For example, using a new file name for every "sync" request would be bad, since Lean caches the results of each file.)  This is a test that `apply_tactic_multiple` is robust.

# %%
# test robustness.  Make sure we are getting correct results back 
# and not results for a previous request.
rounds = 100
with LeanTacticTestingInterface() as lean_interface:
    for r in range(rounds):
        count = rounds - r
        goals = [LeanGoal([], ['p_{}_{} : Prop'.format(r, i)],  'p_{}_{}'.format(r, i)) for i in range(count)]
        
        if r % 3 == 0:
            tactics = ['skip' for _ in range(count)]
            results = lean_interface.apply_tactic_multiple(goals, tactics)
            assert len(results) == count
            for i, (response, new_goals, _) in enumerate(results):
                assert response == 'success'
                assert new_goals[0].conclusion == 'p_{}_{}'.format(r, i)
        else:
            tactics = ['simp' for _ in range(count)]
            results = lean_interface.apply_tactic_multiple(goals, tactics)
            assert len(results) == count
            for i, (response, _, _) in enumerate(results):
                assert response == 'tactic_failure', response
"Passed tests"
# Out:
# 'Passed tests'

# %% [markdown]
# ### Stepping through a full proof

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
# Out:
# ('success',
#  [LeanGoal(universes=[], assumptions=['m : nat'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add m nat.zero) (@has_add.add.{0} nat nat.has_add nat.zero m)'),
#   LeanGoal(universes=[], assumptions=['m : nat', 'n_n : nat', 'n_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add m n_n) (@has_add.add.{0} nat nat.has_add n_n m)'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add m (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) m)')],
#  '')

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(
        LeanGoal([], ['m n_n : ℕ','n_ih : m + n_n = n_n + m'], 'm + nat.succ n_n = nat.succ n_n + m'), 
        "induction m"))
# Out:
# ('success',
#  [LeanGoal(universes=[], assumptions=['n_n : nat', 'n_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add nat.zero n_n) (@has_add.add.{0} nat nat.has_add n_n nat.zero)'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add nat.zero (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) nat.zero)'),
#   LeanGoal(universes=[], assumptions=['n_n : nat', 'm_n : nat', 'm_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add m_n n_n) (@has_add.add.{0} nat nat.has_add n_n m_n) → @eq.{1} nat (@has_add.add.{0} nat nat.has_add m_n (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) m_n)', 'n_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add (nat.succ m_n) n_n) (@has_add.add.{0} nat nat.has_add n_n (nat.succ m_n))'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add (nat.succ m_n) (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) (nat.succ m_n))')],
#  '')

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(
        LeanGoal([], ['n_n : ℕ','n_ih : 0 + n_n = n_n + 0'],
         '0 + nat.succ n_n = nat.succ n_n + 0'), 
        "simp"))
# Out:
# ('success', [], '')

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(
        LeanGoal([], ['n_n m_n : ℕ',
         'm_ih : m_n + n_n = n_n + m_n → m_n + nat.succ n_n = nat.succ n_n + m_n',
         'n_ih : nat.succ m_n + n_n = n_n + nat.succ m_n'],
         'nat.succ m_n + nat.succ n_n = nat.succ n_n + nat.succ m_n'), 
        "simp"))
# Out:
# ('success', [], '')

# %% [markdown]
# ## Creating a simple Lean solver (with breath first search) in Python

# %% [markdown]
# Here we put all of this together to create (a non-practical) BFS prover.  Some highlights:
# - Some tactics like `apply` take a parameter.  We search the local context for all possible things to put in this parameter.  Note, we do no type checking before sending it to Lean.  The user inputs the tactic as `apply {}` to signify that something needs to be filled in from the context.
# - Our setup assumes the tactic is only applied to the first goal.  This isn't true of all tactics, so we force this by "treeifying" our proof, that is adding brackets `{ ... }` where necessary.
# - Sending multiple calls to Lean at the same time makes it much faster.  This is the only difference between the "fast" version.
# - We provide a way to verify a proof in the end (sending the whole proof as if it was a single tactic), and also walking through the proof to get information (which might be useful for machine-learning-like training).
# - This is just a proof-of-concept and not very useful in itself.

# %%
def premises_from_goal(goal):
    prems = []
    for l in goal.assumptions:
        a, _ = l.split(":")
        for v in a.strip().split(" "):
            prems.append(v)
    return prems

def tactic_applications(tactics, prems):
    tacs = []
    for t in tactics:
        if "{}" in t:
            for p in prems:
                tacs.append(t.replace("{}", p))
        else:
            tacs.append(t)
    return tacs

def treeify_proof(proof_list):
    s = ""
    goal_cnts = [1]  # open goal counts at each depth
    for tactic, new_goal_cnt in proof_list:
        while True:
            # take goals
            goal_cnt = goal_cnts.pop()

            # if no goals at this depth, end block and take off stack again
            if goal_cnt == 0:
                s += ", }"
                continue
            
            if goal_cnt == 1:
                if s: # don't put comma in front
                    s += ", "
                
            # if more than one goal, take one of them, start block and put rest back on stack
            if goal_cnt > 1:
                goal_cnts.append(goal_cnt - 1)
                s += ", { "
            
            break
            
        # apply tactic
        s += tactic
        
        # put remaining goals on stack
        goal_cnts.append(new_goal_cnt)
            
    return s 

class BreathFirstProofSearch(LeanTacticTestingInterface):
        
    def proof_search(self, lean_goal, tactics, verbose=False):
        starting_goal = lean_goal
        starting_goal_list = (starting_goal,)
        empty_tactics = tuple()
        goal_list_queue = collections.deque()
        goal_list_queue.append((starting_goal_list, empty_tactics))

        while goal_list_queue:
            goal_list, ts = goal_list_queue.popleft()
            goal = goal_list[0]
            prems = premises_from_goal(goal)
            all_tactics = tactic_applications(tactics, prems)
            for t in all_tactics:
                response, new_goals, _ = self.apply_tactic(goal, t, verbose=verbose)
                if response == 'success':
                    new_goal_list = tuple(new_goals) + goal_list[1:]
                    new_ts = ts + ((t, len(new_goals)),)
                    if not new_goal_list:
                        return treeify_proof(new_ts)

                    goal_list_queue.append((new_goal_list, new_ts))
        return None
    
    def proof_search_fast(self, lean_goal, tactics, verbose=False):
        starting_goal = lean_goal
        starting_goal_list = (starting_goal,)
        empty_tactics = tuple()
        goal_list_queue = collections.deque()
        goal_list_queue.append((starting_goal_list, empty_tactics))

        while goal_list_queue:
            goal_list, ts = goal_list_queue.popleft()
            goal = goal_list[0]
            prems = premises_from_goal(goal)
            all_tactics = tactic_applications(tactics, prems)
            
            # faster to batch process all apply_tactic calls
            results = self.apply_tactic_multiple([goal] * len(all_tactics), all_tactics, verbose=verbose)
            for t, (response, new_goals, _) in zip(all_tactics, results):
                if response == 'success':
                    new_goal_list = tuple(new_goals) + goal_list[1:]
                    new_ts = ts + ((t, len(new_goals)),)
                    if not new_goal_list:
                        return treeify_proof(new_ts)

                    goal_list_queue.append((new_goal_list, new_ts))
        return None
    
    def is_valid_proof(self, goal, proof, verbose=False):
        t = proof.replace("\n", "")  # treat proof as a single tactic
        response, goals, _ = self.apply_tactic(goal, t, verbose=verbose)
        if response == 'success' and goals == []:
            return True
        return goals
    
    def walk_through_proof(self, lean_goal, proof):
        ts = proof.replace(" {", "").replace("}, ", "").split(", ")
        goals = [lean_goal]
        for t in ts:
            goal = goals[0]
            print(" Primary Goal:  ", goal)
            print(" Tactic applied:", t)
            _, new_goals, _ = self.apply_tactic(goal, t)
            goals = new_goals + goals[1:]
            print(" New Goals: ", new_goals)
            print(" All Goals: ", goals)
            print()

# %%
def example(goal, tactics, verbose=False):
    with BreathFirstProofSearch() as bfs:
        print("Goal:", goal)
        print("Tactics:", tactics)
        print()
        start = time.time()
        proof = bfs.proof_search_fast(goal, tactics, verbose=verbose)
        end = time.time()
        print("Time to proof:", end-start, "seconds")
        print("Proof:", proof)
        print()
        print("Verified:", bfs.is_valid_proof(goal, proof, verbose=verbose))
        print()
        print("Walk through proof:")
        bfs.walk_through_proof(goal, proof)

# %%
example(
    goal = LeanGoal([], ['p q r : Prop'], 'p ∧ q → q ∧ p'), 
    tactics=['apply {}', 'cases {}', 'intro', 'split', 'left', 'right'],
)
# Out:
# Goal: LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='p ∧ q → q ∧ p')
# Tactics: ['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
#
# Time to proof: 2.7585809230804443 seconds
# Proof: intro, cases a, split, { apply a_right, }, apply a_left
#
# Verified: True
#
# Walk through proof:
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='p ∧ q → q ∧ p')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q'], conclusion='and q p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q'], conclusion='and q p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q'], conclusion='and q p')
#  Tactic applied: cases a
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='and q p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='and q p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='and q p')
#  Tactic applied: split
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='q')
#  Tactic applied: apply a_right
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='p')
#  Tactic applied: apply a_left
#  New Goals:  []
#  All Goals:  []

# %%
example(
    goal = LeanGoal([], ['p q r : Prop'], '(p -> (q -> r)) <-> (p /\ q -> r)'), 
    tactics=['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
)
# Out:
# Goal: LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='(p -> (q -> r)) <-> (p /\\ q -> r)')
# Tactics: ['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
#
# Time to proof: 7.318338871002197 seconds
# Proof: split, { intro, intro, cases a_1, apply a, { apply a_1_left, }, apply a_1_right, }, intro, intro, intro, apply a, split, { apply a_1, }, apply a_2
#
# Verified: True
#
# Walk through proof:
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='(p -> (q -> r)) <-> (p /\\ q -> r)')
#  Tactic applied: split
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(p → q → r) → and p q → r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(p → q → r) → and p q → r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(p → q → r) → and p q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r'], conclusion='and p q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r'], conclusion='and p q → r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r'], conclusion='and p q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1 : and p q'], conclusion='r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1 : and p q'], conclusion='r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1 : and p q'], conclusion='r')
#  Tactic applied: cases a_1
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='r')
#  Tactic applied: apply a
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='q')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='p')
#  Tactic applied: apply a_1_left
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='q')
#  Tactic applied: apply a_1_right
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(and p q → r) → p → q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r'], conclusion='p → q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r'], conclusion='p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r'], conclusion='p → q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p'], conclusion='q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p'], conclusion='q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p'], conclusion='q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='r')
#  Tactic applied: apply a
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='and p q')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='and p q')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='and p q')
#  Tactic applied: split
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='q')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='q')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='p')
#  Tactic applied: apply a_1
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='q')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='q')
#  Tactic applied: apply a_2
#  New Goals:  []
#  All Goals:  []

# %%
example(
    goal = LeanGoal([], ['p q r : Prop'], '¬(p ↔ ¬p)'), 
    tactics=['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
)
# Out:
# Goal: LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='¬(p ↔ ¬p)')
# Tactics: ['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
#
# Time to proof: 45.084619998931885 seconds
# Proof: intro, cases a, apply a_mp, { apply a_mpr, intro, apply a_mp, { apply a, }, apply a, }, apply a_mpr, intro, apply a_mp, { apply a, }, apply a
#
# Verified: True
#
# Walk through proof:
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='¬(p ↔ ¬p)')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : iff p (not p)'], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : iff p (not p)'], conclusion='false')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : iff p (not p)'], conclusion='false')
#  Tactic applied: cases a
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='false')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='false')
#  Tactic applied: apply a_mp
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')
#  Tactic applied: apply a_mpr
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='not p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='not p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='not p')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='false'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='false')
#  Tactic applied: apply a_mp
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')
#  Tactic applied: apply a
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')
#  Tactic applied: apply a
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')
#  Tactic applied: apply a_mpr
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='not p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='not p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='not p')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='false')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='false')
#  Tactic applied: apply a_mp
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')
#  Tactic applied: apply a
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')
#  Tactic applied: apply a
#  New Goals:  []
#  All Goals:  []

# %% [markdown]
# ## Custom printing of Lean expressions

# %% [markdown]
# Our `apply_tactic` will return a list of goals, using Lean's verbose pp.all format.  Hence, `m n : ℕ ⊢ m + n = n + m` is returned as `LeanGoal(['m n : nat'], "@eq.{1} nat (@has_add.add.{0} nat nat.has_add m n) (@has_add.add.{0} nat nat.has_add n m)")`.  On one hand, this is not very readable by a human.  On the other hand, it is not as machine parsable as it could be.  It is however possible to have `apply_tactic` output the goals in other formats (or print other relevant information about the goal state).
#
# For example, here we write a simple piece of code which prints the Lean goals just as Lean does.

# %%
simple_custom_code = r"""
namespace custom
 
meta def trace_custom_state : tactic unit :=
do 
 tactic.trace_state,  -- default Lean pretty printed goals
 return ()

end custom
"""

# %%
with LeanTacticTestingInterface() as lean_interface:
    lean_interface.custom_code = simple_custom_code
    _, _, custom_msg = (lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
print(custom_msg)
# Out:
# 2 goals
# case nat.zero
# m : ℕ
# ⊢ m + 0 = 0 + m
#
# case nat.succ
# m n_n : ℕ,
# n_ih : m + n_n = n_n + m
# ⊢ m + nat.succ n_n = nat.succ n_n + m

# %% [markdown]
# On the other end, we may which to print the goals as expressions.  Here is  code to do that.  (It is basically the same code we are using in the LeanTacticTestingInterface above except with s-expressions instead of pp.all formatting.)

# %%
sexp_custom_code = r"""
namespace custom

def join (sep : string) : list string → string
| [x]     := x
| []      := ""
| (x::xs) := x ++ sep ++ join xs

meta def expr_to_string (e : expr bool.tt) : tactic string :=
do
  return $ to_string e.to_raw_fmt
  
meta def local_cxt_to_string (v : expr bool.tt) : tactic string := 
do 
  tp ← tactic.infer_type v,
  v_str ← expr_to_string v,
  tp_str ← expr_to_string tp,
  return $ v_str ++ "\n\n" ++ tp_str

meta def goal_to_string (g : expr) : tactic string :=
do 
  tactic.set_goals [g],
  goal ← tactic.target,
  local_cxt ← tactic.local_context,
  let local_cxt_len := list.length local_cxt,
  goal_str ← expr_to_string goal,
  local_cxt_strs ← (list.mmap local_cxt_to_string local_cxt),
  let s1 := goal_str ++ "\n\n",
  let s2 := "Local Context Vars: " ++ (to_string local_cxt_len) ++ "\n\n",
  let s3 := join "\n\n" local_cxt_strs,
  return $ s1 ++ s2 ++ s3

meta def state_report : tactic string :=
do 
 gs ← tactic.get_goals,
 -- loop over all goals (has effect of resetting the goal each time)
 let gs_len := list.length gs,
 goal_strings ← gs.mmap goal_to_string,
 tactic.set_goals gs,  -- set goals back
 let s := "Goals: " ++ (to_string gs_len) ++ "\n\n" ++ (join "\n\n" goal_strings),
 return s
 
meta def trace_custom_state : tactic unit :=
do 
 s ← state_report,
 tactic.trace s,
 return ()

end custom
"""

# %%
with LeanTacticTestingInterface() as lean_interface:
    lean_interface.custom_code = sexp_custom_code
    _, _, custom_msg = (lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
print(custom_msg)
# Out:
# Goals: 2
#
# (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (local_const 0._fresh.12.7660 m (const 1 []))) (const nat.zero []))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (const nat.zero [])) (local_const 0._fresh.12.7660 m (const 1 []))))
#
# Local Context Vars: 1
#
# (local_const 0._fresh.12.7660 m (const 1 []))
#
# (const nat [])
#
# (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (local_const 0._fresh.12.7660 m (const 1 []))) (app (const nat.succ []) (local_const 0._fresh.11.2205 n_n (const 1 []))))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (app (const nat.succ []) (local_const 0._fresh.11.2205 n_n (const 1 [])))) (local_const 0._fresh.12.7660 m (const 1 []))))
#
# Local Context Vars: 3
#
# (local_const 0._fresh.12.7660 m (const 1 []))
#
# (const nat [])
#
# (local_const 0._fresh.11.2205 n_n (const 1 []))
#
# (const nat [])
#
# (local_const 0._fresh.11.2206 n_ih (const 1 []))
#
# (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (local_const 0._fresh.12.7660 m (const 1 []))) (local_const 0._fresh.11.2205 n_n (const 1 [])))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (local_const 0._fresh.11.2205 n_n (const 1 []))) (local_const 0._fresh.12.7660 m (const 1 []))))

# %% [markdown]
# Here is code which turns each goal into a single s-expression.  The format is `(goal <intro_cnt> <expr>)` where `<expr>` is the expression and `<intro_cnt>` is the number of `intro`s one has to do on the expression to get back to the goal.  For example `m n : ℕ ⊢ m + n = n + m` is stored as `∀ m n : ℕ, m + n = n + m` so `intro_cnt` is 2 since to `intro`s are needed to reproduce `m n : ℕ ⊢ m + n = n + m`.

# %%
sexp_custom_code = r"""
namespace custom

def join (sep : string) : list string → string
| [x]     := x
| []      := ""
| (x::xs) := x ++ sep ++ join xs

meta def expr_to_string (e : expr bool.tt) : tactic string :=
do
  return $ to_string e.to_raw_fmt

meta def goal_to_string (g : expr) : tactic string :=
do 
  n ← tactic.revert_all,
  goal ← tactic.target,
  tactic.iterate_exactly n (do tactic.intro1, return ()),
  goal_str ← expr_to_string goal,
  let s := "(goal " ++ (to_string n) ++ " " ++ goal_str ++ ")",
  tactic.rotate_left 1,
  return s

meta def state_report : tactic string :=
do 
 gs ← tactic.get_goals,
 let gs_len := list.length gs,
 goal_strings ← gs.mmap goal_to_string,
 let s := join "\n\n" goal_strings,
 return s
 
meta def trace_custom_state : tactic unit :=
do 
 s ← state_report,
 tactic.trace s,
 return ()

end custom
"""

# %%
with LeanTacticTestingInterface() as lean_interface:
    lean_interface.custom_code = sexp_custom_code
    _, _, custom_msg = (lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
print(custom_msg)
# Out:
# (goal 1 (pi m default (const nat []) (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 0)) (const nat.zero []))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (const nat.zero [])) (var 0)))))
#
# (goal 3 (pi m default (const nat []) (pi n_n default (const nat []) (pi n_ih default (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 1)) (var 0))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 0)) (var 1))) (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 2)) (app (const nat.succ []) (var 1)))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (app (const nat.succ []) (var 1))) (var 2)))))))

# %% [markdown]
# See Lewis and Wu [interface between Mathematica and Lean](https://robertylewis.com/leanmm/) for an example of parsing Lean expressions into Mathematica code.)

# %% [markdown]
# ## Current issues

# %% [markdown]
# The current system relies on Leans pretty printer (with `pp.all` set to true) to output the goals which can then be fed back into Lean.  However, the pretty print (even with `pp.all` set to true) may not always output valid Lean code.  Here are some known issues:

# %% [markdown]
# ### Privately defined terms

# %% [markdown]
# This mostly comes up in proof recording, but some true theorems of Lean can't be entered into our system since they refer to privately defined terms.  However, in most cases those theorems are also marked as private (or they are automatically created theorems internal to Lean).

# %% [markdown]
# ### Term blowup

# %% [markdown]
# Because of subexpression sharing, sometimes the terms can blow up in size (usually because of type classes).  If they get too big, the pretty printer will replace parts with `…`,  making them unusable to Lean.  (Also, for some reason an expression with two `…`s will cause the lean server to stop, so we replace `…` with `_redacted_code_too_long_`.) As we can see, even the statement `12345678901234567890 - 12345678901234567890 = 0`, when expanded out, is too large for the pretty printer.

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal([], [], '12345678901234567890 - 12345678901234567890 = 0')
    result = (lean_interface.apply_tactic(goal, "skip"))
    goal2 = result[1][0]
    print("New goal:\n", goal2)
    print()
    print("Put that new goal back in...")
    result2 = (lean_interface.apply_tactic(goal2, "skip"))
    display(result2)
# Out:
# New goal:
#  LeanGoal(universes=[], assumptions=[], conclusion='@eq.{1} nat (@has_sub.sub.{0} nat nat.has_sub (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (… nat.has_one nat.has_add (… nat.has_add (… …)))))))))))))))))))))))))))))))))))))))))))))))))))))))))))) (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0.{0} nat nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit1.{0} nat nat.has_one nat.has_add (@bit0 ...
#
# Put that new goal back in...
# ('theorem_error',
#  ["unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'",
#   "unknown identifier '_redacted_code_too_long_'"],
#  '')

# %% [markdown]
# ### Missing @ symbols

# %% [markdown]
# `@` symbols are needed for some functions with implicit parameters.  With `pp.all` set to true, the pretty printer usually adds the `@` symbols as needed but can occasionally miss some cases.  Here is one such case.

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u'], [], '@id.{u} = @id.{u}')
    result = (lean_interface.apply_tactic(goal, "skip"))
    goal2 = result[1][0]
    print("New goal:\n", goal2)
    print()
    print("Put that new goal back in...")
    result2 = (lean_interface.apply_tactic(goal2, "skip"))
    display(result2)
    goal3 = LeanGoal(['u'], [], '@eq.{(imax (u+1) u)} (Π {α : Sort u}, α → α) @id.{u} @id.{u}')
    print("What the new goal should be:\n", goal3)
    print()
    print("Put that new goal back in...")
    result3 = (lean_interface.apply_tactic(goal3, "skip"))
    display(result3)
# Out:
# New goal:
#  LeanGoal(universes=['u'], assumptions=[], conclusion='@eq.{(imax (u+1) u)} (Π {α : Sort u}, α → α) id.{u} id.{u}')
#
# Put that new goal back in...
# ('theorem_error',
#  ['type mismatch at application\n  eq id\nterm\n  id\nhas type\n  ?m_1 → ?m_1 : Sort u\nbut is expected to have type\n  Π {α : Sort u}, α → α : Sort (imax (u+1) u)'],
#  '')
# What the new goal should be:
#  LeanGoal(universes=['u'], assumptions=[], conclusion='@eq.{(imax (u+1) u)} (Π {α : Sort u}, α → α) @id.{u} @id.{u}')
#
# Put that new goal back in...
# ('success',
#  [LeanGoal(universes=['u'], assumptions=[], conclusion='@eq.{(imax (u+1) u)} (Π {α : Sort u}, α → α) id.{u} id.{u}')],
#  '')

# %% [markdown]
# ### Extra `@` sysmbols (or maybe a missing case in the Lean parser)

# %% [markdown]
# Currently `@(λ {α : Type} (x : α), x)` is not valid Lean code even though `@id` is.  However, the pretty printer tries to add an @ in this case (and even without the `@` it would still be incorrect, so it is likely a bug in the Lean parser).  Consider this example:
# ```lean
# theorem id_defn : @id = (λ {α : Type} (x: α), x) := by refl
# #check congr_fun id_defn bool -- @eq.{1} ((λ (x : Type), x → x) bool) (@id.{1} bool) (@(λ {α : Type} (x : α), x) bool)
# ```
# If we try plugging that theorem into Lean as follows, we will get an error:

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal([], [], '@eq.{1} ((λ (x : Type), x → x) bool) (@id.{1} bool) (@(λ {α : Type} (x : α), x) bool)')
    result = (lean_interface.apply_tactic(goal, "skip"))
    print(result)
# Out:
# ('theorem_error', ["invalid '@', identifier expected"], '')

# %% [markdown]
# ### Implicit and type class assumptions

# %% [markdown]
# One can't directly enter typeclass and implicit assumptions into our framework.  We could easily add this functionality if it matters, but it shouldn't matter from the stand points of proofs.

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u'], [], '∀ {α : Type u} [inhabited α], (∃ x : α, x = x)')
    result = (lean_interface.apply_tactic(goal, "intro, intro"))
    
    # the new goal should be 
    #  {α : Type u} [_inst_1 : inhabited.{u+1} α] ⊢ @Exists.{u+1} α (λ (x : α), @eq.{u+1} α x x)
    # but we record it as the slightly different
    #  (α : Type u) (_inst_1 : inhabited.{u+1} α) ⊢ @Exists.{u+1} α (λ (x : α), @eq.{u+1} α x x)
    goal2 = result[1][0]
    print(goal2)
    
    # however, the proof is the same
    result = (lean_interface.apply_tactic(goal2, "existsi _inst_1.default, refl"))
    print(result)
# Out:
# LeanGoal(universes=['u'], assumptions=['α : Type u', '_inst_1 : inhabited.{u+1} α'], conclusion='@Exists.{u+1} α (λ (x : α), @eq.{u+1} α x x)')
# ('success', [], '')

# %% [markdown]
# ### Let expressions

# %% [markdown]
# The `intro` tactic can move `let` binders to the local context.  However, I don't know a way to either
# 1. figure out that the assumption in the local context is associated with a let binder and know what it is assigned to, nor
# 2. enter this back into Lean.
#
# Consider the following example.

# %%
with LeanTacticTestingInterface() as lean_interface:
    # This is solvable with this proof:
    goal = LeanGoal([], [], 'let x : ℕ := 0 in x = 0')
    proof = "intro, refl"
    result = (lean_interface.apply_tactic(goal, proof))
    print(result)
    
    # but if we do it in two steps, the assumption gets recorded incorrectly:
    goal = LeanGoal([], [], 'let x : ℕ := 0 in x = 0')
    result = (lean_interface.apply_tactic(goal, 'intro'))
    print(result)
    
    goal2 = result[1][0]
    result = (lean_interface.apply_tactic(goal2, 'refl'))
    print(result)
    
    # moveover, even if we enter this as `x : nat := 0` in the assumptions it gets 
    # a different interpretation than we intend.  It interprets this as `x : opt_param nat 0`.
    goal3 = LeanGoal([], ['x : nat := 0'], 'x = 0')
    result = (lean_interface.apply_tactic(goal3, 'skip'))
    print(result)
# Out:
# ('success', [], '')
# ('success', [LeanGoal(universes=[], assumptions=['x : nat'], conclusion='@eq.{1} nat x (@has_zero.zero.{0} nat nat.has_zero)')], '')
# ('tactic_failure', ['invalid apply tactic, failed to unify\n  x = 0\nwith\n  ?m_2 = ?m_2\nstate:\nx : ℕ\n⊢ x = 0'], '')
# ('success', [LeanGoal(universes=[], assumptions=['x : opt_param.{1} nat (@has_zero.zero.{0} nat nat.has_zero)'], conclusion='@eq.{1} (opt_param.{1} nat (@has_zero.zero.{0} nat nat.has_zero)) x (@has_zero.zero.{0} (opt_param.{1} nat (@has_zero.zero.{0} nat nat.has_zero)) nat.has_zero)')], '')

# %% [markdown]
# ### Other

# %% [markdown]
# There are other small issues that sometimes come up, and I'm sure more issues will arise as this is tested on all the theorems in Lean.  However, right now about in the core library, about 95% of theorems correctly load into Lean.  (I imagine that in `mathlib`, with the increased use of type classes, that this number will go down.)

# %% [markdown]
# ## TODOs

# %% [markdown]
# - Code:
#     - Is there a way to make this faster?
#     - Is there a way to make this more robust?  (It works for now, but still feels rickety.)
#     - Make this production level code.  It is just a proof of concept and still quite hacky.
# - Functionality
#     - How should one enter definitions and notation?
#     - Can we even enter all Lean theorems this way (assuming there definitions and notation are stored in mathlib)?
#       - A next step would be to get a list of all theorems and see if we can apply the `skip` tactic to them.
#     - How should one enter premises?  The easiest way is to add them as assumptions to the goal.
#     - ~~What about imports, etc?~~
#     - We only apply tactics to a single goal and not a goal stack

# %% [markdown]
# ## What I want from Lean 4

# %% [markdown]
# - Either a REPL like interface which is fast,
# - or a way to quickly in a few milliseconds call Lean for the text of a small file and get a direct (and unambiguous) response to my request.
# - Better documentation of the communication interface
# - Better documentation of the tactic commands
