# %% [markdown]
# # Communicating with Lean

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Communicating-with-Lean" data-toc-modified-id="Communicating-with-Lean-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Communicating with Lean</a></span><ul class="toc-item"><li><span><a href="#Lean-Server" data-toc-modified-id="Lean-Server-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Lean Server</a></span></li><li><span><a href="#Testing-tactics-with-the-Lean-Server" data-toc-modified-id="Testing-tactics-with-the-Lean-Server-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Testing tactics with the Lean Server</a></span><ul class="toc-item"><li><span><a href="#Speed-and-robustness" data-toc-modified-id="Speed-and-robustness-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Speed and robustness</a></span></li><li><span><a href="#Stepping-through-a-full-proof" data-toc-modified-id="Stepping-through-a-full-proof-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Stepping through a full proof</a></span></li></ul></li><li><span><a href="#Creating-a-simple-Lean-solver-(with-breath-first-search)-in-Python" data-toc-modified-id="Creating-a-simple-Lean-solver-(with-breath-first-search)-in-Python-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Creating a simple Lean solver (with breath first search) in Python</a></span></li><li><span><a href="#Custom-printing-of-Lean-expressions" data-toc-modified-id="Custom-printing-of-Lean-expressions-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Custom printing of Lean expressions</a></span></li><li><span><a href="#TODOs" data-toc-modified-id="TODOs-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>TODOs</a></span></li><li><span><a href="#What-I-want-from-Lean-4" data-toc-modified-id="What-I-want-from-Lean-4-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>What I want from Lean 4</a></span></li></ul></li></ul></div>

# %% [markdown]
# This is a hacky prototype showing how one can use Lean's server for communication between Lean and another program.  We have in mind implementing something like HOList for Lean. The main idea is that theorem proving is like a puzzle similar to the Rubik cube.  One has states and actions one can perform to move to other states.  This states are goals (or lists of goals) and the actions are tactics.
#
# What we build here is an interface where one says to Lean "apply this tactic to this goal" and Lean says whether that tactic succeeds and if so what the new list of goals are.  It is written in a Python notebook, but the ideas transcend languages.

# %%
import subprocess
import tempfile
import json
from pprint import pprint
import time
from datetime import datetime
import collections
from IPython.display import display

# %% [markdown]
# ## Lean Server
# This class starts up a Lean server and communicates with it.  There are a number of requests one can make to the Lean server, but we only need one or two.  To understand the Lean server, it is important to know it is not like a REPL, but more like the LSP.  It is designed to partial compile and comment on files as they are being written.  The use here is more of a hack (and it is unfortunately quite a bit slow we will see).
#
# One communicates to Lean by sending JSON requests and getting back responses.  We only need one or two request types for our purposes.  The first request we need is a "sync" request.  It sends a "file" to Lean to be synced.  (The file doesn't actually need to exist.)  The second request, an "info" request, asks Lean to provide more information about particular places in the code.  Unfortunately, the responses to the requests don't actually provide a lot of direct answers.  Especially for the "sync" request, one has to wait for an "all_messages" request to provide answers.  (And even then, it is difficult to determine that the response you got is up-to-date with the current Lean file.  We've employed a lot of tricks to make sure we are getting the most up-to-date information from Lean.)  Our class will store any "all_messages" responses it sees into a queue for latter processing.
#
# Ultimately, the "info" requests turned out not to be a reliable as we hoped, so we just use the "sync" request and only use the "info" request to prevent blocking of the channel.

# %%
class LeanServer:
    """
    Open up a Lean server and communicate with it.  
    
    Right now it only has support for the "sync" and "info" requests (and their)
    corresponding responses.  It does however, store all "all_messages" response
    into a queue for later processing.
    """
    
    def __init__(self):
        self.cntr = -1
        self.cntr2 = -1
        self.all_messages = []
        self.all_messages_time = -1
        self.current_tasks = []
        self.current_tasks_time = -1
        self.proc = subprocess.Popen(['lean', '--server'], 
                    universal_newlines=True, 
                    stdin=subprocess.PIPE, # pipe STDIN and STDOUT to send and receive messages
                    stdout=subprocess.PIPE, 
                    #stderr=subprocess.PIPE
                )
    
    # make into a context manager so that it closes lean server automatically
    def __enter__(self):
        self.proc.__enter__()
        return self
    
    def __exit__(self, type, value, traceback):
        self.proc.__exit__(type, value, traceback)
    
    def seq_num(self):
        self.cntr += 1
        return self.cntr
    
    def send_request(self, request, expected_response, verbose=False, sleep=0.0):
        seq_num = self.seq_num()
        request1 = request.copy()
        request1['seq_num'] = seq_num
        j = json.dumps(request1)
        
        # TODO: Use logging instead
        if verbose:
            print()
            print("=>:", datetime.now().strftime('%H:%M:%S.%f'))
            pprint(j)
            print()
        
        # send
        print(j, file=self.proc.stdin, flush=True)
        
        # wait for response
        time.sleep(sleep)
        while True:
            self.cntr2 += 1
            raw_output = self.proc.stdout.readline()
            output = json.loads(raw_output)
            if verbose:
                print("<=:", datetime.now().strftime('%H:%M:%S.%f'))
                pprint(output)
                print()
            if 'response' in output:
                if output['response'] == expected_response and output['seq_num'] == seq_num:
                    return output
                # TODO: Handle error differently.  It means the JSON is bad
                elif output['response'] == 'error':
                    return output
                # record messages since they may point to errors in the lean code
                elif output['response'] == 'all_messages':
                    self.all_messages = output['msgs']
                    self.all_messages_time = self.cntr2
                # record tasks to know when Lean has stopped processing file
                elif output['response'] == 'current_tasks':
                    self.current_tasks = output['tasks']
                    self.current_tasks_time = self.cntr2
    
    def send_sync_request(self, file_name, content, verbose=False):
        request = {
            'command':'sync',
            'file_name': file_name,
            "content": content,
        }
        
        return self.send_request(request, expected_response='ok', verbose=verbose, sleep=0.0)
    
    def send_info_request(self, file_name, line, column, verbose=False):
        request = {            
            'command':'info',
            'file_name': file_name,
            'column': column,
            'line': line
        }
        
        return self.send_request(request, expected_response='ok', verbose=verbose, sleep=0.0)

# %%
# sync file (the "file" doesn't need to exist)
with LeanServer() as lean_server:
    response1 = lean_server.send_sync_request(
        file_name='/tmp/fake_lean_file.lean', 
        content='example (p: Prop) : p = p := begin sorry end')
    time.sleep(1)
    response2 = lean_server.send_info_request(
        file_name='/tmp/fake_lean_file.lean', 
        line=1, 
        column=0)
    
    # the responses themselves aren't always useful
    display(response1)
    display(response2)
    
    # the "all_messages" responses are more useful
    display(lean_server.all_messages)
# Out:
# {'message': 'file invalidated', 'response': 'ok', 'seq_num': 0}
# {'response': 'ok', 'seq_num': 1}
# [{'caption': '',
#   'file_name': '/tmp/fake_lean_file.lean',
#   'pos_col': 0,
#   'pos_line': 1,
#   'severity': 'warning',
#   'text': "declaration '[anonymous]' uses sorry"}]

# %% [markdown]
# In much of the code, use the optional parameter `verbose=True` to see the message traffic.

# %%
# sync file (the "file" doesn't need to exist)
with LeanServer() as lean_server:
    lean_server.send_sync_request(
        file_name='/tmp/fake_lean_file.lean', 
        content='example (p: Prop) : p = p := begin sorry end',
        verbose=True)
    lean_server.send_info_request(
        file_name='/tmp/fake_lean_file.lean', 
        line=1,
        column=0,
        verbose=True)
# Out:
# =>: 07:59:13.079279
# ('{"file_name": "/tmp/fake_lean_file.lean", "seq_num": 0, "content": "example '
#  '(p: Prop) : p = p := begin sorry end", "command": "sync"}')
#
# <=: 07:59:13.388019
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 07:59:13.591447
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 07:59:13.800265
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 07:59:14.004003
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 07:59:14.217396
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 07:59:14.422635
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 07:59:14.501397
# {'message': 'file invalidated', 'response': 'ok', 'seq_num': 0}
#
#
# =>: 07:59:14.501746
# ('{"file_name": "/tmp/fake_lean_file.lean", "seq_num": 1, "command": "info", '
#  '"line": 1, "column": 0}')
#
# <=: 07:59:14.503053
# {'response': 'ok', 'seq_num': 1}

# %% [markdown]
# ## Testing tactics with the Lean Server

# %% [markdown]
# Again, tactic-based theorem proving is like a puzzle.  You go from state to state exploring.  What we need is a way to test if we can use a tactic on a goal and what the next goals are.  This is what the LeanTacticTestingInterface does.  (Note, it is much faster to ask the Lean server about multiple goal-tactic pairs instead of just one at a time.)

# %%
# For storing information about a Lean goal
LeanGoal = collections.namedtuple('LeanGoal', ['universes', 'assumptions', 'conclusion'])

# %%
inspection_tools = r"""
namespace inspection_tools

def join (sep : string) : list string → string
| [x]     := x
| []      := ""
| (x::xs) := x ++ sep ++ join xs

meta def expr_to_string (e : expr bool.tt) : tactic string :=
do
  o ← tactic.get_options,
  tactic.set_options (options.mk.set_bool `pp.all tt),
  f ← tactic.pp e,
  tactic.set_options o,  -- set back to before
  return $ to_string f
  
meta def local_cxt_to_string (v : expr bool.tt) : tactic string := 
do 
  tp ← tactic.infer_type v,
  v_str ← expr_to_string v,
  tp_str ← expr_to_string tp,
  return $ v_str ++ "\n\n" ++ tp_str

meta def goal_to_string (g : expr) : tactic string :=
do 
  tactic.set_goals [g],
  goal ← tactic.target,
  local_cxt ← tactic.local_context,
  let local_cxt_len := list.length local_cxt,
  goal_str ← expr_to_string goal,
  local_cxt_strs ← (list.mmap local_cxt_to_string local_cxt),
  let s1 := goal_str ++ "\n\n",
  let s2 := "Local Context Vars: " ++ (to_string local_cxt_len) ++ "\n\n",
  let s3 := join "\n\n" local_cxt_strs,
  return $ s1 ++ s2 ++ s3

meta def state_report : tactic string :=
do 
 gs ← tactic.get_goals,
 -- loop over all goals (has effect of resetting the goal each time)
 let gs_len := list.length gs,
 goal_strings ← gs.mmap goal_to_string,
 tactic.set_goals gs,  -- set goals back
 let s := "Goals: " ++ (to_string gs_len) ++ "\n\n" ++ (join "\n\n" goal_strings),
 return s
 
meta def trace_goal_state : tactic unit :=
do 
 s ← state_report,
 tactic.trace s,
 return ()

end inspection_tools
"""

default_custom_code = r"""
namespace custom
 
meta def trace_custom_state : tactic unit :=
do 
 tactic.trace "",  -- make more interesting
 return ()

end custom
"""

# %%
class LeanTacticTestingInterface:
    """
    Interface to test a tactic on a goal (or multiple tactics on multiple goals)
    """
    def __init__(self):
        self.lean_server = LeanServer()
        
        self.msg_cntr = 0
        self.file_name = 'dummy.lean'   # the name of the "file" being checked (not a real file)
        self.dummy_file = 'dummy.lean'  # a file always kept empty 
        self.eval_line_pos = None       # used for checking that a file is complete
        
        # set up a dummy file for later use
        self.lean_server.send_sync_request(file_name=self.dummy_file, content="")
        
        # one can implement their own custom state trace.  This is the default.
        self.custom_code = default_custom_code
    
     # make into a context manager so that it closes lean server automatically
    def __enter__(self):
        self.lean_server.__enter__()
        return self
    
    def __exit__(self, type, value, traceback):
        self.lean_server.__exit__(type, value, traceback)
        
    def parse_state(self, universes, goal_state):
        """
        Parses the trace string returned by trace_goal_state
        """
        lines = iter(l.replace("\n", " ") for l in goal_state.split("\n\n"))
        
        goal_cnt = int(next(lines).split()[-1])
        
        goals = []
        for _ in range(goal_cnt):
            target = next(lines)
            assump_cnt = int(next(lines).split()[-1])
            assumptions = []
            for _ in range(assump_cnt):
                v = next(lines)
                tp = next(lines)
                assumptions.append(v + " : " + tp)
            goal = LeanGoal(universes, assumptions, target)
            goals.append(goal)

        return goals
    
    def check_content(self, content, verbose):
        """
        Have Lean check the contents of a Lean "file". 
        """
        self.msg_cntr += 1
        
        # empty out the previous file for good measure
        self.lean_server.send_sync_request(file_name=self.file_name, content="", verbose=verbose)
        
        # use a few different file names to help avoid old data in the messages
        self.file_name = 'fake_lean_file{}.lean'.format(self.msg_cntr % 10)
        
        # put an eval at the end to make sure the response is not from an old file
        extended_content = content + "\n#eval " + str(self.msg_cntr)
        self.eval_line_pos = extended_content.count("\n") + 1
        
        if verbose:
            print("-- {} --------------".format(self.file_name))
            for i, l in enumerate(extended_content.split('\n')):
                print("{:3}   {}".format(i+1, l))
            print("-------------------------")
            
        # send the file
        self.lean_server.send_sync_request(file_name=self.file_name, content=extended_content, verbose=verbose)
        
    def get_messages(self, verbose):
        """
        Get messages for the current content being checked.
        Return all the messages for that "file"
        
        This is really really hard to make robust.  How do I know Lean has finished
        or worst that Lean isn't still providing information from an old
        version of the file?
        """
        
        # wait for tasks to stop running
        tasks_stopped_time = None
        for _ in range(10000):  # lazy time-out mechanism
            
            # keep sending requests to a dummy file to collect more "all_messages" responses
            self.lean_server.send_info_request(file_name=self.dummy_file, line=1, column=0, verbose=verbose)
            
            # check that tasks are complete for file_name
            task_running = False
            for task in self.lean_server.current_tasks:
                if task['file_name'] == self.file_name:
                    task_running = True
                    break
            if not task_running:
                tasks_stopped_time = self.lean_server.current_tasks_time
                break
        else:
            raise TimeoutError("Tasks still running for {}:\n{}".format('file_name', "\n".join(self.lean_server.current_tasks)))
            
                
        # check that messages are complete by looking at eval at the end
        for _ in range(10000):  # lazy time-out mechanism
            
            # keep sending requests to a dummy file to collect more "all_messages" responses
            self.lean_server.send_info_request(self.dummy_file, line=1, column=0, verbose=verbose)
            
            # wait until messages are after current tasks
            #if self.lean_server.all_messages_time < tasks_stopped_time:
            #    continue
                
            # filter the messages to those for this "file" 
            # and also check for the final the eval statement
            filtered_messages = []
            messages_are_complete = False
            for msg in self.lean_server.all_messages:
                if msg['file_name'] == self.file_name:
                    if msg['pos_line'] < self.eval_line_pos:
                        filtered_messages.append(msg)
                    elif msg['pos_line'] == self.eval_line_pos and msg['caption'] == "eval result":
                        if msg['text'] == str(self.msg_cntr):
                            messages_are_complete = True
                        else:
                            break

            # clear messages
            self.lean_server.all_messages = []

            if messages_are_complete:
                return filtered_messages
            
        raise TimeoutError("Expecting eval result on line {} of file {} to be {}.  Run with verbose=True to check for error messages.".format(
                self.eval_line_pos, self.file_name, self.msg_cntr
        ))
    
    def preamble(self, imports):
        if imports:
            import_line = "import " + " ".join(imports) + "\n"
        else:
            import_line = ""
        
        return import_line + inspection_tools + "\n" + self.custom_code + "\n"
        
    def example_block(self, goal, tactic):
        block = ""
        # line: preamble + 9 * n + 0
        block += "section example_block\n"
        # line: preamble + 9 * n + 1
        if goal.universes:
            block += "universes " + " ".join(goal.universes) + "\n"
        else:
            block += "--no universes\n"
        # line: preamble + 9 * n + 2  
        block += "example "
        block += " ".join("(" + l.replace("\n", " ") + ")" for l in goal.assumptions)
        block += " : "
        block += goal.conclusion.replace("\n", " ") + " :=\n"
        # line: preamble + 9 * n + 3
        block += "begin\n"  
        # line: preamble + 9 * n + 4
        block += tactic + ",\n"
        # line: preamble + 9 * n + 5
        block += 'inspection_tools.trace_goal_state,\n' # goal state
        # line: preamble + 9 * n + 6
        block += 'custom.trace_custom_state,\n'         # custom trace
        # line: preamble + 9 * n + 7
        block += "end\n"
        # line: preamble + 9 * n + 8
        block += "end example_block\n"

        return block
            
    def apply_tactic_multiple(self, lean_goals, tactics, imports=[], verbose=False):
        assert len(lean_goals) == len(tactics)
        
        # build content
        preamble = self.preamble(imports)
        
        # this is the line (indexed from 1) that the first block will be on
        preamble_length = preamble.count("\n") + 1
        
        content = preamble
        for goal, tactic in zip(lean_goals, tactics):
            content += self.example_block(goal, tactic)
        
        # start checking the file
        self.check_content(content, verbose=verbose)
            
        # positions in the block
        theorem_line = 2
        tactic_line = 4
        goals_line = 5
        custom_state_line = 6
        block_length = 9
        
        for _ in range(1000):  # lazy timeout method
            # start checking the file
            msgs = self.get_messages(verbose=verbose)
        
            # extract data from messages
            results = [[None, None, [], []] for _ in lean_goals]
            for msg in msgs:
                block_line_pos = (msg['pos_line'] - preamble_length) % block_length
                block_num = (msg['pos_line'] - preamble_length) // block_length

                if msg['pos_line'] < preamble_length:
                    continue
                elif block_line_pos == goals_line and msg['severity'] == 'information':
                    results[block_num][0] = msg['text']
                elif block_line_pos == custom_state_line and msg['severity'] == 'information':
                    results[block_num][1] = msg['text']
                elif block_line_pos == tactic_line and msg['severity'] == 'error':
                    results[block_num][2].append(msg['text'])
                elif block_line_pos == theorem_line and msg['severity'] == 'error':
                    results[block_num][3].append(msg['text'])

            # parse data and check for completeness
            final_results = []
            complete = True
            for i, ((goal_state, custom_state, tactic_errors, theorem_errors), prev_goal) in enumerate(zip(results, lean_goals)):
                if theorem_errors:
                    result = ('theorem_error', theorem_errors, '')
                elif tactic_errors:
                    result = ('tactic_failure', tactic_errors, '')
                elif goal_state is not None and custom_state is not None:
                    result = ('success', self.parse_state(prev_goal.universes, goal_state), custom_state.strip())
                else:
                    complete = False  # need to get messages again
                    break

                final_results.append(result)

            if complete:
                return final_results
        
        raise TimeoutError("Lean server sessages are not as expected:\n{}".format("\n".join(msgs)))
        
    def apply_tactic(self, lean_goal, tactic, imports=[], verbose=False):
        """
        Apply tactic to a goal and see what you get.
        """
        
        result = self.apply_tactic_multiple([lean_goal], [tactic], imports=imports, verbose=verbose)
        return result[0]

# %% [markdown]
# We see if we apply `refl` to `p = p` we solve all the goals (hence the empty list returned).

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal([], ['p q : Prop'],  'p = p')
    display(lean_interface.apply_tactic(goal, 'refl'))
# Out:
# ('success', [], '')

# %% [markdown]
# One can also add universe levels, e.g. `u`, `v`, as follows:

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u', 'v'], ['a b: Type u'],  'a = a')
    display(lean_interface.apply_tactic(goal, 'refl'))
# Out:
# ('success', [], '')

# %% [markdown]
# Imports can also be added to the `apply_tactic` call:

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u'], ['α : Type u'],  'dlist.to_list (@dlist.empty α) = []')
    display(lean_interface.apply_tactic(goal, 'refl', imports=['data.dlist']))
# Out:
# ('success', [], '')

# %% [markdown]
# To see what is going on, we show the logs with `verbose=True`.  This also prints the file being sent to Lean.
#
# The main idea is that we encode everything we want to check into a Lean file, send that via a "sync" request, and read off the response from the messages.

# %%
with LeanTacticTestingInterface() as lean_interface:
    goal = LeanGoal(['u', 'v'], ['a b: Type u'],  'a = a')
    display(lean_interface.apply_tactic(goal, 'refl', verbose=True))
# Out:
# =>: 07:59:23.678679
# '{"file_name": "dummy.lean", "seq_num": 1, "content": "", "command": "sync"}'
#
# <=: 07:59:23.679982
# {'message': 'file unchanged', 'response': 'ok', 'seq_num': 1}
#
# -- fake_lean_file1.lean --------------
#   1
#   2   namespace inspection_tools
#   3
#   4   def join (sep : string) : list string → string
#   5   | [x]     := x
#   6   | []      := ""
#   7   | (x::xs) := x ++ sep ++ join xs
#   8
#   9   meta def expr_to_string (e : expr bool.tt) : tactic string :=
#  10   do
#  11     o ← tactic.get_options,
#  12     tactic.set_options (options.mk.set_bool `pp.all tt),
#  13     f ← tactic.pp e,
#  14     tactic.set_options o,  -- set back to before
#  15     return $ to_string f
#  16
#  17   meta def local_cxt_to_string (v : expr bool.tt) : tactic string :=
#  18   do
#  19     tp ← tactic.infer_type v,
#  20     v_str ← expr_to_string v,
#  21     tp_str ← expr_to_string tp,
#  22     return $ v_str ++ "\n\n" ++ tp_str
#  23
#  24   meta def goal_to_string (g : expr) : tactic string :=
#  25   do
#  26     tactic.set_goals [g],
#  27     goal ← tactic.target,
#  28     local_cxt ← tactic.local_context,
#  29     let local_cxt_len := list.length local_cxt,
#  30     goal_str ← expr_to_string goal,
#  31     local_cxt_strs ← (list.mmap local_cxt_to_string local_cxt),
#  32     let s1 := goal_str ++ "\n\n",
#  33     let s2 := "Local Context Vars: " ++ (to_string local_cxt_len) ++ "\n\n",
#  34     let s3 := join "\n\n" local_cxt_strs,
#  35     return $ s1 ++ s2 ++ s3
#  36
#  37   meta def state_report : tactic string :=
#  38   do
#  39    gs ← tactic.get_goals,
#  40    -- loop over all goals (has effect of resetting the goal each time)
#  41    let gs_len := list.length gs,
#  42    goal_strings ← gs.mmap goal_to_string,
#  43    tactic.set_goals gs,  -- set goals back
#  44    let s := "Goals: " ++ (to_string gs_len) ++ "\n\n" ++ (join "\n\n" goal_strings),
#  45    return s
#  46
#  47   meta def trace_goal_state : tactic unit :=
#  48   do
#  49    s ← state_report,
#  50    tactic.trace s,
#  51    return ()
#  52
#  53   end inspection_tools
#  54
#  55
#  56   namespace custom
#  57
#  58   meta def trace_custom_state : tactic unit :=
#  59   do
#  60    tactic.trace "",  -- make more interesting
#  61    return ()
#  62
#  63   end custom
#  64
#  65   section example_block
#  66   universes u v
#  67   example (a b: Type u) : a = a :=
#  68   begin
#  69   refl,
#  70   inspection_tools.trace_goal_state,
#  71   custom.trace_custom_state,
#  72   end
#  73   end example_block
#  74
#  75   #eval 1
# -------------------------
#
# =>: 07:59:23.690432
# ('{"file_name": "fake_lean_file1.lean", "seq_num": 2, "content": "\\nnamespace '
#  'inspection_tools\\n\\ndef join (sep : string) : list string \\u2192 '
#  'string\\n| [x]     := x\\n| []      := \\"\\"\\n| (x::xs) := x ++ sep ++ '
#  'join xs\\n\\nmeta def expr_to_string (e : expr bool.tt) : tactic string '
#  ':=\\ndo\\n  o \\u2190 tactic.get_options,\\n  tactic.set_options '
#  '(options.mk.set_bool `pp.all tt),\\n  f \\u2190 tactic.pp e,\\n  '
#  'tactic.set_options o,  -- set back to before\\n  return $ to_string f\\n  '
#  '\\nmeta def local_cxt_to_string (v : expr bool.tt) : tactic string := \\ndo '
#  '\\n  tp \\u2190 tactic.infer_type v,\\n  v_str \\u2190 expr_to_string v,\\n  '
#  'tp_str \\u2190 expr_to_string tp,\\n  return $ v_str ++ \\"\\\\n\\\\n\\" ++ '
#  'tp_str\\n\\nmeta def goal_to_string (g : expr) : tactic string :=\\ndo \\n  '
#  'tactic.set_goals [g],\\n  goal \\u2190 tactic.target,\\n  local_cxt \\u2190 '
#  'tactic.local_context,\\n  let local_cxt_len := list.length local_cxt,\\n  '
#  'goal_str \\u2190 expr_to_string goal,\\n  local_cxt_strs \\u2190 (list.mmap '
#  'local_cxt_to_string local_cxt),\\n  let s1 := goal_str ++ '
#  '\\"\\\\n\\\\n\\",\\n  let s2 := \\"Local Context Vars: \\" ++ (to_string '
#  'local_cxt_len) ++ \\"\\\\n\\\\n\\",\\n  let s3 := join \\"\\\\n\\\\n\\" '
#  'local_cxt_strs,\\n  return $ s1 ++ s2 ++ s3\\n\\nmeta def state_report : '
#  'tactic string :=\\ndo \\n gs \\u2190 tactic.get_goals,\\n -- loop over all '
#  'goals (has effect of resetting the goal each time)\\n let gs_len := '
#  'list.length gs,\\n goal_strings \\u2190 gs.mmap goal_to_string,\\n '
#  'tactic.set_goals gs,  -- set goals back\\n let s := \\"Goals: \\" ++ '
#  '(to_string gs_len) ++ \\"\\\\n\\\\n\\" ++ (join \\"\\\\n\\\\n\\" '
#  'goal_strings),\\n return s\\n \\nmeta def trace_goal_state : tactic unit '
#  ':=\\ndo \\n s \\u2190 state_report,\\n tactic.trace s,\\n return ()\\n\\nend '
#  'inspection_tools\\n\\n\\nnamespace custom\\n \\nmeta def trace_custom_state '
#  ': tactic unit :=\\ndo \\n tactic.trace \\"\\",  -- make more interesting\\n '
#  'return ()\\n\\nend custom\\n\\nsection example_block\\nuniverses u '
#  'v\\nexample (a b: Type u) : a = a '
#  ':=\\nbegin\\nrefl,\\ninspection_tools.trace_goal_state,\\ncustom.trace_custom_state,\\nend\\nend '
#  'example_block\\n\\n#eval 1", "command": "sync"}')
#
# <=: 07:59:23.897245
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 07:59:24.101658
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 07:59:24.306920
# {'is_running': False, 'response': 'current_tasks', 'tasks': []}
#
# <=: 07:59:24.484588
# {'message': 'file invalidated', 'response': 'ok', 'seq_num': 2}
#
#
# =>: 07:59:24.484780
# ('{"file_name": "dummy.lean", "seq_num": 3, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.486201
# {'response': 'ok', 'seq_num': 3}
#
#
# =>: 07:59:24.486382
# ('{"file_name": "dummy.lean", "seq_num": 4, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.486708
# {'response': 'ok', 'seq_num': 4}
#
#
# =>: 07:59:24.486837
# ('{"file_name": "dummy.lean", "seq_num": 5, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.487163
# {'response': 'ok', 'seq_num': 5}
#
#
# =>: 07:59:24.487371
# ('{"file_name": "dummy.lean", "seq_num": 6, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.487800
# {'response': 'ok', 'seq_num': 6}
#
#
# =>: 07:59:24.487983
# ('{"file_name": "dummy.lean", "seq_num": 7, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.488846
# {'response': 'ok', 'seq_num': 7}
#
#
# =>: 07:59:24.488998
# ('{"file_name": "dummy.lean", "seq_num": 8, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.489296
# {'response': 'ok', 'seq_num': 8}
#
#
# =>: 07:59:24.489399
# ('{"file_name": "dummy.lean", "seq_num": 9, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.489670
# {'response': 'ok', 'seq_num': 9}
#
#
# =>: 07:59:24.489768
# ('{"file_name": "dummy.lean", "seq_num": 10, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.490039
# {'response': 'ok', 'seq_num': 10}
#
#
# =>: 07:59:24.490183
# ('{"file_name": "dummy.lean", "seq_num": 11, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.490576
# {'response': 'ok', 'seq_num': 11}
#
#
# =>: 07:59:24.490712
# ('{"file_name": "dummy.lean", "seq_num": 12, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.491046
# {'response': 'ok', 'seq_num': 12}
#
#
# =>: 07:59:24.491154
# ('{"file_name": "dummy.lean", "seq_num": 13, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.491460
# {'response': 'ok', 'seq_num': 13}
#
#
# =>: 07:59:24.491562
# ('{"file_name": "dummy.lean", "seq_num": 14, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.492661
# {'response': 'ok', 'seq_num': 14}
#
#
# =>: 07:59:24.492914
# ('{"file_name": "dummy.lean", "seq_num": 15, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.493247
# {'response': 'ok', 'seq_num': 15}
#
#
# =>: 07:59:24.493359
# ('{"file_name": "dummy.lean", "seq_num": 16, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.493634
# {'response': 'ok', 'seq_num': 16}
#
#
# =>: 07:59:24.493735
# ('{"file_name": "dummy.lean", "seq_num": 17, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.494505
# {'response': 'ok', 'seq_num': 17}
#
#
# =>: 07:59:24.494733
# ('{"file_name": "dummy.lean", "seq_num": 18, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.495240
# {'response': 'ok', 'seq_num': 18}
#
#
# =>: 07:59:24.495388
# ('{"file_name": "dummy.lean", "seq_num": 19, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.495830
# {'response': 'ok', 'seq_num': 19}
#
#
# =>: 07:59:24.495965
# ('{"file_name": "dummy.lean", "seq_num": 20, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.496321
# {'response': 'ok', 'seq_num': 20}
#
#
# =>: 07:59:24.496448
# ('{"file_name": "dummy.lean", "seq_num": 21, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.496971
# {'response': 'ok', 'seq_num': 21}
#
#
# =>: 07:59:24.497202
# ('{"file_name": "dummy.lean", "seq_num": 22, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.497732
# {'response': 'ok', 'seq_num': 22}
#
#
# =>: 07:59:24.497874
# ('{"file_name": "dummy.lean", "seq_num": 23, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.498205
# {'response': 'ok', 'seq_num': 23}
#
#
# =>: 07:59:24.498389
# ('{"file_name": "dummy.lean", "seq_num": 24, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.498786
# {'response': 'ok', 'seq_num': 24}
#
#
# =>: 07:59:24.498908
# ('{"file_name": "dummy.lean", "seq_num": 25, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.499230
# {'response': 'ok', 'seq_num': 25}
#
#
# =>: 07:59:24.499334
# ('{"file_name": "dummy.lean", "seq_num": 26, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.499629
# {'response': 'ok', 'seq_num': 26}
#
#
# =>: 07:59:24.499730
# ('{"file_name": "dummy.lean", "seq_num": 27, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.500063
# {'response': 'ok', 'seq_num': 27}
#
#
# =>: 07:59:24.500220
# ('{"file_name": "dummy.lean", "seq_num": 28, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.500536
# {'response': 'ok', 'seq_num': 28}
#
#
# =>: 07:59:24.500659
# ('{"file_name": "dummy.lean", "seq_num": 29, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.500939
# {'response': 'ok', 'seq_num': 29}
#
#
# =>: 07:59:24.501042
# ('{"file_name": "dummy.lean", "seq_num": 30, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.501309
# {'response': 'ok', 'seq_num': 30}
#
#
# =>: 07:59:24.501407
# ('{"file_name": "dummy.lean", "seq_num": 31, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.501767
# {'response': 'ok', 'seq_num': 31}
#
#
# =>: 07:59:24.501891
# ('{"file_name": "dummy.lean", "seq_num": 32, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.502250
# {'response': 'ok', 'seq_num': 32}
#
#
# =>: 07:59:24.502371
# ('{"file_name": "dummy.lean", "seq_num": 33, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.502740
# {'response': 'ok', 'seq_num': 33}
#
#
# =>: 07:59:24.502892
# ('{"file_name": "dummy.lean", "seq_num": 34, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.503207
# {'response': 'ok', 'seq_num': 34}
#
#
# =>: 07:59:24.503327
# ('{"file_name": "dummy.lean", "seq_num": 35, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.503704
# {'response': 'ok', 'seq_num': 35}
#
#
# =>: 07:59:24.505029
# ('{"file_name": "dummy.lean", "seq_num": 36, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.505414
# {'response': 'ok', 'seq_num': 36}
#
#
# =>: 07:59:24.505529
# ('{"file_name": "dummy.lean", "seq_num": 37, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.505808
# {'response': 'ok', 'seq_num': 37}
#
#
# =>: 07:59:24.505910
# ('{"file_name": "dummy.lean", "seq_num": 38, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.506177
# {'response': 'ok', 'seq_num': 38}
#
#
# =>: 07:59:24.506277
# ('{"file_name": "dummy.lean", "seq_num": 39, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.506542
# {'response': 'ok', 'seq_num': 39}
#
#
# =>: 07:59:24.506641
# ('{"file_name": "dummy.lean", "seq_num": 40, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.507715
# {'response': 'ok', 'seq_num': 40}
#
#
# =>: 07:59:24.507875
# ('{"file_name": "dummy.lean", "seq_num": 41, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.508258
# {'response': 'ok', 'seq_num': 41}
#
#
# =>: 07:59:24.508367
# ('{"file_name": "dummy.lean", "seq_num": 42, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.508716
# {'response': 'ok', 'seq_num': 42}
#
#
# =>: 07:59:24.508868
# ('{"file_name": "dummy.lean", "seq_num": 43, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.509551
# {'response': 'ok', 'seq_num': 43}
#
#
# =>: 07:59:24.509763
# ('{"file_name": "dummy.lean", "seq_num": 44, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.510199
# {'response': 'ok', 'seq_num': 44}
#
#
# =>: 07:59:24.510414
# ('{"file_name": "dummy.lean", "seq_num": 45, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.511429
# {'response': 'ok', 'seq_num': 45}
#
#
# =>: 07:59:24.511615
# ('{"file_name": "dummy.lean", "seq_num": 46, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.512078
# {'response': 'ok', 'seq_num': 46}
#
#
# =>: 07:59:24.512217
# ('{"file_name": "dummy.lean", "seq_num": 47, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.512562
# {'response': 'ok', 'seq_num': 47}
#
#
# =>: 07:59:24.512677
# ('{"file_name": "dummy.lean", "seq_num": 48, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.513002
# {'response': 'ok', 'seq_num': 48}
#
#
# =>: 07:59:24.513121
# ('{"file_name": "dummy.lean", "seq_num": 49, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.513436
# {'response': 'ok', 'seq_num': 49}
#
#
# =>: 07:59:24.513544
# ('{"file_name": "dummy.lean", "seq_num": 50, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.513855
# {'response': 'ok', 'seq_num': 50}
#
#
# =>: 07:59:24.513957
# ('{"file_name": "dummy.lean", "seq_num": 51, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.514245
# {'response': 'ok', 'seq_num': 51}
#
#
# =>: 07:59:24.514344
# ('{"file_name": "dummy.lean", "seq_num": 52, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.514638
# {'response': 'ok', 'seq_num': 52}
#
#
# =>: 07:59:24.514737
# ('{"file_name": "dummy.lean", "seq_num": 53, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.515039
# {'response': 'ok', 'seq_num': 53}
#
#
# =>: 07:59:24.515161
# ('{"file_name": "dummy.lean", "seq_num": 54, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.515664
# {'response': 'ok', 'seq_num': 54}
#
#
# =>: 07:59:24.515842
# ('{"file_name": "dummy.lean", "seq_num": 55, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.516155
# {'response': 'ok', 'seq_num': 55}
#
#
# =>: 07:59:24.516279
# ('{"file_name": "dummy.lean", "seq_num": 56, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.516567
# {'response': 'ok', 'seq_num': 56}
#
#
# =>: 07:59:24.516672
# ('{"file_name": "dummy.lean", "seq_num": 57, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.516937
# {'response': 'ok', 'seq_num': 57}
#
#
# =>: 07:59:24.517040
# ('{"file_name": "dummy.lean", "seq_num": 58, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.517417
# {'response': 'ok', 'seq_num': 58}
#
#
# =>: 07:59:24.517617
# ('{"file_name": "dummy.lean", "seq_num": 59, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.518065
# {'response': 'ok', 'seq_num': 59}
#
#
# =>: 07:59:24.518204
# ('{"file_name": "dummy.lean", "seq_num": 60, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.518529
# {'response': 'ok', 'seq_num': 60}
#
#
# =>: 07:59:24.518637
# ('{"file_name": "dummy.lean", "seq_num": 61, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.518935
# {'response': 'ok', 'seq_num': 61}
#
#
# =>: 07:59:24.519040
# ('{"file_name": "dummy.lean", "seq_num": 62, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.519438
# {'response': 'ok', 'seq_num': 62}
#
#
# =>: 07:59:24.519566
# ('{"file_name": "dummy.lean", "seq_num": 63, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.519944
# {'response': 'ok', 'seq_num': 63}
#
#
# =>: 07:59:24.520061
# ('{"file_name": "dummy.lean", "seq_num": 64, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.520359
# {'response': 'ok', 'seq_num': 64}
#
#
# =>: 07:59:24.520479
# ('{"file_name": "dummy.lean", "seq_num": 65, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.520780
# {'response': 'ok', 'seq_num': 65}
#
#
# =>: 07:59:24.520896
# ('{"file_name": "dummy.lean", "seq_num": 66, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.522025
# {'response': 'ok', 'seq_num': 66}
#
#
# =>: 07:59:24.522257
# ('{"file_name": "dummy.lean", "seq_num": 67, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.522718
# {'response': 'ok', 'seq_num': 67}
#
#
# =>: 07:59:24.522846
# ('{"file_name": "dummy.lean", "seq_num": 68, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.523137
# {'response': 'ok', 'seq_num': 68}
#
#
# =>: 07:59:24.523239
# ('{"file_name": "dummy.lean", "seq_num": 69, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.523525
# {'response': 'ok', 'seq_num': 69}
#
#
# =>: 07:59:24.523626
# ('{"file_name": "dummy.lean", "seq_num": 70, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.523898
# {'response': 'ok', 'seq_num': 70}
#
#
# =>: 07:59:24.524007
# ('{"file_name": "dummy.lean", "seq_num": 71, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.524332
# {'response': 'ok', 'seq_num': 71}
#
#
# =>: 07:59:24.524476
# ('{"file_name": "dummy.lean", "seq_num": 72, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.524764
# {'response': 'ok', 'seq_num': 72}
#
#
# =>: 07:59:24.524869
# ('{"file_name": "dummy.lean", "seq_num": 73, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.525163
# {'response': 'ok', 'seq_num': 73}
#
#
# =>: 07:59:24.525289
# ('{"file_name": "dummy.lean", "seq_num": 74, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.525617
# {'response': 'ok', 'seq_num': 74}
#
#
# =>: 07:59:24.525724
# ('{"file_name": "dummy.lean", "seq_num": 75, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.526023
# {'response': 'ok', 'seq_num': 75}
#
#
# =>: 07:59:24.526125
# ('{"file_name": "dummy.lean", "seq_num": 76, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.526426
# {'response': 'ok', 'seq_num': 76}
#
#
# =>: 07:59:24.526525
# ('{"file_name": "dummy.lean", "seq_num": 77, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.526975
# {'response': 'ok', 'seq_num': 77}
#
#
# =>: 07:59:24.527238
# ('{"file_name": "dummy.lean", "seq_num": 78, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.527493
# {'is_running': True,
#  'response': 'current_tasks',
#  'tasks': [{'desc': 'parsing at line 1',
#             'end_pos_col': 8,
#             'end_pos_line': 75,
#             'file_name': 'fake_lean_file1.lean',
#             'pos_col': 0,
#             'pos_line': 1},
#            {'desc': 'parsing at line 1',
#             'end_pos_col': 1,
#             'end_pos_line': 1,
#             'file_name': 'dummy.lean',
#             'pos_col': 0,
#             'pos_line': 1}]}
#
# <=: 07:59:24.528269
# {'response': 'ok', 'seq_num': 78}
#
#
# =>: 07:59:24.528380
# ('{"file_name": "dummy.lean", "seq_num": 79, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.528732
# {'response': 'ok', 'seq_num': 79}
#
#
# =>: 07:59:24.528850
# ('{"file_name": "dummy.lean", "seq_num": 80, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.529313
# {'response': 'ok', 'seq_num': 80}
#
#
# =>: 07:59:24.529493
# ('{"file_name": "dummy.lean", "seq_num": 81, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.529846
# {'response': 'ok', 'seq_num': 81}
#
#
# =>: 07:59:24.529964
# ('{"file_name": "dummy.lean", "seq_num": 82, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.530285
# {'response': 'ok', 'seq_num': 82}
#
#
# =>: 07:59:24.530396
# ('{"file_name": "dummy.lean", "seq_num": 83, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.530704
# {'response': 'ok', 'seq_num': 83}
#
#
# =>: 07:59:24.530806
# ('{"file_name": "dummy.lean", "seq_num": 84, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.531095
# {'response': 'ok', 'seq_num': 84}
#
#
# =>: 07:59:24.531194
# ('{"file_name": "dummy.lean", "seq_num": 85, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.531492
# {'response': 'ok', 'seq_num': 85}
#
#
# =>: 07:59:24.531646
# ('{"file_name": "dummy.lean", "seq_num": 86, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.532121
# {'response': 'ok', 'seq_num': 86}
#
#
# =>: 07:59:24.532279
# ('{"file_name": "dummy.lean", "seq_num": 87, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.532630
# {'response': 'ok', 'seq_num': 87}
#
#
# =>: 07:59:24.532737
# ('{"file_name": "dummy.lean", "seq_num": 88, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.533051
# {'response': 'ok', 'seq_num': 88}
#
#
# =>: 07:59:24.533156
# ('{"file_name": "dummy.lean", "seq_num": 89, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.533465
# {'response': 'ok', 'seq_num': 89}
#
#
# =>: 07:59:24.533567
# ('{"file_name": "dummy.lean", "seq_num": 90, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.533878
# {'response': 'ok', 'seq_num': 90}
#
#
# =>: 07:59:24.533978
# ('{"file_name": "dummy.lean", "seq_num": 91, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.534342
# {'response': 'ok', 'seq_num': 91}
#
#
# =>: 07:59:24.534594
# ('{"file_name": "dummy.lean", "seq_num": 92, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.534984
# {'response': 'ok', 'seq_num': 92}
#
#
# =>: 07:59:24.535109
# ('{"file_name": "dummy.lean", "seq_num": 93, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.535410
# {'response': 'ok', 'seq_num': 93}
#
#
# =>: 07:59:24.535515
# ('{"file_name": "dummy.lean", "seq_num": 94, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.535788
# {'response': 'ok', 'seq_num': 94}
#
#
# =>: 07:59:24.535888
# ('{"file_name": "dummy.lean", "seq_num": 95, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.536767
# {'response': 'ok', 'seq_num': 95}
#
#
# =>: 07:59:24.536984
# ('{"file_name": "dummy.lean", "seq_num": 96, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.537384
# {'response': 'ok', 'seq_num': 96}
#
#
# =>: 07:59:24.537560
# ('{"file_name": "dummy.lean", "seq_num": 97, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.538002
# {'response': 'ok', 'seq_num': 97}
#
#
# =>: 07:59:24.538122
# ('{"file_name": "dummy.lean", "seq_num": 98, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.538440
# {'response': 'ok', 'seq_num': 98}
#
#
# =>: 07:59:24.538605
# ('{"file_name": "dummy.lean", "seq_num": 99, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.539027
# {'response': 'ok', 'seq_num': 99}
#
#
# =>: 07:59:24.539288
# ('{"file_name": "dummy.lean", "seq_num": 100, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.539750
# {'response': 'ok', 'seq_num': 100}
#
#
# =>: 07:59:24.539879
# ('{"file_name": "dummy.lean", "seq_num": 101, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.540195
# {'response': 'ok', 'seq_num': 101}
#
#
# =>: 07:59:24.540307
# ('{"file_name": "dummy.lean", "seq_num": 102, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.540873
# {'response': 'ok', 'seq_num': 102}
#
#
# =>: 07:59:24.541107
# ('{"file_name": "dummy.lean", "seq_num": 103, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.541502
# {'response': 'ok', 'seq_num': 103}
#
#
# =>: 07:59:24.541633
# ('{"file_name": "dummy.lean", "seq_num": 104, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.541921
# {'response': 'ok', 'seq_num': 104}
#
#
# =>: 07:59:24.542025
# ('{"file_name": "dummy.lean", "seq_num": 105, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.542294
# {'response': 'ok', 'seq_num': 105}
#
#
# =>: 07:59:24.542395
# ('{"file_name": "dummy.lean", "seq_num": 106, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.542673
# {'response': 'ok', 'seq_num': 106}
#
#
# =>: 07:59:24.542773
# ('{"file_name": "dummy.lean", "seq_num": 107, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.543194
# {'response': 'ok', 'seq_num': 107}
#
#
# =>: 07:59:24.543405
# ('{"file_name": "dummy.lean", "seq_num": 108, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.543743
# {'response': 'ok', 'seq_num': 108}
#
#
# =>: 07:59:24.543865
# ('{"file_name": "dummy.lean", "seq_num": 109, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.544359
# {'response': 'ok', 'seq_num': 109}
#
#
# =>: 07:59:24.544550
# ('{"file_name": "dummy.lean", "seq_num": 110, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.545024
# {'response': 'ok', 'seq_num': 110}
#
#
# =>: 07:59:24.545199
# ('{"file_name": "dummy.lean", "seq_num": 111, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.545671
# {'response': 'ok', 'seq_num': 111}
#
#
# =>: 07:59:24.545851
# ('{"file_name": "dummy.lean", "seq_num": 112, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.554316
# {'response': 'ok', 'seq_num': 112}
#
#
# =>: 07:59:24.554512
# ('{"file_name": "dummy.lean", "seq_num": 113, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.554901
# {'response': 'ok', 'seq_num': 113}
#
#
# =>: 07:59:24.555083
# ('{"file_name": "dummy.lean", "seq_num": 114, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.555469
# {'response': 'ok', 'seq_num': 114}
#
#
# =>: 07:59:24.555596
# ('{"file_name": "dummy.lean", "seq_num": 115, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.556137
# {'response': 'ok', 'seq_num': 115}
#
#
# =>: 07:59:24.556335
# ('{"file_name": "dummy.lean", "seq_num": 116, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.556689
# {'response': 'ok', 'seq_num': 116}
#
#
# =>: 07:59:24.556799
# ('{"file_name": "dummy.lean", "seq_num": 117, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.557072
# {'response': 'ok', 'seq_num': 117}
#
#
# =>: 07:59:24.557173
# ('{"file_name": "dummy.lean", "seq_num": 118, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.557437
# {'response': 'ok', 'seq_num': 118}
#
#
# =>: 07:59:24.557537
# ('{"file_name": "dummy.lean", "seq_num": 119, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.557890
# {'response': 'ok', 'seq_num': 119}
#
#
# =>: 07:59:24.558098
# ('{"file_name": "dummy.lean", "seq_num": 120, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.558881
# {'response': 'ok', 'seq_num': 120}
#
#
# =>: 07:59:24.559116
# ('{"file_name": "dummy.lean", "seq_num": 121, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.559423
# {'response': 'ok', 'seq_num': 121}
#
#
# =>: 07:59:24.559546
# ('{"file_name": "dummy.lean", "seq_num": 122, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.559835
# {'response': 'ok', 'seq_num': 122}
#
#
# =>: 07:59:24.559986
# ('{"file_name": "dummy.lean", "seq_num": 123, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.560348
# {'response': 'ok', 'seq_num': 123}
#
#
# =>: 07:59:24.560475
# ('{"file_name": "dummy.lean", "seq_num": 124, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.560812
# {'response': 'ok', 'seq_num': 124}
#
#
# =>: 07:59:24.560938
# ('{"file_name": "dummy.lean", "seq_num": 125, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.561269
# {'response': 'ok', 'seq_num': 125}
#
#
# =>: 07:59:24.561373
# ('{"file_name": "dummy.lean", "seq_num": 126, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.561681
# {'response': 'ok', 'seq_num': 126}
#
#
# =>: 07:59:24.561824
# ('{"file_name": "dummy.lean", "seq_num": 127, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.562135
# {'response': 'ok', 'seq_num': 127}
#
#
# =>: 07:59:24.562254
# ('{"file_name": "dummy.lean", "seq_num": 128, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.562568
# {'response': 'ok', 'seq_num': 128}
#
#
# =>: 07:59:24.562676
# ('{"file_name": "dummy.lean", "seq_num": 129, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.562983
# {'response': 'ok', 'seq_num': 129}
#
#
# =>: 07:59:24.563087
# ('{"file_name": "dummy.lean", "seq_num": 130, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.563486
# {'response': 'ok', 'seq_num': 130}
#
#
# =>: 07:59:24.563687
# ('{"file_name": "dummy.lean", "seq_num": 131, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.567202
# {'response': 'ok', 'seq_num': 131}
#
#
# =>: 07:59:24.567441
# ('{"file_name": "dummy.lean", "seq_num": 132, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.568736
# {'response': 'ok', 'seq_num': 132}
#
#
# =>: 07:59:24.568967
# ('{"file_name": "dummy.lean", "seq_num": 133, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.569415
# {'response': 'ok', 'seq_num': 133}
#
#
# =>: 07:59:24.569611
# ('{"file_name": "dummy.lean", "seq_num": 134, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.570035
# {'response': 'ok', 'seq_num': 134}
#
#
# =>: 07:59:24.570214
# ('{"file_name": "dummy.lean", "seq_num": 135, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.571388
# {'response': 'ok', 'seq_num': 135}
#
#
# =>: 07:59:24.571569
# ('{"file_name": "dummy.lean", "seq_num": 136, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.571905
# {'response': 'ok', 'seq_num': 136}
#
#
# =>: 07:59:24.572020
# ('{"file_name": "dummy.lean", "seq_num": 137, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.572314
# {'response': 'ok', 'seq_num': 137}
#
#
# =>: 07:59:24.572428
# ('{"file_name": "dummy.lean", "seq_num": 138, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.572791
# {'response': 'ok', 'seq_num': 138}
#
#
# =>: 07:59:24.572990
# ('{"file_name": "dummy.lean", "seq_num": 139, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.573563
# {'response': 'ok', 'seq_num': 139}
#
#
# =>: 07:59:24.573957
# ('{"file_name": "dummy.lean", "seq_num": 140, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.574329
# {'response': 'ok', 'seq_num': 140}
#
#
# =>: 07:59:24.574453
# ('{"file_name": "dummy.lean", "seq_num": 141, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.574805
# {'response': 'ok', 'seq_num': 141}
#
#
# =>: 07:59:24.574911
# ('{"file_name": "dummy.lean", "seq_num": 142, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.575216
# {'response': 'ok', 'seq_num': 142}
#
#
# =>: 07:59:24.575347
# ('{"file_name": "dummy.lean", "seq_num": 143, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.575831
# {'response': 'ok', 'seq_num': 143}
#
#
# =>: 07:59:24.575973
# ('{"file_name": "dummy.lean", "seq_num": 144, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.576287
# {'response': 'ok', 'seq_num': 144}
#
#
# =>: 07:59:24.576409
# ('{"file_name": "dummy.lean", "seq_num": 145, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.576703
# {'response': 'ok', 'seq_num': 145}
#
#
# =>: 07:59:24.576829
# ('{"file_name": "dummy.lean", "seq_num": 146, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.577111
# {'response': 'ok', 'seq_num': 146}
#
#
# =>: 07:59:24.577215
# ('{"file_name": "dummy.lean", "seq_num": 147, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.577493
# {'response': 'ok', 'seq_num': 147}
#
#
# =>: 07:59:24.577650
# ('{"file_name": "dummy.lean", "seq_num": 148, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.583551
# {'response': 'ok', 'seq_num': 148}
#
#
# =>: 07:59:24.583798
# ('{"file_name": "dummy.lean", "seq_num": 149, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.584282
# {'response': 'ok', 'seq_num': 149}
#
#
# =>: 07:59:24.584477
# ('{"file_name": "dummy.lean", "seq_num": 150, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.585556
# {'response': 'ok', 'seq_num': 150}
#
#
# =>: 07:59:24.585802
# ('{"file_name": "dummy.lean", "seq_num": 151, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.586289
# {'response': 'ok', 'seq_num': 151}
#
#
# =>: 07:59:24.586501
# ('{"file_name": "dummy.lean", "seq_num": 152, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.587017
# {'response': 'ok', 'seq_num': 152}
#
#
# =>: 07:59:24.587231
# ('{"file_name": "dummy.lean", "seq_num": 153, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.588029
# {'response': 'ok', 'seq_num': 153}
#
#
# =>: 07:59:24.588323
# ('{"file_name": "dummy.lean", "seq_num": 154, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.588824
# {'response': 'ok', 'seq_num': 154}
#
#
# =>: 07:59:24.589030
# ('{"file_name": "dummy.lean", "seq_num": 155, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.589509
# {'response': 'ok', 'seq_num': 155}
#
#
# =>: 07:59:24.589711
# ('{"file_name": "dummy.lean", "seq_num": 156, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.591216
# {'response': 'ok', 'seq_num': 156}
#
#
# =>: 07:59:24.591455
# ('{"file_name": "dummy.lean", "seq_num": 157, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.591959
# {'response': 'ok', 'seq_num': 157}
#
#
# =>: 07:59:24.592537
# ('{"file_name": "dummy.lean", "seq_num": 158, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.593337
# {'response': 'ok', 'seq_num': 158}
#
#
# =>: 07:59:24.593563
# ('{"file_name": "dummy.lean", "seq_num": 159, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.594290
# {'response': 'ok', 'seq_num': 159}
#
#
# =>: 07:59:24.596097
# ('{"file_name": "dummy.lean", "seq_num": 160, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.597708
# {'response': 'ok', 'seq_num': 160}
#
#
# =>: 07:59:24.597932
# ('{"file_name": "dummy.lean", "seq_num": 161, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.598310
# {'response': 'ok', 'seq_num': 161}
#
#
# =>: 07:59:24.598427
# ('{"file_name": "dummy.lean", "seq_num": 162, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.598738
# {'response': 'ok', 'seq_num': 162}
#
#
# =>: 07:59:24.598843
# ('{"file_name": "dummy.lean", "seq_num": 163, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.599147
# {'response': 'ok', 'seq_num': 163}
#
#
# =>: 07:59:24.599250
# ('{"file_name": "dummy.lean", "seq_num": 164, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.599563
# {'response': 'ok', 'seq_num': 164}
#
#
# =>: 07:59:24.599729
# ('{"file_name": "dummy.lean", "seq_num": 165, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.600132
# {'response': 'ok', 'seq_num': 165}
#
#
# =>: 07:59:24.600313
# ('{"file_name": "dummy.lean", "seq_num": 166, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.600645
# {'response': 'ok', 'seq_num': 166}
#
#
# =>: 07:59:24.600751
# ('{"file_name": "dummy.lean", "seq_num": 167, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.601064
# {'response': 'ok', 'seq_num': 167}
#
#
# =>: 07:59:24.601166
# ('{"file_name": "dummy.lean", "seq_num": 168, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.601550
# {'response': 'ok', 'seq_num': 168}
#
#
# =>: 07:59:24.601742
# ('{"file_name": "dummy.lean", "seq_num": 169, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.602321
# {'response': 'ok', 'seq_num': 169}
#
#
# =>: 07:59:24.602476
# ('{"file_name": "dummy.lean", "seq_num": 170, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.602808
# {'response': 'ok', 'seq_num': 170}
#
#
# =>: 07:59:24.602924
# ('{"file_name": "dummy.lean", "seq_num": 171, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.603226
# {'response': 'ok', 'seq_num': 171}
#
#
# =>: 07:59:24.603329
# ('{"file_name": "dummy.lean", "seq_num": 172, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.604371
# {'response': 'ok', 'seq_num': 172}
#
#
# =>: 07:59:24.604626
# ('{"file_name": "dummy.lean", "seq_num": 173, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.605312
# {'response': 'ok', 'seq_num': 173}
#
#
# =>: 07:59:24.605460
# ('{"file_name": "dummy.lean", "seq_num": 174, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.605827
# {'response': 'ok', 'seq_num': 174}
#
#
# =>: 07:59:24.605966
# ('{"file_name": "dummy.lean", "seq_num": 175, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.606255
# {'response': 'ok', 'seq_num': 175}
#
#
# =>: 07:59:24.606362
# ('{"file_name": "dummy.lean", "seq_num": 176, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.606653
# {'response': 'ok', 'seq_num': 176}
#
#
# =>: 07:59:24.606770
# ('{"file_name": "dummy.lean", "seq_num": 177, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.607031
# {'response': 'ok', 'seq_num': 177}
#
#
# =>: 07:59:24.607141
# ('{"file_name": "dummy.lean", "seq_num": 178, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.607418
# {'response': 'ok', 'seq_num': 178}
#
#
# =>: 07:59:24.607520
# ('{"file_name": "dummy.lean", "seq_num": 179, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.607794
# {'response': 'ok', 'seq_num': 179}
#
#
# =>: 07:59:24.607895
# ('{"file_name": "dummy.lean", "seq_num": 180, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.608172
# {'response': 'ok', 'seq_num': 180}
#
#
# =>: 07:59:24.608288
# ('{"file_name": "dummy.lean", "seq_num": 181, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.608548
# {'response': 'ok', 'seq_num': 181}
#
#
# =>: 07:59:24.608658
# ('{"file_name": "dummy.lean", "seq_num": 182, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.608933
# {'response': 'ok', 'seq_num': 182}
#
#
# =>: 07:59:24.609036
# ('{"file_name": "dummy.lean", "seq_num": 183, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.609299
# {'response': 'ok', 'seq_num': 183}
#
#
# =>: 07:59:24.609398
# ('{"file_name": "dummy.lean", "seq_num": 184, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.609667
# {'response': 'ok', 'seq_num': 184}
#
#
# =>: 07:59:24.609765
# ('{"file_name": "dummy.lean", "seq_num": 185, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.610015
# {'response': 'ok', 'seq_num': 185}
#
#
# =>: 07:59:24.610540
# ('{"file_name": "dummy.lean", "seq_num": 186, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.611287
# {'response': 'ok', 'seq_num': 186}
#
#
# =>: 07:59:24.611453
# ('{"file_name": "dummy.lean", "seq_num": 187, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.613435
# {'response': 'ok', 'seq_num': 187}
#
#
# =>: 07:59:24.613685
# ('{"file_name": "dummy.lean", "seq_num": 188, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.614189
# {'response': 'ok', 'seq_num': 188}
#
#
# =>: 07:59:24.614391
# ('{"file_name": "dummy.lean", "seq_num": 189, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.614835
# {'response': 'ok', 'seq_num': 189}
#
#
# =>: 07:59:24.614972
# ('{"file_name": "dummy.lean", "seq_num": 190, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.615285
# {'response': 'ok', 'seq_num': 190}
#
#
# =>: 07:59:24.615394
# ('{"file_name": "dummy.lean", "seq_num": 191, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.615727
# {'response': 'ok', 'seq_num': 191}
#
#
# =>: 07:59:24.615873
# ('{"file_name": "dummy.lean", "seq_num": 192, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.616160
# {'response': 'ok', 'seq_num': 192}
#
#
# =>: 07:59:24.616266
# ('{"file_name": "dummy.lean", "seq_num": 193, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.616531
# {'response': 'ok', 'seq_num': 193}
#
#
# =>: 07:59:24.616634
# ('{"file_name": "dummy.lean", "seq_num": 194, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.616897
# {'response': 'ok', 'seq_num': 194}
#
#
# =>: 07:59:24.616998
# ('{"file_name": "dummy.lean", "seq_num": 195, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.617296
# {'response': 'ok', 'seq_num': 195}
#
#
# =>: 07:59:24.617414
# ('{"file_name": "dummy.lean", "seq_num": 196, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.617680
# {'response': 'ok', 'seq_num': 196}
#
#
# =>: 07:59:24.617792
# ('{"file_name": "dummy.lean", "seq_num": 197, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.618124
# {'response': 'ok', 'seq_num': 197}
#
#
# =>: 07:59:24.620169
# ('{"file_name": "dummy.lean", "seq_num": 198, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.620580
# {'response': 'ok', 'seq_num': 198}
#
#
# =>: 07:59:24.620717
# ('{"file_name": "dummy.lean", "seq_num": 199, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.621009
# {'response': 'ok', 'seq_num': 199}
#
#
# =>: 07:59:24.621115
# ('{"file_name": "dummy.lean", "seq_num": 200, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.621384
# {'response': 'ok', 'seq_num': 200}
#
#
# =>: 07:59:24.621486
# ('{"file_name": "dummy.lean", "seq_num": 201, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.621777
# {'response': 'ok', 'seq_num': 201}
#
#
# =>: 07:59:24.621877
# ('{"file_name": "dummy.lean", "seq_num": 202, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.622166
# {'response': 'ok', 'seq_num': 202}
#
#
# =>: 07:59:24.622269
# ('{"file_name": "dummy.lean", "seq_num": 203, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.622542
# {'response': 'ok', 'seq_num': 203}
#
#
# =>: 07:59:24.622642
# ('{"file_name": "dummy.lean", "seq_num": 204, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.622895
# {'response': 'ok', 'seq_num': 204}
#
#
# =>: 07:59:24.622992
# ('{"file_name": "dummy.lean", "seq_num": 205, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.623250
# {'response': 'ok', 'seq_num': 205}
#
#
# =>: 07:59:24.623347
# ('{"file_name": "dummy.lean", "seq_num": 206, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.627450
# {'response': 'ok', 'seq_num': 206}
#
#
# =>: 07:59:24.627686
# ('{"file_name": "dummy.lean", "seq_num": 207, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.628148
# {'response': 'ok', 'seq_num': 207}
#
#
# =>: 07:59:24.628333
# ('{"file_name": "dummy.lean", "seq_num": 208, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.628725
# {'response': 'ok', 'seq_num': 208}
#
#
# =>: 07:59:24.628857
# ('{"file_name": "dummy.lean", "seq_num": 209, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.631431
# {'response': 'ok', 'seq_num': 209}
#
#
# =>: 07:59:24.631671
# ('{"file_name": "dummy.lean", "seq_num": 210, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.632166
# {'response': 'ok', 'seq_num': 210}
#
#
# =>: 07:59:24.632483
# ('{"file_name": "dummy.lean", "seq_num": 211, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.639405
# {'response': 'ok', 'seq_num': 211}
#
#
# =>: 07:59:24.639651
# ('{"file_name": "dummy.lean", "seq_num": 212, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.640172
# {'response': 'ok', 'seq_num': 212}
#
#
# =>: 07:59:24.640394
# ('{"file_name": "dummy.lean", "seq_num": 213, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.640934
# {'response': 'ok', 'seq_num': 213}
#
#
# =>: 07:59:24.641147
# ('{"file_name": "dummy.lean", "seq_num": 214, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.648408
# {'response': 'ok', 'seq_num': 214}
#
#
# =>: 07:59:24.648645
# ('{"file_name": "dummy.lean", "seq_num": 215, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.649165
# {'response': 'ok', 'seq_num': 215}
#
#
# =>: 07:59:24.649383
# ('{"file_name": "dummy.lean", "seq_num": 216, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.649837
# {'response': 'ok', 'seq_num': 216}
#
#
# =>: 07:59:24.649969
# ('{"file_name": "dummy.lean", "seq_num": 217, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.650279
# {'response': 'ok', 'seq_num': 217}
#
#
# =>: 07:59:24.650398
# ('{"file_name": "dummy.lean", "seq_num": 218, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.650721
# {'response': 'ok', 'seq_num': 218}
#
#
# =>: 07:59:24.650883
# ('{"file_name": "dummy.lean", "seq_num": 219, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.651300
# {'response': 'ok', 'seq_num': 219}
#
#
# =>: 07:59:24.651488
# ('{"file_name": "dummy.lean", "seq_num": 220, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.651916
# {'response': 'ok', 'seq_num': 220}
#
#
# =>: 07:59:24.652100
# ('{"file_name": "dummy.lean", "seq_num": 221, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.652564
# {'response': 'ok', 'seq_num': 221}
#
#
# =>: 07:59:24.652795
# ('{"file_name": "dummy.lean", "seq_num": 222, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.653277
# {'response': 'ok', 'seq_num': 222}
#
#
# =>: 07:59:24.653482
# ('{"file_name": "dummy.lean", "seq_num": 223, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.655706
# {'response': 'ok', 'seq_num': 223}
#
#
# =>: 07:59:24.655968
# ('{"file_name": "dummy.lean", "seq_num": 224, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.656464
# {'response': 'ok', 'seq_num': 224}
#
#
# =>: 07:59:24.656681
# ('{"file_name": "dummy.lean", "seq_num": 225, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.657151
# {'response': 'ok', 'seq_num': 225}
#
#
# =>: 07:59:24.657367
# ('{"file_name": "dummy.lean", "seq_num": 226, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.658680
# {'response': 'ok', 'seq_num': 226}
#
#
# =>: 07:59:24.658975
# ('{"file_name": "dummy.lean", "seq_num": 227, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.669566
# {'response': 'ok', 'seq_num': 227}
#
#
# =>: 07:59:24.669810
# ('{"file_name": "dummy.lean", "seq_num": 228, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.670334
# {'response': 'ok', 'seq_num': 228}
#
#
# =>: 07:59:24.670555
# ('{"file_name": "dummy.lean", "seq_num": 229, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.671101
# {'response': 'ok', 'seq_num': 229}
#
#
# =>: 07:59:24.671346
# ('{"file_name": "dummy.lean", "seq_num": 230, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.673529
# {'response': 'ok', 'seq_num': 230}
#
#
# =>: 07:59:24.673781
# ('{"file_name": "dummy.lean", "seq_num": 231, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.675009
# {'response': 'ok', 'seq_num': 231}
#
#
# =>: 07:59:24.675372
# ('{"file_name": "dummy.lean", "seq_num": 232, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.675943
# {'response': 'ok', 'seq_num': 232}
#
#
# =>: 07:59:24.676223
# ('{"file_name": "dummy.lean", "seq_num": 233, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.681230
# {'response': 'ok', 'seq_num': 233}
#
#
# =>: 07:59:24.681574
# ('{"file_name": "dummy.lean", "seq_num": 234, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.682170
# {'response': 'ok', 'seq_num': 234}
#
#
# =>: 07:59:24.682411
# ('{"file_name": "dummy.lean", "seq_num": 235, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.682760
# {'response': 'ok', 'seq_num': 235}
#
#
# =>: 07:59:24.682872
# ('{"file_name": "dummy.lean", "seq_num": 236, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.683196
# {'response': 'ok', 'seq_num': 236}
#
#
# =>: 07:59:24.683321
# ('{"file_name": "dummy.lean", "seq_num": 237, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.685603
# {'response': 'ok', 'seq_num': 237}
#
#
# =>: 07:59:24.688837
# ('{"file_name": "dummy.lean", "seq_num": 238, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.689811
# {'response': 'ok', 'seq_num': 238}
#
#
# =>: 07:59:24.690011
# ('{"file_name": "dummy.lean", "seq_num": 239, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.690313
# {'response': 'ok', 'seq_num': 239}
#
#
# =>: 07:59:24.690421
# ('{"file_name": "dummy.lean", "seq_num": 240, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.690785
# {'response': 'ok', 'seq_num': 240}
#
#
# =>: 07:59:24.690916
# ('{"file_name": "dummy.lean", "seq_num": 241, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.691208
# {'response': 'ok', 'seq_num': 241}
#
#
# =>: 07:59:24.691388
# ('{"file_name": "dummy.lean", "seq_num": 242, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.691689
# {'response': 'ok', 'seq_num': 242}
#
#
# =>: 07:59:24.691796
# ('{"file_name": "dummy.lean", "seq_num": 243, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.696852
# {'response': 'ok', 'seq_num': 243}
#
#
# =>: 07:59:24.697157
# ('{"file_name": "dummy.lean", "seq_num": 244, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.762982
# {'response': 'ok', 'seq_num': 244}
#
#
# =>: 07:59:24.787666
# ('{"file_name": "dummy.lean", "seq_num": 245, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.788252
# {'response': 'ok', 'seq_num': 245}
#
#
# =>: 07:59:24.788444
# ('{"file_name": "dummy.lean", "seq_num": 246, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.788907
# {'response': 'ok', 'seq_num': 246}
#
#
# =>: 07:59:24.789079
# ('{"file_name": "dummy.lean", "seq_num": 247, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.789504
# {'response': 'ok', 'seq_num': 247}
#
#
# =>: 07:59:24.808643
# ('{"file_name": "dummy.lean", "seq_num": 248, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:24.809237
# ...
#  '"column": 0}')
#
# <=: 07:59:33.195884
# {'response': 'ok', 'seq_num': 2096}
#
#
# =>: 07:59:33.197336
# ('{"file_name": "dummy.lean", "seq_num": 2097, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.198673
# {'response': 'ok', 'seq_num': 2097}
#
#
# =>: 07:59:33.198905
# ('{"file_name": "dummy.lean", "seq_num": 2098, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.200113
# {'response': 'ok', 'seq_num': 2098}
#
#
# =>: 07:59:33.201051
# ('{"file_name": "dummy.lean", "seq_num": 2099, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.202318
# {'response': 'ok', 'seq_num': 2099}
#
#
# =>: 07:59:33.202694
# ('{"file_name": "dummy.lean", "seq_num": 2100, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.203257
# {'response': 'ok', 'seq_num': 2100}
#
#
# =>: 07:59:33.203472
# ('{"file_name": "dummy.lean", "seq_num": 2101, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.204010
# {'response': 'ok', 'seq_num': 2101}
#
#
# =>: 07:59:33.204255
# ('{"file_name": "dummy.lean", "seq_num": 2102, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.205039
# {'response': 'ok', 'seq_num': 2102}
#
#
# =>: 07:59:33.205214
# ('{"file_name": "dummy.lean", "seq_num": 2103, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.206342
# {'response': 'ok', 'seq_num': 2103}
#
#
# =>: 07:59:33.206600
# ('{"file_name": "dummy.lean", "seq_num": 2104, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.207187
# {'response': 'ok', 'seq_num': 2104}
#
#
# =>: 07:59:33.207387
# ('{"file_name": "dummy.lean", "seq_num": 2105, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.208034
# {'response': 'ok', 'seq_num': 2105}
#
#
# =>: 07:59:33.208297
# ('{"file_name": "dummy.lean", "seq_num": 2106, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.208846
# {'response': 'ok', 'seq_num': 2106}
#
#
# =>: 07:59:33.209061
# ('{"file_name": "dummy.lean", "seq_num": 2107, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.209932
# {'response': 'ok', 'seq_num': 2107}
#
#
# =>: 07:59:33.210234
# ('{"file_name": "dummy.lean", "seq_num": 2108, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.210798
# {'response': 'ok', 'seq_num': 2108}
#
#
# =>: 07:59:33.211000
# ('{"file_name": "dummy.lean", "seq_num": 2109, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.212246
# {'response': 'ok', 'seq_num': 2109}
#
#
# =>: 07:59:33.212843
# ('{"file_name": "dummy.lean", "seq_num": 2110, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.214084
# {'response': 'ok', 'seq_num': 2110}
#
#
# =>: 07:59:33.214533
# ('{"file_name": "dummy.lean", "seq_num": 2111, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.215302
# {'response': 'ok', 'seq_num': 2111}
#
#
# =>: 07:59:33.215542
# ('{"file_name": "dummy.lean", "seq_num": 2112, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.216045
# {'response': 'ok', 'seq_num': 2112}
#
#
# =>: 07:59:33.216431
# ('{"file_name": "dummy.lean", "seq_num": 2113, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.217158
# {'response': 'ok', 'seq_num': 2113}
#
#
# =>: 07:59:33.217377
# ('{"file_name": "dummy.lean", "seq_num": 2114, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.217915
# {'response': 'ok', 'seq_num': 2114}
#
#
# =>: 07:59:33.218263
# ('{"file_name": "dummy.lean", "seq_num": 2115, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.218865
# {'response': 'ok', 'seq_num': 2115}
#
#
# =>: 07:59:33.219377
# ('{"file_name": "dummy.lean", "seq_num": 2116, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.219949
# {'response': 'ok', 'seq_num': 2116}
#
#
# =>: 07:59:33.220226
# ('{"file_name": "dummy.lean", "seq_num": 2117, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.221694
# {'response': 'ok', 'seq_num': 2117}
#
#
# =>: 07:59:33.222245
# ('{"file_name": "dummy.lean", "seq_num": 2118, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.223116
# {'response': 'ok', 'seq_num': 2118}
#
#
# =>: 07:59:33.223335
# ('{"file_name": "dummy.lean", "seq_num": 2119, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.224000
# {'response': 'ok', 'seq_num': 2119}
#
#
# =>: 07:59:33.224259
# ('{"file_name": "dummy.lean", "seq_num": 2120, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.225047
# {'response': 'ok', 'seq_num': 2120}
#
#
# =>: 07:59:33.225273
# ('{"file_name": "dummy.lean", "seq_num": 2121, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.225986
# {'response': 'ok', 'seq_num': 2121}
#
#
# =>: 07:59:33.226217
# ('{"file_name": "dummy.lean", "seq_num": 2122, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.226671
# {'response': 'ok', 'seq_num': 2122}
#
#
# =>: 07:59:33.226849
# ('{"file_name": "dummy.lean", "seq_num": 2123, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.227289
# {'response': 'ok', 'seq_num': 2123}
#
#
# =>: 07:59:33.227473
# ('{"file_name": "dummy.lean", "seq_num": 2124, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.227897
# {'response': 'ok', 'seq_num': 2124}
#
#
# =>: 07:59:33.228072
# ('{"file_name": "dummy.lean", "seq_num": 2125, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.228488
# {'response': 'ok', 'seq_num': 2125}
#
#
# =>: 07:59:33.229166
# ('{"file_name": "dummy.lean", "seq_num": 2126, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.230336
# {'response': 'ok', 'seq_num': 2126}
#
#
# =>: 07:59:33.230745
# ('{"file_name": "dummy.lean", "seq_num": 2127, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.231533
# {'response': 'ok', 'seq_num': 2127}
#
#
# =>: 07:59:33.231750
# ('{"file_name": "dummy.lean", "seq_num": 2128, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.232663
# {'response': 'ok', 'seq_num': 2128}
#
#
# =>: 07:59:33.232898
# ('{"file_name": "dummy.lean", "seq_num": 2129, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.233844
# {'response': 'ok', 'seq_num': 2129}
#
#
# =>: 07:59:33.234066
# ('{"file_name": "dummy.lean", "seq_num": 2130, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.234865
# {'response': 'ok', 'seq_num': 2130}
#
#
# =>: 07:59:33.235070
# ('{"file_name": "dummy.lean", "seq_num": 2131, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.235527
# {'response': 'ok', 'seq_num': 2131}
#
#
# =>: 07:59:33.235704
# ('{"file_name": "dummy.lean", "seq_num": 2132, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.236121
# {'response': 'ok', 'seq_num': 2132}
#
#
# =>: 07:59:33.236291
# ('{"file_name": "dummy.lean", "seq_num": 2133, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.239565
# {'response': 'ok', 'seq_num': 2133}
#
#
# =>: 07:59:33.239757
# ('{"file_name": "dummy.lean", "seq_num": 2134, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.240145
# {'response': 'ok', 'seq_num': 2134}
#
#
# =>: 07:59:33.240303
# ('{"file_name": "dummy.lean", "seq_num": 2135, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.240701
# {'response': 'ok', 'seq_num': 2135}
#
#
# =>: 07:59:33.240865
# ('{"file_name": "dummy.lean", "seq_num": 2136, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.241283
# {'response': 'ok', 'seq_num': 2136}
#
#
# =>: 07:59:33.247906
# ('{"file_name": "dummy.lean", "seq_num": 2137, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.248449
# {'response': 'ok', 'seq_num': 2137}
#
#
# =>: 07:59:33.248637
# ('{"file_name": "dummy.lean", "seq_num": 2138, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.282559
# {'response': 'ok', 'seq_num': 2138}
#
#
# =>: 07:59:33.282779
# ('{"file_name": "dummy.lean", "seq_num": 2139, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.283269
# {'response': 'ok', 'seq_num': 2139}
#
#
# =>: 07:59:33.283458
# ('{"file_name": "dummy.lean", "seq_num": 2140, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.288653
# {'response': 'ok', 'seq_num': 2140}
#
#
# =>: 07:59:33.288876
# ('{"file_name": "dummy.lean", "seq_num": 2141, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.289330
# {'response': 'ok', 'seq_num': 2141}
#
#
# =>: 07:59:33.289492
# ('{"file_name": "dummy.lean", "seq_num": 2142, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.289894
# {'response': 'ok', 'seq_num': 2142}
#
#
# =>: 07:59:33.290054
# ('{"file_name": "dummy.lean", "seq_num": 2143, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.291919
# {'response': 'ok', 'seq_num': 2143}
#
#
# =>: 07:59:33.292148
# ('{"file_name": "dummy.lean", "seq_num": 2144, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.293806
# {'response': 'ok', 'seq_num': 2144}
#
#
# =>: 07:59:33.295210
# ('{"file_name": "dummy.lean", "seq_num": 2145, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.295716
# {'response': 'ok', 'seq_num': 2145}
#
#
# =>: 07:59:33.295882
# ('{"file_name": "dummy.lean", "seq_num": 2146, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.300170
# {'response': 'ok', 'seq_num': 2146}
#
#
# =>: 07:59:33.300396
# ('{"file_name": "dummy.lean", "seq_num": 2147, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.300923
# {'response': 'ok', 'seq_num': 2147}
#
#
# =>: 07:59:33.301292
# ('{"file_name": "dummy.lean", "seq_num": 2148, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.301869
# {'response': 'ok', 'seq_num': 2148}
#
#
# =>: 07:59:33.302081
# ('{"file_name": "dummy.lean", "seq_num": 2149, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.302527
# {'response': 'ok', 'seq_num': 2149}
#
#
# =>: 07:59:33.302901
# ('{"file_name": "dummy.lean", "seq_num": 2150, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.303650
# {'response': 'ok', 'seq_num': 2150}
#
#
# =>: 07:59:33.304191
# ('{"file_name": "dummy.lean", "seq_num": 2151, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.305795
# {'response': 'ok', 'seq_num': 2151}
#
#
# =>: 07:59:33.306016
# ('{"file_name": "dummy.lean", "seq_num": 2152, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.306458
# {'response': 'ok', 'seq_num': 2152}
#
#
# =>: 07:59:33.306635
# ('{"file_name": "dummy.lean", "seq_num": 2153, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.307050
# {'response': 'ok', 'seq_num': 2153}
#
#
# =>: 07:59:33.307209
# ('{"file_name": "dummy.lean", "seq_num": 2154, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.308221
# {'response': 'ok', 'seq_num': 2154}
#
#
# =>: 07:59:33.308520
# ('{"file_name": "dummy.lean", "seq_num": 2155, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.309753
# {'response': 'ok', 'seq_num': 2155}
#
#
# =>: 07:59:33.310536
# ('{"file_name": "dummy.lean", "seq_num": 2156, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.312550
# {'response': 'ok', 'seq_num': 2156}
#
#
# =>: 07:59:33.313107
# ('{"file_name": "dummy.lean", "seq_num": 2157, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.315042
# {'response': 'ok', 'seq_num': 2157}
#
#
# =>: 07:59:33.315278
# ('{"file_name": "dummy.lean", "seq_num": 2158, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.315835
# {'response': 'ok', 'seq_num': 2158}
#
#
# =>: 07:59:33.316057
# ('{"file_name": "dummy.lean", "seq_num": 2159, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.316913
# {'response': 'ok', 'seq_num': 2159}
#
#
# =>: 07:59:33.317278
# ('{"file_name": "dummy.lean", "seq_num": 2160, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.318952
# {'response': 'ok', 'seq_num': 2160}
#
#
# =>: 07:59:33.319173
# ('{"file_name": "dummy.lean", "seq_num": 2161, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.319923
# {'response': 'ok', 'seq_num': 2161}
#
#
# =>: 07:59:33.320140
# ('{"file_name": "dummy.lean", "seq_num": 2162, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.320725
# {'response': 'ok', 'seq_num': 2162}
#
#
# =>: 07:59:33.320925
# ('{"file_name": "dummy.lean", "seq_num": 2163, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.321411
# {'response': 'ok', 'seq_num': 2163}
#
#
# =>: 07:59:33.321610
# ('{"file_name": "dummy.lean", "seq_num": 2164, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.326622
# {'response': 'ok', 'seq_num': 2164}
#
#
# =>: 07:59:33.326849
# ('{"file_name": "dummy.lean", "seq_num": 2165, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.327392
# {'response': 'ok', 'seq_num': 2165}
#
#
# =>: 07:59:33.329060
# ('{"file_name": "dummy.lean", "seq_num": 2166, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.329628
# {'response': 'ok', 'seq_num': 2166}
#
#
# =>: 07:59:33.329952
# ('{"file_name": "dummy.lean", "seq_num": 2167, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.331630
# {'response': 'ok', 'seq_num': 2167}
#
#
# =>: 07:59:33.335852
# ('{"file_name": "dummy.lean", "seq_num": 2168, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.336413
# {'response': 'ok', 'seq_num': 2168}
#
#
# =>: 07:59:33.336618
# ('{"file_name": "dummy.lean", "seq_num": 2169, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.337115
# {'response': 'ok', 'seq_num': 2169}
#
#
# =>: 07:59:33.337333
# ('{"file_name": "dummy.lean", "seq_num": 2170, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.337864
# {'response': 'ok', 'seq_num': 2170}
#
#
# =>: 07:59:33.338072
# ('{"file_name": "dummy.lean", "seq_num": 2171, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.340155
# {'response': 'ok', 'seq_num': 2171}
#
#
# =>: 07:59:33.340388
# ('{"file_name": "dummy.lean", "seq_num": 2172, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.342099
# {'response': 'ok', 'seq_num': 2172}
#
#
# =>: 07:59:33.342299
# ('{"file_name": "dummy.lean", "seq_num": 2173, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.345460
# {'response': 'ok', 'seq_num': 2173}
#
#
# =>: 07:59:33.345684
# ('{"file_name": "dummy.lean", "seq_num": 2174, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.346330
# {'response': 'ok', 'seq_num': 2174}
#
#
# =>: 07:59:33.347117
# ('{"file_name": "dummy.lean", "seq_num": 2175, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.348415
# {'response': 'ok', 'seq_num': 2175}
#
#
# =>: 07:59:33.350050
# ('{"file_name": "dummy.lean", "seq_num": 2176, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.350264
# {'is_running': True,
#  'response': 'current_tasks',
#  'tasks': [{'desc': '_example',
#             'end_pos_col': 0,
#             'end_pos_line': 73,
#             'file_name': 'fake_lean_file1.lean',
#             'pos_col': 0,
#             'pos_line': 67}]}
#
# <=: 07:59:33.350974
# {'response': 'ok', 'seq_num': 2176}
#
#
# =>: 07:59:33.351132
# ('{"file_name": "dummy.lean", "seq_num": 2177, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.351574
# {'response': 'ok', 'seq_num': 2177}
#
#
# =>: 07:59:33.351707
# ('{"file_name": "dummy.lean", "seq_num": 2178, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.352024
# {'response': 'ok', 'seq_num': 2178}
#
#
# =>: 07:59:33.352126
# ('{"file_name": "dummy.lean", "seq_num": 2179, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.353253
# {'response': 'ok', 'seq_num': 2179}
#
#
# =>: 07:59:33.353664
# ('{"file_name": "dummy.lean", "seq_num": 2180, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.355356
# {'response': 'ok', 'seq_num': 2180}
#
#
# =>: 07:59:33.355637
# ('{"file_name": "dummy.lean", "seq_num": 2181, "command": "info", "line": 1, '
#  '"column": 0}')
#
# <=: 07:59:33.367252
# {'msgs': [{'caption': 'trace output',
#            'file_name': 'fake_lean_file1.lean',
#            'pos_col': 0,
#            'pos_line': 70,
#            'severity': 'information',
#            'text': 'Goals: 0\n\n\n'},
#           {'caption': 'trace output',
#            'file_name': 'fake_lean_file1.lean',
#            'pos_col': 0,
#            'pos_line': 71,
#            'severity': 'information',
#            'text': '\n'},
#           {'caption': 'eval result',
#            'end_pos_col': 7,
#            'end_pos_line': 75,
#            'file_name': 'fake_lean_file1.lean',
#            'pos_col': 0,
#            'pos_line': 75,
#            'severity': 'information',
#            'text': '1'}],
#  'response': 'all_messages'}
#
# <=: 07:59:33.369109
# {'response': 'ok', 'seq_num': 2181}
# ('success', [], '')

# %%
# lots of examples
with LeanTacticTestingInterface() as lean_interface:
    goal1 = LeanGoal([], ['p q : Prop'],  'p = p')
    display(lean_interface.apply_tactic(goal1, 'refl'))
    display(lean_interface.apply_tactic(goal1, 'skip'))
    display(lean_interface.apply_tactic(goal1, 'done'))
    display(lean_interface.apply_tactic(goal1, 'abc123'))
    goal2 = LeanGoal([], ['n m : nat'],  'n = n')
    display(lean_interface.apply_tactic(goal2, 'induction n'))
    goal3 = LeanGoal([], [], 'abc = xyz')
    display(lean_interface.apply_tactic(goal3, 'skip'))
    display(lean_interface.apply_tactic(goal3, 'fgh'))
# Out:
# ('success', [], '')
# ('success',
#  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop '], conclusion='@eq.{1} Prop p p')],
#  '')
# ('tactic_failure',
#  ['done tactic failed, there are unsolved goals\nstate:\np q : Prop\n⊢ p = p'],
#  '')
# ('tactic_failure',
#  ["unknown identifier 'abc123'",
#   "don't know how to synthesize placeholder\ncontext:\np q : Prop\n⊢ Type ?"],
#  '')
# ('success',
#  [LeanGoal(universes=[], assumptions=['m : nat'], conclusion='@eq.{1} nat nat.zero nat.zero'),
#   LeanGoal(universes=[], assumptions=['m : nat', 'n_n : nat', 'n_ih : @eq.{1} nat n_n n_n '], conclusion='@eq.{1} nat (nat.succ n_n) (nat.succ n_n)')],
#  '')
# ('theorem_error',
#  ["unknown identifier 'abc'",
#   "unknown identifier 'xyz'",
#   "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#  '')
# ('theorem_error',
#  ["unknown identifier 'abc'",
#   "unknown identifier 'xyz'",
#   "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#  '')

# %%
# examples of executing in batch
with LeanTacticTestingInterface() as lean_interface:
    goal1 = LeanGoal([], ['p q : Prop'],  'p = p')
    goal2 = LeanGoal([], ['n m : nat'],  'n = n')
    goal3 = LeanGoal([], [], 'abc = xyz')
    
    goals = [goal1, goal1, goal1, goal1, goal2, goal3, goal3]
    tactics = ['refl', 'skip', 'done', 'abc123', 'induction n', 'skip', 'fgh']
    
    display(lean_interface.apply_tactic_multiple(goals, tactics))
# Out:
# [('success', [], ''),
#  ('success',
#   [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop '], conclusion='@eq.{1} Prop p p')],
#   ''),
#  ('tactic_failure',
#   ['done tactic failed, there are unsolved goals\nstate:\np q : Prop\n⊢ p = p'],
#   ''),
#  ('tactic_failure',
#   ["unknown identifier 'abc123'",
#    "don't know how to synthesize placeholder\ncontext:\np q : Prop\n⊢ Type ?"],
#   ''),
#  ('success',
#   [LeanGoal(universes=[], assumptions=['m : nat'], conclusion='@eq.{1} nat nat.zero nat.zero'),
#    LeanGoal(universes=[], assumptions=['m : nat', 'n_n : nat', 'n_ih : @eq.{1} nat n_n n_n '], conclusion='@eq.{1} nat (nat.succ n_n) (nat.succ n_n)')],
#   ''),
#  ('theorem_error',
#   ["unknown identifier 'abc'",
#    "unknown identifier 'xyz'",
#    "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#   ''),
#  ('theorem_error',
#   ["unknown identifier 'abc'",
#    "unknown identifier 'xyz'",
#    "don't know how to synthesize placeholder\ncontext:\n⊢ Sort ?"],
#   '')]

# %% [markdown]
# ### Speed and robustness
# Unfortunately, this is quit slow.

# %%
# time it
total_runs = 50
total_time = 0
goal = LeanGoal([], [],  'true')
with LeanTacticTestingInterface() as lean_interface:
    # give the system a chance to "warm up"
    lean_interface.apply_tactic(goal, 'refl')
    time.sleep(2)
    
    for i in range(total_runs):
        a = time.time()
        response = lean_interface.apply_tactic(goal, 'refl')
        b = time.time()
        total_time += b - a
"Each call to the Lean interface takes on average {} seconds".format(total_time / total_runs)
# Out:
# 'Each call to the Lean interface takes on average 0.3020005702972412 seconds'

# %% [markdown]
# But sending multiple calls to Lean speeds things up.

# %%
# time running multiple goal-tactics at a time 
total_runs = 50
batch_size = 32
total_time = 0
goals = [LeanGoal([], [],  'true')] * batch_size
tactics = ['refl'] * batch_size
with LeanTacticTestingInterface() as lean_interface:
    # give the system a chance to "warm up"
    lean_interface.apply_tactic(LeanGoal([], [],  'true'), 'refl')
    time.sleep(2)
    
    for i in range(total_runs):
        a = time.time()
        response = lean_interface.apply_tactic_multiple(goals, tactics)
        b = time.time()
        total_time += b - a
display("Each call to the Lean interface takes on average {} seconds".format(total_time / total_runs))
display("Each goal/tactic pair (w/ batch size {}) takes on average {} seconds".format(batch_size, total_time / total_runs / batch_size))
# Out:
# 'Each call to the Lean interface takes on average 0.7805574274063111 seconds'
# 'Each goal/tactic pair (w/ batch size 32) takes on average 0.02439241960644722 seconds'

# %% [markdown]
# It is very difficult to make this process robust. If one is not careful, the results returned by `apply_tactic_multiple` could be for a previous call to the method.  There are ways to get around this, but if one is not careful they would significantly increase Lean's memory usage over time.  (For example, using a new file name for every "sync" request would be bad, since Lean caches the results of each file.)  This is a test that `apply_tactic_multiple` is robust.

# %%
# test robustness.  Make sure we are getting correct results back 
# and not results for a previous request.
rounds = 100
with LeanTacticTestingInterface() as lean_interface:
    for r in range(rounds):
        count = rounds - r
        goals = [LeanGoal([], ['p_{}_{} : Prop'.format(r, i)],  'p_{}_{}'.format(r, i)) for i in range(count)]
        
        if r % 3 == 0:
            tactics = ['skip' for _ in range(count)]
            results = lean_interface.apply_tactic_multiple(goals, tactics)
            assert len(results) == count
            for i, (response, new_goals, _) in enumerate(results):
                assert response == 'success'
                assert new_goals[0].conclusion == 'p_{}_{}'.format(r, i)
        else:
            tactics = ['simp' for _ in range(count)]
            results = lean_interface.apply_tactic_multiple(goals, tactics)
            assert len(results) == count
            for i, (response, _, _) in enumerate(results):
                assert response == 'tactic_failure', response
"Passed tests"
# Out:
# 'Passed tests'

# %% [markdown]
# ### Stepping through a full proof

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
# Out:
# ('success',
#  [LeanGoal(universes=[], assumptions=['m : nat'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add m nat.zero) (@has_add.add.{0} nat nat.has_add nat.zero m)'),
#   LeanGoal(universes=[], assumptions=['m : nat', 'n_n : nat', 'n_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add m n_n) (@has_add.add.{0} nat nat.has_add n_n m) '], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add m (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) m)')],
#  '')

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(
        LeanGoal([], ['m n_n : ℕ','n_ih : m + n_n = n_n + m'], 'm + nat.succ n_n = nat.succ n_n + m'), 
        "induction m"))
# Out:
# ('success',
#  [LeanGoal(universes=[], assumptions=['n_n : nat', 'n_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add nat.zero n_n) (@has_add.add.{0} nat nat.has_add n_n nat.zero)'], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add nat.zero (nat.succ n_n))   (@has_add.add.{0} nat nat.has_add (nat.succ n_n) nat.zero)'),
#   LeanGoal(universes=[], assumptions=['n_n : nat', 'm_n : nat', 'm_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add m_n n_n) (@has_add.add.{0} nat nat.has_add n_n m_n) → @eq.{1} nat (@has_add.add.{0} nat nat.has_add m_n (nat.succ n_n)) (@has_add.add.{0} nat nat.has_add (nat.succ n_n) m_n)', 'n_ih : @eq.{1} nat (@has_add.add.{0} nat nat.has_add (nat.succ m_n) n_n) (@has_add.add.{0} nat nat.has_add n_n (nat.succ m_n)) '], conclusion='@eq.{1} nat (@has_add.add.{0} nat nat.has_add (nat.succ m_n) (nat.succ n_n))   (@has_add.add.{0} nat nat.has_add (nat.succ n_n) (nat.succ m_n))')],
#  '')

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(
        LeanGoal([], ['n_n : ℕ','n_ih : 0 + n_n = n_n + 0'],
         '0 + nat.succ n_n = nat.succ n_n + 0'), 
        "simp"))
# Out:
# ('success', [], '')

# %%
with LeanTacticTestingInterface() as lean_interface:
    display(lean_interface.apply_tactic(
        LeanGoal([], ['n_n m_n : ℕ',
         'm_ih : m_n + n_n = n_n + m_n → m_n + nat.succ n_n = nat.succ n_n + m_n',
         'n_ih : nat.succ m_n + n_n = n_n + nat.succ m_n'],
         'nat.succ m_n + nat.succ n_n = nat.succ n_n + nat.succ m_n'), 
        "simp"))
# Out:
# ('success', [], '')

# %% [markdown]
# ## Creating a simple Lean solver (with breath first search) in Python

# %% [markdown]
# Here we put all of this together to create (a non-practical) BFS prover.  Some highlights:
# - Some tactics like `apply` take a parameter.  We search the local context for all possible things to put in this parameter.  Note, we do no type checking before sending it to Lean.  The user inputs the tactic as `apply {}` to signify that something needs to be filled in from the context.
# - Our setup assumes the tactic is only applied to the first goal.  This isn't true of all tactics, so we force this by "treeifying" our proof, that is adding brackets `{ ... }` where necessary.
# - Sending multiple calls to Lean at the same time makes it much faster.  This is the only difference between the "fast" version.
# - We provide a way to verify a proof in the end (sending the whole proof as if it was a single tactic), and also walking through the proof to get information (which might be useful for machine-learning-like training).
# - This is just a proof-of-concept and not very useful in itself.

# %%
def premises_from_goal(goal):
    prems = []
    for l in goal.assumptions:
        a, _ = l.split(":")
        for v in a.strip().split(" "):
            prems.append(v)
    return prems

def tactic_applications(tactics, prems):
    tacs = []
    for t in tactics:
        if "{}" in t:
            for p in prems:
                tacs.append(t.replace("{}", p))
        else:
            tacs.append(t)
    return tacs

def treeify_proof(proof_list):
    s = ""
    goal_cnts = [1]  # open goal counts at each depth
    for tactic, new_goal_cnt in proof_list:
        while True:
            # take goals
            goal_cnt = goal_cnts.pop()

            # if no goals at this depth, end block and take off stack again
            if goal_cnt == 0:
                s += ", }"
                continue
            
            if goal_cnt == 1:
                if s: # don't put comma in front
                    s += ", "
                
            # if more than one goal, take one of them, start block and put rest back on stack
            if goal_cnt > 1:
                goal_cnts.append(goal_cnt - 1)
                s += ", { "
            
            break
            
        # apply tactic
        s += tactic
        
        # put remaining goals on stack
        goal_cnts.append(new_goal_cnt)
            
    return s 

class BreathFirstProofSearch(LeanTacticTestingInterface):
        
    def proof_search(self, lean_goal, tactics, verbose=False):
        starting_goal = lean_goal
        starting_goal_list = (starting_goal,)
        empty_tactics = tuple()
        goal_list_queue = collections.deque()
        goal_list_queue.append((starting_goal_list, empty_tactics))

        while goal_list_queue:
            goal_list, ts = goal_list_queue.popleft()
            goal = goal_list[0]
            prems = premises_from_goal(goal)
            all_tactics = tactic_applications(tactics, prems)
            for t in all_tactics:
                response, new_goals, _ = self.apply_tactic(goal, t, verbose=verbose)
                if response == 'success':
                    new_goal_list = tuple(new_goals) + goal_list[1:]
                    new_ts = ts + ((t, len(new_goals)),)
                    if not new_goal_list:
                        return treeify_proof(new_ts)

                    goal_list_queue.append((new_goal_list, new_ts))
        return None
    
    def proof_search_fast(self, lean_goal, tactics, verbose=False):
        starting_goal = lean_goal
        starting_goal_list = (starting_goal,)
        empty_tactics = tuple()
        goal_list_queue = collections.deque()
        goal_list_queue.append((starting_goal_list, empty_tactics))

        while goal_list_queue:
            goal_list, ts = goal_list_queue.popleft()
            goal = goal_list[0]
            prems = premises_from_goal(goal)
            all_tactics = tactic_applications(tactics, prems)
            
            # faster to batch process all apply_tactic calls
            results = self.apply_tactic_multiple([goal] * len(all_tactics), all_tactics, verbose=verbose)
            for t, (response, new_goals, _) in zip(all_tactics, results):
                if response == 'success':
                    new_goal_list = tuple(new_goals) + goal_list[1:]
                    new_ts = ts + ((t, len(new_goals)),)
                    if not new_goal_list:
                        return treeify_proof(new_ts)

                    goal_list_queue.append((new_goal_list, new_ts))
        return None
    
    def is_valid_proof(self, goal, proof, verbose=False):
        t = proof.replace("\n", "")  # treat proof as a single tactic
        response, goals, _ = self.apply_tactic(goal, t, verbose=verbose)
        if response == 'success' and goals == []:
            return True
        return goals
    
    def walk_through_proof(self, lean_goal, proof):
        ts = proof.replace(" {", "").replace("}, ", "").split(", ")
        goals = [lean_goal]
        for t in ts:
            goal = goals[0]
            print(" Primary Goal:  ", goal)
            print(" Tactic applied:", t)
            _, new_goals, _ = self.apply_tactic(goal, t)
            goals = new_goals + goals[1:]
            print(" New Goals: ", new_goals)
            print(" All Goals: ", goals)
            print()

# %%
def example(goal, tactics, verbose=False):
    with BreathFirstProofSearch() as bfs:
        print("Goal:", goal)
        print("Tactics:", tactics)
        print()
        start = time.time()
        proof = bfs.proof_search_fast(goal, tactics, verbose=verbose)
        end = time.time()
        print("Time to proof:", end-start, "seconds")
        print("Proof:", proof)
        print()
        print("Verified:", bfs.is_valid_proof(goal, proof, verbose=verbose))
        print()
        print("Walk through proof:")
        bfs.walk_through_proof(goal, proof)

# %%
example(
    goal = LeanGoal([], ['p q r : Prop'], 'p ∧ q → q ∧ p'), 
    tactics=['apply {}', 'cases {}', 'intro', 'split', 'left', 'right'],
)
# Out:
# Goal: LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='p ∧ q → q ∧ p')
# Tactics: ['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
#
# Time to proof: 3.0447800159454346 seconds
# Proof: intro, cases a, split, { apply a_right, }, apply a_left
#
# Verified: True
#
# Walk through proof:
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='p ∧ q → q ∧ p')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q '], conclusion='and q p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q '], conclusion='and q p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q '], conclusion='and q p')
#  Tactic applied: cases a
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q '], conclusion='and q p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q '], conclusion='and q p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q '], conclusion='and q p')
#  Tactic applied: split
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q '], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q'], conclusion='q')
#  Tactic applied: apply a_right
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_left : p', 'a_right : q '], conclusion='p')
#  Tactic applied: apply a_left
#  New Goals:  []
#  All Goals:  []

# %%
example(
    goal = LeanGoal([], ['p q r : Prop'], '(p -> (q -> r)) <-> (p /\ q -> r)'), 
    tactics=['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
)
# Out:
# Goal: LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='(p -> (q -> r)) <-> (p /\\ q -> r)')
# Tactics: ['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
#
# Time to proof: 10.852973937988281 seconds
# Proof: split, { intro, intro, cases a_1, apply a, { apply a_1_left, }, apply a_1_right, }, intro, intro, intro, apply a, split, { apply a_1, }, apply a_2
#
# Verified: True
#
# Walk through proof:
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='(p -> (q -> r)) <-> (p /\\ q -> r)')
#  Tactic applied: split
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(p → q → r) → and p q → r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop '], conclusion='(and p q → r) → p → q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(p → q → r) → and p q → r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop '], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop'], conclusion='(p → q → r) → and p q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r '], conclusion='and p q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r '], conclusion='and p q → r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop '], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r '], conclusion='and p q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1 : and p q '], conclusion='r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1 : and p q '], conclusion='r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop '], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1 : and p q '], conclusion='r')
#  Tactic applied: cases a_1
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q '], conclusion='r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q '], conclusion='r'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop '], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q '], conclusion='r')
#  Tactic applied: apply a
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q '], conclusion='q')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q '], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop '], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q'], conclusion='p')
#  Tactic applied: apply a_1_left
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q '], conclusion='q'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop '], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : p → q → r', 'a_1_left : p', 'a_1_right : q '], conclusion='q')
#  Tactic applied: apply a_1_right
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop '], conclusion='(and p q → r) → p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop '], conclusion='(and p q → r) → p → q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r '], conclusion='p → q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r '], conclusion='p → q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r '], conclusion='p → q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p '], conclusion='q → r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p '], conclusion='q → r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p '], conclusion='q → r')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='r')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='r')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='r')
#  Tactic applied: apply a
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='and p q')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='and p q')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='and p q')
#  Tactic applied: split
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='q')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='q')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q'], conclusion='p')
#  Tactic applied: apply a_1
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='q')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : and p q → r', 'a_1 : p', 'a_2 : q '], conclusion='q')
#  Tactic applied: apply a_2
#  New Goals:  []
#  All Goals:  []

# %%
example(
    goal = LeanGoal([], ['p q r : Prop'], '¬(p ↔ ¬p)'), 
    tactics=['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
)
# Out:
# Goal: LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='¬(p ↔ ¬p)')
# Tactics: ['apply {}', 'cases {}', 'intro', 'split', 'left', 'right']
#
# Time to proof: 54.75517702102661 seconds
# Proof: intro, cases a, apply a_mp, { apply a_mpr, intro, apply a_mp, { apply a, }, apply a, }, apply a_mpr, intro, apply a_mp, { apply a, }, apply a
#
# Verified: True
#
# Walk through proof:
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p q r : Prop'], conclusion='¬(p ↔ ¬p)')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : iff p (not p) '], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : iff p (not p) '], conclusion='false')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a : iff p (not p) '], conclusion='false')
#  Tactic applied: cases a
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='false')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='false')
#  Tactic applied: apply a_mp
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p'], conclusion='p')
#  Tactic applied: apply a_mpr
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='not p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='not p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='not p')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='false'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='false')
#  Tactic applied: apply a_mp
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')
#  Tactic applied: apply a
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='p')
#  Tactic applied: apply a
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='p')
#  Tactic applied: apply a_mpr
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='not p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='not p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p '], conclusion='not p')
#  Tactic applied: intro
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='false')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='false')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='false')
#  Tactic applied: apply a_mp
#  New Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='p')]
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p'), LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p'], conclusion='p')
#  Tactic applied: apply a
#  New Goals:  []
#  All Goals:  [LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='p')]
#
#  Primary Goal:   LeanGoal(universes=[], assumptions=['p : Prop', 'q : Prop', 'r : Prop', 'a_mp : p → not p', 'a_mpr : not p → p', 'a : p '], conclusion='p')
#  Tactic applied: apply a
#  New Goals:  []
#  All Goals:  []

# %% [markdown]
# ## Custom printing of Lean expressions

# %% [markdown]
# Our `apply_tactic` will return a list of goals, using Lean's verbose pp.all format.  Hence, `m n : ℕ ⊢ m + n = n + m` is returned as `LeanGoal(['m n : nat'], "@eq.{1} nat (@has_add.add.{0} nat nat.has_add m n) (@has_add.add.{0} nat nat.has_add n m)")`.  On one hand, this is not very readable by a human.  On the other hand, it is not as machine parsable as it could be.  It is however possible to have `apply_tactic` output the goals in other formats (or print other relevant information about the goal state).
#
# For example, here we write a simple piece of code which prints the Lean goals just as Lean does.

# %%
simple_custom_code = r"""
namespace custom
 
meta def trace_custom_state : tactic unit :=
do 
 tactic.trace_state,  -- default Lean pretty printed goals
 return ()

end custom
"""

# %%
with LeanTacticTestingInterface() as lean_interface:
    lean_interface.custom_code = simple_custom_code
    _, _, custom_msg = (lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
print(custom_msg)
# Out:
# 2 goals
# case nat.zero
# m : ℕ
# ⊢ m + 0 = 0 + m
#
# case nat.succ
# m n_n : ℕ,
# n_ih : m + n_n = n_n + m
# ⊢ m + nat.succ n_n = nat.succ n_n + m

# %% [markdown]
# On the other end, we may which to print the goals as expressions.  Here is  code to do that.  (It is basically the same code we are using in the LeanTacticTestingInterface above except with s-expressions instead of pp.all formatting.)

# %%
sexp_custom_code = r"""
namespace custom

def join (sep : string) : list string → string
| [x]     := x
| []      := ""
| (x::xs) := x ++ sep ++ join xs

meta def expr_to_string (e : expr bool.tt) : tactic string :=
do
  return $ to_string e.to_raw_fmt
  
meta def local_cxt_to_string (v : expr bool.tt) : tactic string := 
do 
  tp ← tactic.infer_type v,
  v_str ← expr_to_string v,
  tp_str ← expr_to_string tp,
  return $ v_str ++ "\n\n" ++ tp_str

meta def goal_to_string (g : expr) : tactic string :=
do 
  tactic.set_goals [g],
  goal ← tactic.target,
  local_cxt ← tactic.local_context,
  let local_cxt_len := list.length local_cxt,
  goal_str ← expr_to_string goal,
  local_cxt_strs ← (list.mmap local_cxt_to_string local_cxt),
  let s1 := goal_str ++ "\n\n",
  let s2 := "Local Context Vars: " ++ (to_string local_cxt_len) ++ "\n\n",
  let s3 := join "\n\n" local_cxt_strs,
  return $ s1 ++ s2 ++ s3

meta def state_report : tactic string :=
do 
 gs ← tactic.get_goals,
 -- loop over all goals (has effect of resetting the goal each time)
 let gs_len := list.length gs,
 goal_strings ← gs.mmap goal_to_string,
 tactic.set_goals gs,  -- set goals back
 let s := "Goals: " ++ (to_string gs_len) ++ "\n\n" ++ (join "\n\n" goal_strings),
 return s
 
meta def trace_custom_state : tactic unit :=
do 
 s ← state_report,
 tactic.trace s,
 return ()

end custom
"""

# %%
with LeanTacticTestingInterface() as lean_interface:
    lean_interface.custom_code = sexp_custom_code
    _, _, custom_msg = (lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
print(custom_msg)
# Out:
# Goals: 2
#
# (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (local_const 0._fresh.13.564 m (const 1 []))) (const nat.zero []))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (const nat.zero [])) (local_const 0._fresh.13.564 m (const 1 []))))
#
# Local Context Vars: 1
#
# (local_const 0._fresh.13.564 m (const 1 []))
#
# (const nat [])
#
# (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (local_const 0._fresh.13.564 m (const 1 []))) (app (const nat.succ []) (local_const 0._fresh.10.1906 n_n (const 1 []))))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (app (const nat.succ []) (local_const 0._fresh.10.1906 n_n (const 1 [])))) (local_const 0._fresh.13.564 m (const 1 []))))
#
# Local Context Vars: 3
#
# (local_const 0._fresh.13.564 m (const 1 []))
#
# (const nat [])
#
# (local_const 0._fresh.10.1906 n_n (const 1 []))
#
# (const nat [])
#
# (local_const 0._fresh.10.1907 n_ih (const 1 []))
#
# (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (local_const 0._fresh.13.564 m (const 1 []))) (local_const 0._fresh.10.1906 n_n (const 1 [])))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (local_const 0._fresh.10.1906 n_n (const 1 []))) (local_const 0._fresh.13.564 m (const 1 []))))

# %% [markdown]
# Here is code which turns each goal into a single s-expression.  The format is `(goal <intro_cnt> <expr>)` where `<expr>` is the expression and `<intro_cnt>` is the number of `intro`s one has to do on the expression to get back to the goal.  For example `m n : ℕ ⊢ m + n = n + m` is stored as `∀ m n : ℕ, m + n = n + m` so `intro_cnt` is 2 since to `intro`s are needed to reproduce `m n : ℕ ⊢ m + n = n + m`.

# %%
sexp_custom_code = r"""
namespace custom

def join (sep : string) : list string → string
| [x]     := x
| []      := ""
| (x::xs) := x ++ sep ++ join xs

meta def expr_to_string (e : expr bool.tt) : tactic string :=
do
  return $ to_string e.to_raw_fmt

meta def goal_to_string (g : expr) : tactic string :=
do 
  n ← tactic.revert_all,
  goal ← tactic.target,
  tactic.iterate_exactly n (do tactic.intro1, return ()),
  goal_str ← expr_to_string goal,
  let s := "(goal " ++ (to_string n) ++ " " ++ goal_str ++ ")",
  tactic.rotate_left 1,
  return s

meta def state_report : tactic string :=
do 
 gs ← tactic.get_goals,
 let gs_len := list.length gs,
 goal_strings ← gs.mmap goal_to_string,
 let s := join "\n\n" goal_strings,
 return s
 
meta def trace_custom_state : tactic unit :=
do 
 s ← state_report,
 tactic.trace s,
 return ()

end custom
"""

# %%
with LeanTacticTestingInterface() as lean_interface:
    lean_interface.custom_code = sexp_custom_code
    _, _, custom_msg = (lean_interface.apply_tactic(LeanGoal([], ['m n : nat'], "m + n = n + m"), "induction n"))
print(custom_msg)
# Out:
# (goal 1 (pi m default (const nat []) (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 0)) (const nat.zero []))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (const nat.zero [])) (var 0)))))
#
# (goal 3 (pi m default (const nat []) (pi n_n default (const nat []) (pi n_ih default (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 1)) (var 0))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 0)) (var 1))) (app (app (app (const eq [1]) (const nat [])) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (var 2)) (app (const nat.succ []) (var 1)))) (app (app (app (app (const has_add.add [0]) (const nat [])) (const nat.has_add [])) (app (const nat.succ []) (var 1))) (var 2)))))))

# %% [markdown]
# See Lewis and Wu [interface between Mathematica and Lean](https://robertylewis.com/leanmm/) for an example of parsing Lean expressions into Mathematica code.)

# %% [markdown]
# ## TODOs

# %% [markdown]
# - Code:
#     - Is there a way to make this faster?
#     - Is there a way to make this more robust?  (It works for now, but still feels rickety.)
#     - Make this production level code.  It is just a proof of concept and still quite hacky.
# - Functionality
#     - How should one enter definitions and notation?
#     - Can we even enter all Lean theorems this way (assuming there definitions and notation are stored in mathlib)?
#       - A next step would be to get a list of all theorems and see if we can apply the `skip` tactic to them.
#     - How should one enter premises?  The easiest way is to add them as assumptions to the goal.
#     - What about imports, etc?
#     - We only apply tactics to a single goal and not a goal stack

# %% [markdown]
# ## What I want from Lean 4

# %% [markdown]
# - Either a REPL like interface which is fast,
# - or a way to quickly in a few milliseconds call Lean for the text of a small file and get a direct (and unambiguous) response to my request.
# - Better documentation of the communication interface
# - Better documentation of the tactic commands
